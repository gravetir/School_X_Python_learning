# %%
# %pip install tensorflow numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import numpy as np

# %%
model = None

def generateInputs(num):
    inputs = []
    for i in range(num):
        x = np.random.randint(-10, 10)
        y = np.random.randint(-10, 10)
        inputs.append([x, y])
    return inputs

def initModel():
    global model
    input = [[1, 0], [-1, 1], [-1, 1], [1, 1]]
    inputTensor = tf.constant(input, shape=(len(input), 2))
    output = [[1], [-1], [1], [-1]]
    outputTensor = tf.constant(output, shape=(len(output), 1))
    testInput = generateInputs(10)
    testInputTensor = tf.constant(testInput, shape=(len(testInput), 2))
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(units=2, activation='sigmoid', input_shape=(2,)))
    model.add(tf.keras.layers.Dense(units=1, activation='sigmoid', input_shape=(1,)))
    model.compile(optimizer=tf.keras.optimizers.Adam(0.1), loss='mean_squared_error')
    model.fit(inputTensor, outputTensor, epochs=100, shuffle=True, callbacks=[LossHistoryCallback()])

class LossHistoryCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        loss = logs['loss']
        # changeLossHistory((prevHistory) => [...prevHistory, {'epoch': epoch, 'loss': loss}])

data = []
lossHistory = []

initModel()
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 350ms/step - loss: 1.6584
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5743
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4854
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3980
# Epoch 5/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3182
# Epoch 6/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2497
# Epoch 7/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1937
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1490
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1137
# Epoch 10/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0861
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0644
# Epoch 12/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0475
# ...
