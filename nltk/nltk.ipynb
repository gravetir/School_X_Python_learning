# %%
# %pip install nltk spacy pymorphy2 pymorphy2-dicts pymystem3
# Out:
# Requirement already satisfied: nltk in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (3.8.1)
# Requirement already satisfied: spacy in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (3.7.2)
# Requirement already satisfied: pymorphy2 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (0.9.1)
# Requirement already satisfied: pymorphy2-dicts in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (2.4.393442.3710985)
# Collecting pymystem3
#   Downloading pymystem3-0.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: click in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: jinja2 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (63.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from spacy) (1.26.1)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: colorama in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\дима титаренко\desktop\python\.venv\lib\site-packages (from jinja2->spacy) (2.1.3)
# Installing collected packages: pymystem3
# Successfully installed pymystem3-0.2.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.stem import SnowballStemmer
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import RegexpTokenizer
from pymystem3 import Mystem
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Дима
# [nltk_data]     Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Дима Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to C:\Users\Дима
# [nltk_data]     Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
wordpunct = nltk.tokenize.WordPunctTokenizer()
print(wordpunct.tokenize(text))
# Out:
# ['1', 'Глава', 'Завещаю', 'в', 'той', 'жизни', 'Вам', 'счастливыми', 'быть', 'И', 'родимой', 'Отчизне', 'С', 'честью', 'дальше', 'служить', '.', 'Горевать', '—', 'горделиво', ',', 'Не', 'клонясь', 'головой', '.', 'Ликовать', '—', 'не', 'хвастливо', 'В', 'час', 'победы', 'самой', '.', 'И', 'беречь', 'ее', 'свято', ',', 'Братья', ',', 'счастье', 'свое', '—', 'В', 'память', 'воина', '-', 'брата', ',', 'Что', 'погиб', 'за', 'нее', '.', 'А', '.', 'Твардовский', 'В', 'двенадцатом', 'часу', 'ночи', 'капитан', 'Новиков', 'проверял', 'посты', '.', 'Он', 'шел', 'по', 'высоте', 'в', 'черной', 'осенней', 'тьме', ',', 'над', 'головой', 'густо', 'шумели', 'вершины', 'сосен', '.', 'Острым', 'северным', 'холодом', 'дуло', 'с', 'Карпат', ',', 'вся', 'высота', 'гудела', ',', 'точно', 'гулко', 'вибрировала', 'под', 'непрерывными', 'ударами', 'воздушных', 'потоков', '.', 'Пахло', 'снегом', '.', 'Редкие', 'ракеты', 'извивались', 'над', 'немецкой', 'передовой', ',', 'сносимые', 'ветром', ',', 'догорали', 'за', 'темным', 'полукружьем', 'соседней', 'высоты', '.', 'В', 'низине', 'справа', ',', 'где', 'лежал', 'польский', 'город', 'Касно', ',', 'беззвучно', 'вспыхивали', ',', 'гасли', 'неопределенные', 'светы', ',', 'как', 'будто', 'задувало', 'их', '.', 'Молчали', 'пулеметы', '.', 'Новиков', 'не', 'видел', 'в', 'темноте', 'ни', 'орудия', ',', 'ни', 'часовых', ',', 'шел', '—', 'руки', 'в', 'карманах', ',', 'ветер', 'неистово', 'трепал', 'полы', 'шинели', ',', '—', 'и', 'странное', 'чувство', 'тоски', ',', 'глухой', 'затерянности', 'в', 'этих', 'мрачных', ',', 'холодных', 'Карпатах', 'охватывало', 'его', '.', 'Приступы', 'тоски', 'появлялись', 'в', 'последнюю', 'неделю', 'не', 'раз', '—', 'и', 'всегда', 'ночью', ',', 'в', 'короткие', 'затишья', ',', 'и', 'объяснялись', 'главным', 'образом', 'тем', ',', 'что', 'четыре', 'дня', 'назад', ',', 'при', 'взятии', 'города', 'Касно', ',', 'батарея', 'Новикова', 'впервые', 'потеряла', 'девять', 'человек', 'сразу', ',', 'в', 'том', 'числе', 'командира', 'взвода', 'управления', ',', 'и', 'Новиков', 'не', 'мог', 'простить', 'себе', 'этого', '.', '—', 'Часовой', '!', '—', 'строго', 'окликнул', 'Новиков', ',', 'останавливаясь', ',', 'по', 'звуку', 'голосов', 'угадывая', 'впереди', 'землянку', 'первого', 'взвода', ',', 'вырытую', 'в', 'скате', 'высоты', '.', 'Ответа', 'не', 'было', '.', '—', 'Часовой', '!', '—', 'повторил', 'он', 'громче', '.', '—', 'А', '?', 'Что', '-', 'то', 'черное', 'завозилось', ',', 'шурша', 'плащ', '-', 'палаткой', ',', 'возле', 'входа', 'в', 'землянку', ',', 'голос', 'из', 'темноты', 'отозвался', 'сдавленно', ':', '—', 'А', '!', 'Кто', 'тут', '?', '—', 'Что', 'это', 'за', '«', 'а', '»?', 'Черт', 'бы', 'драл', '!', '—', 'выругался', 'Новиков', '.', '—', 'В', 'прятки', 'играете', '?', '—', 'Стой', '!', 'Кто', 'идет', '?', '—', 'преувеличенно', 'грозно', 'выкрикнул', 'часовой', 'и', 'щелкнул', 'затвором', 'автомата', '.', '—', 'Проснулись', '?', 'Что', 'там', 'за', 'колготня', 'в', 'землянке', '?', '—', 'спросил', 'Новиков', 'недовольным', 'тоном', '.', '—', 'Что', 'молчите', '?', '—', 'Овчинников', 'чегой', '-', 'то', 'шумит', ',', 'товарищ', 'капитан', ',', '—', 'робко', 'кашлянув', ',', 'забормотал', 'часовой', '.', '—', 'И', 'чего', 'они', 'разоряются', '?', 'Новиков', 'толкнул', 'дверь', 'в', 'землянку', '.', 'Плотный', 'гул', 'голосов', 'колыхался', 'под', 'низкими', 'накатами', '.', 'Среди', 'дыма', 'плавали', 'фиолетовые', 'огни', 'немецких', 'плошек', ',', 'мутно', 'проступали', 'за', 'столом', 'и', 'на', 'нарах', 'красно', '-', 'багровые', 'лица', 'солдат', '—', 'все', 'говорили', 'разом', ',', 'нещадно', 'курили', '.', 'Командир', 'первого', 'взвода', 'лейтенант', 'Овчинников', ',', 'с', 'тонким', ',', 'красивым', ',', 'самолюбивым', 'ртом', ',', 'ударил', 'кулаком', 'по', 'столу', ',', 'покачиваясь', ',', 'встал', ',', 'затем', ',', 'небрежно', 'оттолкнув', 'на', 'бедре', 'тяжелую', 'кобуру', 'пистолета', ',', 'скомандовал', ':', 'сипло', 'и', 'властно', ':', '—', 'Прекратить', 'галдеж ...

# %%
with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
tokenized = nltk.word_tokenize(text)
tokenized
# Out:
# ['1',
#  'Глава',
#  'Завещаю',
#  'в',
#  'той',
#  'жизни',
#  'Вам',
#  'счастливыми',
#  'быть',
#  'И',
#  'родимой',
#  'Отчизне',
#  'С',
#  'честью',
#  'дальше',
#  'служить',
#  '.',
#  'Горевать',
#  '—',
#  'горделиво',
#  ',',
#  'Не',
#  'клонясь',
#  'головой',
#  '.',
#  'Ликовать',
#  '—',
#  'не',
#  'хвастливо',
#  'В',
#  'час',
#  'победы',
#  'самой',
#  '.',
#  'И',
#  'беречь',
#  'ее',
#  'свято',
#  ',',
#  'Братья',
#  ',',
#  'счастье',
#  'свое',
#  '—',
#  'В',
#  'память',
#  'воина-брата',
#  ',',
#  'Что',
#  'погиб',
#  'за',
#  'нее',
#  '.',
#  'А.',
#  'Твардовский',
#  'В',
#  'двенадцатом',
#  'часу',
#  'ночи',
#  'капитан',
#  'Новиков',
#  'проверял',
#  'посты',
#  '.',
#  'Он',
#  'шел',
#  'по',
#  'высоте',
#  'в',
#  'черной',
#  'осенней',
#  'тьме',
#  ',',
#  'над',
#  'головой',
#  'густо',
#  'шумели',
#  'вершины',
#  'сосен',
#  '.',
#  'Острым',
#  'северным',
#  'холодом',
#  'дуло',
#  'с',
#  'Карпат',
#  ',',
#  'вся',
#  'высота',
#  'гудела',
#  ',',
#  'точно',
#  'гулко',
#  'вибрировала',
#  'под',
#  'непрерывными',
#  'ударами',
#  'воздушных',
#  'потоков',
#  '.',
#  'Пахло',
#  'снегом',
#  '.',
#  'Редкие',
#  'ракеты',
#  'извивались',
#  'над',
#  'немецкой',
#  'передовой',
#  ',',
#  'сносимые',
#  'ветром',
#  ',',
#  'догорали',
#  'за',
#  'темным',
#  'полукружьем',
#  'соседней',
#  'высоты',
#  '.',
#  'В',
#  'низине',
#  'справа',
#  ',',
#  'где',
#  'лежал',
#  'польский',
#  'город',
#  'Касно',
#  ',',
#  'беззвучно',
#  'вспыхивали',
#  ',',
#  'гасли',
#  'неопределенные',
#  'светы',
#  ',',
#  'как',
#  'будто',
#  'задувало',
#  'их',
#  '.',
#  'Молчали',
#  'пулеметы',
#  '.',
#  'Новиков',
#  'не',
#  'видел',
#  'в',
#  'темноте',
#  'ни',
#  'орудия',
#  ',',
#  'ни',
#  'часовых',
#  ',',
#  'шел',
#  '—',
#  'руки',
#  'в',
#  'карманах',
#  ',',
#  'ветер',
#  'неистово',
#  'трепал',
#  'полы',
#  'шинели',
#  ',',
#  '—',
#  'и',
#  'странное',
#  'чувство',
#  'тоски',
#  ',',
#  'глухой',
#  'затерянности',
#  'в',
#  'этих',
#  'мрачных',
#  ',',
#  'холодных',
#  'Карпатах',
#  'охватывало',
#  'его',
#  '.',
#  'Приступы',
#  'тоски',
#  'появлялись',
#  'в',
#  'последнюю',
#  'неделю',
#  'не',
#  'раз',
#  '—',
#  'и',
#  'всегда',
#  'ночью',
#  ',',
#  'в',
#  'короткие',
#  'затишья',
#  ',',
#  'и',
#  'объяснялись',
#  'главным',
#  'образом',
#  'тем',
#  ',',
#  'что',
#  'четыре',
#  'дня',
#  'назад',
#  ',',
#  'при',
#  'взятии',
#  'города',
#  'Касно',
#  ',',
#  'батарея',
#  'Новикова',
#  'впервые',
#  'потеряла',
#  'девять',
#  'человек',
#  'сразу',
#  ',',
#  'в',
#  'том',
#  'числе',
#  'командира',
#  'взвода',
#  'управления',
#  ',',
#  'и',
#  'Новиков',
#  'не',
#  'мог',
#  'простить',
#  'себе',
#  'этого',
#  '.',
#  '—',
#  'Часовой',
#  '!',
#  '—',
#  'строго',
#  'окликнул',
#  'Новиков',
#  ',',
#  'останавливаясь',
#  ',',
#  'по',
#  'звуку',
#  'голосов',
#  'угадывая',
#  'впереди',
#  'землянку',
#  'первого',
#  'взвода',
#  ',',
#  'вырытую',
#  'в',
#  'скате',
#  'высоты',
#  '.',
#  'Ответа',
#  'не',
#  'было',
#  '.',
#  '—',
#  'Часовой',
#  '!',
#  '—',
#  'повторил',
#  'он',
#  'громче',
#  '.',
#  '—',
#  'А',
#  '?',
#  'Что-то',
#  'черное',
#  'завозилось',
#  ',',
#  'шурша',
#  'плащ-палаткой',
#  ',',
#  'возле',
#  'входа',
#  'в',
#  'землянку',
#  ',',
#  'голос',
#  'из',
#  'темноты',
#  'отозвался',
#  'сдавленно',
#  ':',
#  '—',
#  'А',
#  '!',
#  'Кто',
#  'тут',
#  '?',
#  '—',
#  'Что',
#  'это',
#  'за',
#  '«',
#  'а',
#  '»',
#  '?',
#  'Черт',
#  'бы',
#  'драл',
#  '!',
#  '—',
#  'выругался',
#  'Новиков',
#  '.',
#  '—',
#  'В',
#  'прятки',
#  'играете',
#  '?',
#  '—',
#  'Стой',
#  '!',
#  'Кто',
#  'идет',
#  '?',
#  '—',
#  'преувеличенно',
#  'грозно',
#  'выкрикнул',
#  'часовой',
#  'и',
#  'щелкнул',
#  'затвором',
#  'автомата',
#  '.',
#  '—',
#  'Проснулись',
#  '?',
#  'Что',
#  'там',
#  'за',
#  'колготня',
#  'в',
#  'землянке',
#  '?',
#  '—',
#  'спросил',
#  'Новиков',
#  'недовольным',
#  'тоном',
#  '.',
#  '—',
#  'Что',
#  'молчите',
#  '?',
#  '—',
#  'Овчинников',
#  'чегой-то',
#  'шумит',
#  ',',
#  'товарищ',
#  'капитан',
#  ',',
#  '—',
#  'робко',
#  'кашлянув',
#  ',',
#  'забормотал',
#  'часовой',
#  '.',
#  '—',
#  'И',
#  'чего',
#  'они',
#  'разоряются',
#  '?',
#  'Новиков',
#  'толкнул',
#  'дверь',
#  'в',
#  'землянку',
#  '.',
#  'Плотный',
#  'гул',
#  'голосов',
#  'колыхался',
#  'под',
#  'низкими',
#  'накатами',
#  '.',
#  'Среди',
#  'дыма',
#  'плавали',
#  'фиолетовые',
#  'огни',
#  'немецких',
#  'плошек',
#  ',',
#  'мутно',
#  'проступали',
#  'за',
#  'столом',
#  'и',
#  'на',
#  'нарах',
#  'красно-багровые',
#  'лица',
#  'солдат',
#  '—',
#  'все',
#  'говорили',
#  'разом',
#  ',',
#  'нещадно',
#  'курили',
#  '.',
#  'Командир',
#  'первого',
#  'взвода',
#  'лейтенант',
#  'Овчинников',
#  ',',
#  'с',
#  'тонким',
#  ',',
#  'красивым',
#  ',',
#  'самолюбивым',
#  'ртом',
#  ',',
#  'ударил',
#  'кулаком',
#  'по',
#  'столу',
#  ',',
#  'покачиваясь',
#  ',',
#  'встал',
#  ',',
#  'затем',
#  ',',
#  'небрежно',
#  'оттолкнув',
#  'на',
#  'бедре',
#  'тяжелую',
#  'кобуру',
#  'пистолета',
#  ',',
#  'скомандовал',
#  ':',
#  'сипло',
#  'и',
#  'властно',
#  ':',
#  '—',
#  'Прекратить',
#  'галдеж',
#  'и',
#  'слушай',
#  'тост',
#  '!',
#  'За',
#  'Леночку',
#  '!',
#  'А',
#  ',',
#  'братцы',
#  '?',
#  'Пить',
#  'всем',
#  '!',
#  'Смутный',
#  'рев',
#  'голосов',
#  'ответил',
#  'ему',
#  'и',
#  'стих',
#  ':',
#  'все',
#  'увидели',
#  'молча',
#  'стоявшего',
#  'в',
#  'дверях',
#  'капитана',
#  'Новикова',
#  '.',
#  'Он',
#  'медленно',
#  'обвел',
#  'взглядом',
#  'лица',
#  'солдат',
#  '.',
#  '—',
#  'Значит',
#  ',',
#  'пыль',
#  'столбом',
#  '?',
#  '—',
#  'произнес',
#  'он',
#  ',',
#  'хмурясь',
#  '.',
#  '—',
#  'И',
#  'санинструктор',
#  'здесь',
#  '?',
#  'То',
#  ',',
#  'что',
#  'веселье',
#  'это',
#  'происходило',
#  'в',
#  'восьмистах',
#  'метрах',
#  'от',
#  'немецкой',
#  'передовой',
#  'и',
#  'люди',
#  ',',
#  'зная',
#  'это',
#  ',',
#  'не',
#  'сдерживали',
#  'себя',
#  ',',
#  'не',
#  'удивило',
#  'Новикова',
#  '.',
#  'Удивило',
#  'то',
#  ',',
#  'что',
#  'здесь',
#  ',',
#  'среди',
#  'едкого',
#  'махорочного',
#  'дыма',
#  ',',
#  'среди',
#  'этого',
#  'нетрезвого',
#  'шума',
#  ',',
#  'сидела',
#  'на',
#  'нарах',
#  'санинструктор',
#  'Лена',
#  'Колоскова',
#  '.',
#  'Сидела',
#  'она',
#  ',',
#  'охватив',
#  'руками',
#  'колени',
#  'и',
#  'покачиваясь',
#  'взад',
#  'и',
#  'вперед',
#  ',',
#  'разговаривала',
#  'с',
#  'умиленно',
#  'расплывшимся',
#  'замковым',
#  'Лягаловым',
#  ',',
#  'смеялась',
#  'тихим',
#  ',',
#  'трудным',
#  ',',
#  'ласковым',
#  'смехом',
#  '.',
#  '«',
#  'Смеется',
#  'каким-то',
#  'жемчужным',
#  'смехом',
#  ',',
#  '—',
#  'не',
#  'без',
#  'раздражения',
#  'подумал',
#  'Новиков',
#  '.',
#  '—',
#  'Она',
#  'пьяна',
#  'или',
#  'хочет',
#  'понравиться',
#  'лейтенанту',
#  'Овчинникову',
#  '.',
#  'Зачем',
#  'ей',
#  'это',
#  '?',
#  '»',
#  'И',
#  ',',
#  'стараясь',
#  'еще',
#  'более',
#  'возбудить',
#  'в',
#  'себе',
#  'неприязнь',
#  'к',
#  'этому',
#  'легкомысленному',
#  'смеху',
#  ',',
#  'он',
#  'быстро',
#  'взглянул',
#  'на',
#  'нее',
#  ',',
#  'потом',
#  'на',
#  'Овчинникова',
#  ',',
#  'спросил',
#  ':',
#  '—',
#  'Что',
#  'у',
#  'вас',
#  'тут',
#  '?',
#  'Свадьба',
#  '?',
#  '..',
#  'Он',
#  'произнес',
#  'это',
#  ',',
#  'должно',
#  'быть',
#  ',',
#  'грубо',
#  '—',
#  'все',
#  'замолчали',
#  '.',
#  'Лена',
#  'вопросительно',
#  'перевела',
#  'на',
#  'него',
#  'взгляд',
#  'и',
#  'вдруг',
#  'легко',
#  'и',
#  'гибко',
#  'спрыгнула',
#  'с',
#  'нар',
#  ',',
#  'взяла',
#  'со',
#  'стола',
#  'чей-то',
#  'стакан',
#  ',',
#  'подошла',
#  'к',
#  'Новикову',
#  ',',
#  'блестя',
#  'яркими',
#  ',',
#  'чуть',
#  'прищуренными',
#  ',',
#  'улыбающимися',
#  'глазами',
#  '.',
#  '—',
#  'Да',
#  ',',
#  'именно',
#  ',',
#  '—',
#  'сказала',
#  ',',
#  'откидывая',
#  'голову',
#  ',',
#  '—',
#  'здесь',
#  'свадьба',
#  '.',
#  'Поздравьте',
#  'меня',
#  'и',
#  'Овчинникова',
#  '.',
#  'Лейтенант',
#  'Овчинников',
#  '!',
#  '—',
#  'приказала',
#  'она',
#  '.',
#  '—',
#  'Дайте',
#  'водки',
#  'капитану',
#  '!',
#  '«',
#  'Что',
#  'это',
#  'с',
#  'ней',
#  '?',
#  '»',
#  'Она',
#  'не',
#  'была',
#  'пьяна',
#  ',',
#  'кажется',
#  '(',
#  'а',
#  'вообще',
#  'не',
#  'поймешь',
#  '!',
#  ')',
#  ',',
#  'и',
#  'дерзко',
#  'глядела',
#  'на',
#  'него',
#  'снизу',
#  'вверх',
#  ',',
#  '—',
#  'тонкая',
#  'нежная',
#  'шея',
#  'окаймлена',
#  'воротом',
#  ',',
#  'узкие',
#  'плечи',
#  ',',
#  'крепкая',
#  'маленькая',
#  'грудь',
#  'обтянута',
#  'суконной',
#  'гимнастеркой',
#  ',',
#  'сжатой',
#  'в',
#  'талии',
#  'широким',
#  'ремнем',
#  '.',
#  'Не',
#  'раз',
#  'ловил',
#  'себя',
#  'Новиков',
#  'на',
#  'том',
#  ',',
#  'что',
#  'его',
#  'непривычно',
#  'смущала',
#  'постоянная',
#  'вызывающая',
#  'смелость',
#  'санинструктора',
#  ',',
#  '—',
#  'он',
#  'почувствовал',
#  ',',
#  'что',
#  'покраснел',
#  'на',
#  'виду',
#  'мгновенно',
#  'притихших',
#  'солдат',
#  ',',
#  'и',
#  ',',
#  'разозленный',
#  'на',
#  'себя',
#  'за',
#  'это',
#  ',',
#  'резко',
#  'сказал',
#  ':',
#  '—',
#  'Вы',
#  'всегда',
#  'неудачно',
#  'шутите',
#  ',',
#  'товарищ',
#  'санинструктор',
#  '!',
#  '—',
#  'И',
#  ',',
#  'повернувшись',
#  'к',
#  'лейтенанту',
#  'Овчинникову',
#  ',',
#  'договорил',
#  'тоном',
#  'приказа',
#  ':',
#  '—',
#  'Прекратить',
#  '!',
#  'Что',
#  'это',
#  'за',
#  'веселье',
#  '?',
#  'С',
#  'какой',
#  'радости',
#  '?',
#  'Всем',
#  'отдыхать',
#  '!',
#  'Лейтенант',
#  'Овчинников',
#  ',',
#  'самолюбиво',
#  'сузив',
#  'светло',
#  'трезвые',
#  'глаза',
#  'на',
#  'недопитый',
#  'стакан',
#  ',',
#  'спросил',
#  ':',
#  '—',
#  'За',
#  'что',
#  'вы',
#  ',',
#  'товарищ',
#  'капитан',
#  '?',
#  'Мой',
#  'день',
#  'рождения',
#  '.',
#  'Не',
#  'признаете',
#  '?',
#  'Двадцать',
#  'шесть',
#  'стукнуло',
#  '.',
#  'Лягалов',
#  ',',
#  'налей',
#  'комбату',
#  '!',
#  'Ломанем',
#  ',',
#  'товарищ',
#  'капитан',
#  '?',
#  '..',
#  'Чтоб',
#  'пыль',
#  'на',
#  'всю',
#  'Европу',
#  ',',
#  'а',
#  '?',
#  'Замковый',
#  'Лягалов',
#  ',',
#  'солдат',
#  'пожилой',
#  ',',
#  'некрасивый',
#  ',',
#  'низкорослый',
#  ',',
#  'обросший',
#  'золотистой',
#  'щетинкой',
#  'на',
#  'худых',
#  'щеках',
#  ',',
#  'помигал',
#  'конфузливо',
#  'на',
#  'Овчинникова',
#  ',',
#  'на',
#  'комбата',
#  ',',
#  'неуверенно',
#  'налил',
#  'из',
#  'фляги',
#  'полную',
#  'кружку',
#  ',',
#  'протянул',
#  'Новикову',
#  ':',
#  '—',
#  'Товарищ',
#  'капитан',
#  ',',
#  'не',
#  'побрезгуйте',
#  ',',
#  'стадо',
#  'быть…',
#  'Чистая-а',
#  '!',
#  'Считался',
#  'Лягалов',
#  'непьющим',
#  ',',
#  'и',
#  'то',
#  ',',
#  'что',
#  'он',
#  'пил',
#  'сейчас',
#  'и',
#  'протягивал',
#  'кружку',
#  ',',
#  'вконец',
#  'испортило',
#  'настроение',
#  'Новикову',
#  '.',
#  'Он',
#  'оттолкнул',
#  'руку',
#  'Лягалова',
#  ',',
#  'криво',
#  'усмехнулся',
#  ':',
#  '—',
#  'Поздравляю',
#  '.',
#  '—',
#  'И',
#  ',',
#  'ссутулившись',
#  ',',
#  'шагнул',
#  'к',
#  'двери',
#  ...]

# %%
tagged = nltk.pos_tag(tokenized)
tagged
# Out:
# [('1', 'CD'),
#  ('Глава', 'JJ'),
#  ('Завещаю', 'NNP'),
#  ('в', 'NNP'),
#  ('той', 'NNP'),
#  ('жизни', 'NNP'),
#  ('Вам', 'NNP'),
#  ('счастливыми', 'NNP'),
#  ('быть', 'NNP'),
#  ('И', 'NNP'),
#  ('родимой', 'NNP'),
#  ('Отчизне', 'NNP'),
#  ('С', 'NNP'),
#  ('честью', 'NNP'),
#  ('дальше', 'NNP'),
#  ('служить', 'NNP'),
#  ('.', '.'),
#  ('Горевать', 'VB'),
#  ('—', 'JJ'),
#  ('горделиво', 'NNP'),
#  (',', ','),
#  ('Не', 'NNP'),
#  ('клонясь', 'NNP'),
#  ('головой', 'NNP'),
#  ('.', '.'),
#  ('Ликовать', 'VB'),
#  ('—', 'JJ'),
#  ('не', 'NNP'),
#  ('хвастливо', 'NNP'),
#  ('В', 'NNP'),
#  ('час', 'NNP'),
#  ('победы', 'NNP'),
#  ('самой', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('беречь', 'JJ'),
#  ('ее', 'NNP'),
#  ('свято', 'NNP'),
#  (',', ','),
#  ('Братья', 'NNP'),
#  (',', ','),
#  ('счастье', 'NNP'),
#  ('свое', 'NNP'),
#  ('—', 'NNP'),
#  ('В', 'NNP'),
#  ('память', 'NNP'),
#  ('воина-брата', 'NNP'),
#  (',', ','),
#  ('Что', 'NNP'),
#  ('погиб', 'NNP'),
#  ('за', 'NNP'),
#  ('нее', 'NNP'),
#  ('.', '.'),
#  ('А.', 'VB'),
#  ('Твардовский', 'JJ'),
#  ('В', 'NNP'),
#  ('двенадцатом', 'NNP'),
#  ('часу', 'NNP'),
#  ('ночи', 'NNP'),
#  ('капитан', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('проверял', 'NNP'),
#  ('посты', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('шел', 'JJ'),
#  ('по', 'NNP'),
#  ('высоте', 'NNP'),
#  ('в', 'NNP'),
#  ('черной', 'NNP'),
#  ('осенней', 'NNP'),
#  ('тьме', 'NNP'),
#  (',', ','),
#  ('над', 'NNP'),
#  ('головой', 'NNP'),
#  ('густо', 'NNP'),
#  ('шумели', 'NNP'),
#  ('вершины', 'NNP'),
#  ('сосен', 'NNP'),
#  ('.', '.'),
#  ('Острым', 'VB'),
#  ('северным', 'JJ'),
#  ('холодом', 'NNP'),
#  ('дуло', 'NNP'),
#  ('с', 'NNP'),
#  ('Карпат', 'NNP'),
#  (',', ','),
#  ('вся', 'NNP'),
#  ('высота', 'NNP'),
#  ('гудела', 'NNP'),
#  (',', ','),
#  ('точно', 'NNP'),
#  ('гулко', 'NNP'),
#  ('вибрировала', 'NNP'),
#  ('под', 'NNP'),
#  ('непрерывными', 'NNP'),
#  ('ударами', 'NNP'),
#  ('воздушных', 'NNP'),
#  ('потоков', 'NNP'),
#  ('.', '.'),
#  ('Пахло', 'NN'),
#  ('снегом', 'NN'),
#  ('.', '.'),
#  ('Редкие', 'CC'),
#  ('ракеты', 'JJ'),
#  ('извивались', 'NNP'),
#  ('над', 'NNP'),
#  ('немецкой', 'NNP'),
#  ('передовой', 'NNP'),
#  (',', ','),
#  ('сносимые', 'NNP'),
#  ('ветром', 'NNP'),
#  (',', ','),
#  ('догорали', 'NNP'),
#  ('за', 'NNP'),
#  ('темным', 'NNP'),
#  ('полукружьем', 'NNP'),
#  ('соседней', 'NNP'),
#  ('высоты', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('низине', 'JJ'),
#  ('справа', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('лежал', 'NNP'),
#  ('польский', 'NNP'),
#  ('город', 'NNP'),
#  ('Касно', 'NNP'),
#  (',', ','),
#  ('беззвучно', 'NNP'),
#  ('вспыхивали', 'NNP'),
#  (',', ','),
#  ('гасли', 'NNP'),
#  ('неопределенные', 'NNP'),
#  ('светы', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('будто', 'NNP'),
#  ('задувало', 'NNP'),
#  ('их', 'NNP'),
#  ('.', '.'),
#  ('Молчали', 'NN'),
#  ('пулеметы', 'NN'),
#  ('.', '.'),
#  ('Новиков', 'CC'),
#  ('не', 'JJ'),
#  ('видел', 'NNP'),
#  ('в', 'NNP'),
#  ('темноте', 'NNP'),
#  ('ни', 'NNP'),
#  ('орудия', 'NNP'),
#  (',', ','),
#  ('ни', 'NNP'),
#  ('часовых', 'NNP'),
#  (',', ','),
#  ('шел', 'NNP'),
#  ('—', 'NNP'),
#  ('руки', 'NNP'),
#  ('в', 'NNP'),
#  ('карманах', 'NNP'),
#  (',', ','),
#  ('ветер', 'NNP'),
#  ('неистово', 'NNP'),
#  ('трепал', 'NNP'),
#  ('полы', 'NNP'),
#  ('шинели', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('и', 'NNP'),
#  ('странное', 'NNP'),
#  ('чувство', 'NNP'),
#  ('тоски', 'NNP'),
#  (',', ','),
#  ('глухой', 'NNP'),
#  ('затерянности', 'NNP'),
#  ('в', 'NNP'),
#  ('этих', 'NNP'),
#  ('мрачных', 'NNP'),
#  (',', ','),
#  ('холодных', 'NNP'),
#  ('Карпатах', 'NNP'),
#  ('охватывало', 'NNP'),
#  ('его', 'NNP'),
#  ('.', '.'),
#  ('Приступы', 'VB'),
#  ('тоски', 'JJ'),
#  ('появлялись', 'NNP'),
#  ('в', 'NNP'),
#  ('последнюю', 'NNP'),
#  ('неделю', 'NNP'),
#  ('не', 'NNP'),
#  ('раз', 'NNP'),
#  ('—', 'NNP'),
#  ('и', 'NNP'),
#  ('всегда', 'NNP'),
#  ('ночью', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('короткие', 'NNP'),
#  ('затишья', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('объяснялись', 'NNP'),
#  ('главным', 'NNP'),
#  ('образом', 'NNP'),
#  ('тем', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('четыре', 'NNP'),
#  ('дня', 'NNP'),
#  ('назад', 'NNP'),
#  (',', ','),
#  ('при', 'NNP'),
#  ('взятии', 'NNP'),
#  ('города', 'NNP'),
#  ('Касно', 'NNP'),
#  (',', ','),
#  ('батарея', 'NNP'),
#  ('Новикова', 'NNP'),
#  ('впервые', 'NNP'),
#  ('потеряла', 'NNP'),
#  ('девять', 'NNP'),
#  ('человек', 'NNP'),
#  ('сразу', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('том', 'NNP'),
#  ('числе', 'NNP'),
#  ('командира', 'NNP'),
#  ('взвода', 'NNP'),
#  ('управления', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('не', 'NNP'),
#  ('мог', 'NNP'),
#  ('простить', 'NNP'),
#  ('себе', 'NNP'),
#  ('этого', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Часовой', 'JJ'),
#  ('!', '.'),
#  ('—', 'JJ'),
#  ('строго', 'JJ'),
#  ('окликнул', 'NN'),
#  ('Новиков', 'NN'),
#  (',', ','),
#  ('останавливаясь', 'NNP'),
#  (',', ','),
#  ('по', 'NNP'),
#  ('звуку', 'NNP'),
#  ('голосов', 'NNP'),
#  ('угадывая', 'NNP'),
#  ('впереди', 'NNP'),
#  ('землянку', 'NNP'),
#  ('первого', 'NNP'),
#  ('взвода', 'NNP'),
#  (',', ','),
#  ('вырытую', 'NNP'),
#  ('в', 'NNP'),
#  ('скате', 'NNP'),
#  ('высоты', 'NNP'),
#  ('.', '.'),
#  ('Ответа', 'VB'),
#  ('не', 'JJ'),
#  ('было', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Часовой', 'JJ'),
#  ('!', '.'),
#  ('—', 'JJ'),
#  ('повторил', 'JJ'),
#  ('он', 'NN'),
#  ('громче', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('А', 'JJ'),
#  ('?', '.'),
#  ('Что-то', 'JJ'),
#  ('черное', 'NN'),
#  ('завозилось', 'NN'),
#  (',', ','),
#  ('шурша', 'JJ'),
#  ('плащ-палаткой', 'NN'),
#  (',', ','),
#  ('возле', 'NNP'),
#  ('входа', 'NNP'),
#  ('в', 'NNP'),
#  ('землянку', 'NNP'),
#  (',', ','),
#  ('голос', 'NNP'),
#  ('из', 'NNP'),
#  ('темноты', 'NNP'),
#  ('отозвался', 'NNP'),
#  ('сдавленно', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('А', 'NN'),
#  ('!', '.'),
#  ('Кто', 'NN'),
#  ('тут', 'NN'),
#  ('?', '.'),
#  ('—', 'JJ'),
#  ('Что', 'NN'),
#  ('это', 'NNP'),
#  ('за', 'NNP'),
#  ('«', 'NNP'),
#  ('а', 'NNP'),
#  ('»', 'NNP'),
#  ('?', '.'),
#  ('Черт', 'NNP'),
#  ('бы', 'NNP'),
#  ('драл', 'NN'),
#  ('!', '.'),
#  ('—', 'JJ'),
#  ('выругался', 'JJ'),
#  ('Новиков', 'NN'),
#  ('.', '.'),
#  ('—', 'CC'),
#  ('В', 'JJ'),
#  ('прятки', 'NN'),
#  ('играете', 'NN'),
#  ('?', '.'),
#  ('—', 'JJ'),
#  ('Стой', 'NN'),
#  ('!', '.'),
#  ('Кто', 'NN'),
#  ('идет', 'NN'),
#  ('?', '.'),
#  ('—', 'JJ'),
#  ('преувеличенно', 'NN'),
#  ('грозно', 'NNP'),
#  ('выкрикнул', 'NNP'),
#  ('часовой', 'NNP'),
#  ('и', 'NNP'),
#  ('щелкнул', 'NNP'),
#  ('затвором', 'NNP'),
#  ('автомата', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Проснулись', 'NN'),
#  ('?', '.'),
#  ('Что', 'JJ'),
#  ('там', 'NN'),
#  ('за', 'NNP'),
#  ('колготня', 'NNP'),
#  ('в', 'NNP'),
#  ('землянке', 'NNP'),
#  ('?', '.'),
#  ('—', 'NNP'),
#  ('спросил', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('недовольным', 'NNP'),
#  ('тоном', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Что', 'JJ'),
#  ('молчите', 'NNP'),
#  ('?', '.'),
#  ('—', 'JJ'),
#  ('Овчинников', 'JJ'),
#  ('чегой-то', 'JJ'),
#  ('шумит', 'NN'),
#  (',', ','),
#  ('товарищ', 'NNP'),
#  ('капитан', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('робко', 'NNP'),
#  ('кашлянув', 'NNP'),
#  (',', ','),
#  ('забормотал', 'NNP'),
#  ('часовой', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('И', 'JJ'),
#  ('чего', 'NNP'),
#  ('они', 'NNP'),
#  ('разоряются', 'NNP'),
#  ('?', '.'),
#  ('Новиков', 'NNP'),
#  ('толкнул', 'NNP'),
#  ('дверь', 'NNP'),
#  ('в', 'NNP'),
#  ('землянку', 'NNP'),
#  ('.', '.'),
#  ('Плотный', 'VB'),
#  ('гул', 'JJ'),
#  ('голосов', 'NNP'),
#  ('колыхался', 'NNP'),
#  ('под', 'NNP'),
#  ('низкими', 'NNP'),
#  ('накатами', 'NNP'),
#  ('.', '.'),
#  ('Среди', 'VB'),
#  ('дыма', 'JJ'),
#  ('плавали', 'NNP'),
#  ('фиолетовые', 'NNP'),
#  ('огни', 'NNP'),
#  ('немецких', 'NNP'),
#  ('плошек', 'NNP'),
#  (',', ','),
#  ('мутно', 'NNP'),
#  ('проступали', 'NNP'),
#  ('за', 'NNP'),
#  ('столом', 'NNP'),
#  ('и', 'NNP'),
#  ('на', 'NNP'),
#  ('нарах', 'NNP'),
#  ('красно-багровые', 'JJ'),
#  ('лица', 'NNP'),
#  ('солдат', 'NNP'),
#  ('—', 'NNP'),
#  ('все', 'NNP'),
#  ('говорили', 'NNP'),
#  ('разом', 'NNP'),
#  (',', ','),
#  ('нещадно', 'NNP'),
#  ('курили', 'NNP'),
#  ('.', '.'),
#  ('Командир', 'VB'),
#  ('первого', 'JJ'),
#  ('взвода', 'NNP'),
#  ('лейтенант', 'NNP'),
#  ('Овчинников', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('тонким', 'NNP'),
#  (',', ','),
#  ('красивым', 'NNP'),
#  (',', ','),
#  ('самолюбивым', 'NNP'),
#  ('ртом', 'NNP'),
#  (',', ','),
#  ('ударил', 'NNP'),
#  ('кулаком', 'NNP'),
#  ('по', 'NNP'),
#  ('столу', 'NNP'),
#  (',', ','),
#  ('покачиваясь', 'NNP'),
#  (',', ','),
#  ('встал', 'NNP'),
#  (',', ','),
#  ('затем', 'NNP'),
#  (',', ','),
#  ('небрежно', 'NNP'),
#  ('оттолкнув', 'NNP'),
#  ('на', 'NNP'),
#  ('бедре', 'NNP'),
#  ('тяжелую', 'NNP'),
#  ('кобуру', 'NNP'),
#  ('пистолета', 'NNP'),
#  (',', ','),
#  ('скомандовал', 'NN'),
#  (':', ':'),
#  ('сипло', 'JJ'),
#  ('и', 'JJ'),
#  ('властно', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Прекратить', 'NNP'),
#  ('галдеж', 'NNP'),
#  ('и', 'NNP'),
#  ('слушай', 'NNP'),
#  ('тост', 'NN'),
#  ('!', '.'),
#  ('За', 'JJ'),
#  ('Леночку', 'NN'),
#  ('!', '.'),
#  ('А', 'NN'),
#  (',', ','),
#  ('братцы', 'VB'),
#  ('?', '.'),
#  ('Пить', 'JJ'),
#  ('всем', 'NN'),
#  ('!', '.'),
#  ('Смутный', 'JJ'),
#  ('рев', 'JJ'),
#  ('голосов', 'NN'),
#  ('ответил', 'NNP'),
#  ('ему', 'NNP'),
#  ('и', 'NNP'),
#  ('стих', 'NN'),
#  (':', ':'),
#  ('все', 'JJ'),
#  ('увидели', 'NNP'),
#  ('молча', 'NNP'),
#  ('стоявшего', 'NNP'),
#  ('в', 'NNP'),
#  ('дверях', 'NNP'),
#  ('капитана', 'NNP'),
#  ('Новикова', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('медленно', 'JJ'),
#  ('обвел', 'NNP'),
#  ('взглядом', 'NNP'),
#  ('лица', 'NNP'),
#  ('солдат', 'NNP'),
#  ('.', '.'),
#  ('—', 'NN'),
#  ('Значит', 'NN'),
#  (',', ','),
#  ('пыль', 'NNP'),
#  ('столбом', 'NNP'),
#  ('?', '.'),
#  ('—', 'NNP'),
#  ('произнес', 'NNP'),
#  ('он', 'NNP'),
#  (',', ','),
#  ('хмурясь', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('И', 'JJ'),
#  ('санинструктор', 'NNP'),
#  ('здесь', 'NNP'),
#  ('?', '.'),
#  ('То', 'NN'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('веселье', 'NNP'),
#  ('это', 'NNP'),
#  ('происходило', 'NNP'),
#  ('в', 'NNP'),
#  ('восьмистах', 'NNP'),
#  ('метрах', 'NNP'),
#  ('от', 'NNP'),
#  ('немецкой', 'NNP'),
#  ('передовой', 'NNP'),
#  ('и', 'NNP'),
#  ('люди', 'NNP'),
#  (',', ','),
#  ('зная', 'NNP'),
#  ('это', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('сдерживали', 'NNP'),
#  ('себя', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('удивило', 'NNP'),
#  ('Новикова', 'NNP'),
#  ('.', '.'),
#  ('Удивило', 'NN'),
#  ('то', 'NN'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('здесь', 'NNP'),
#  (',', ','),
#  ('среди', 'NNP'),
#  ('едкого', 'NNP'),
#  ('махорочного', 'NNP'),
#  ('дыма', 'NNP'),
#  (',', ','),
#  ('среди', 'NNP'),
#  ('этого', 'NNP'),
#  ('нетрезвого', 'NNP'),
#  ('шума', 'NNP'),
#  (',', ','),
#  ('сидела', 'NNP'),
#  ('на', 'NNP'),
#  ('нарах', 'NNP'),
#  ('санинструктор', 'NNP'),
#  ('Лена', 'NNP'),
#  ('Колоскова', 'NNP'),
#  ('.', '.'),
#  ('Сидела', 'NN'),
#  ('она', 'NN'),
#  (',', ','),
#  ('охватив', 'NNP'),
#  ('руками', 'NNP'),
#  ('колени', 'NNP'),
#  ('и', 'NNP'),
#  ('покачиваясь', 'NNP'),
#  ('взад', 'NNP'),
#  ('и', 'NNP'),
#  ('вперед', 'NNP'),
#  (',', ','),
#  ('разговаривала', 'NNP'),
#  ('с', 'NNP'),
#  ('умиленно', 'NNP'),
#  ('расплывшимся', 'NNP'),
#  ('замковым', 'NNP'),
#  ('Лягаловым', 'NNP'),
#  (',', ','),
#  ('смеялась', 'NNP'),
#  ('тихим', 'NNP'),
#  (',', ','),
#  ('трудным', 'NNP'),
#  (',', ','),
#  ('ласковым', 'NNP'),
#  ('смехом', 'NNP'),
#  ('.', '.'),
#  ('«', 'VB'),
#  ('Смеется', 'JJ'),
#  ('каким-то', 'JJ'),
#  ('жемчужным', 'NN'),
#  ('смехом', 'NN'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('не', 'NNP'),
#  ('без', 'NNP'),
#  ('раздражения', 'NNP'),
#  ('подумал', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Она', 'JJ'),
#  ('пьяна', 'NNP'),
#  ('или', 'NNP'),
#  ('хочет', 'NNP'),
#  ('понравиться', 'NNP'),
#  ('лейтенанту', 'NNP'),
#  ('Овчинникову', 'NNP'),
#  ('.', '.'),
#  ('Зачем', 'VB'),
#  ('ей', 'JJ'),
#  ('это', 'NNP'),
#  ('?', '.'),
#  ('»', 'NNP'),
#  ('И', 'NNP'),
#  (',', ','),
#  ('стараясь', 'NNP'),
#  ('еще', 'NNP'),
#  ('более', 'NNP'),
#  ('возбудить', 'NNP'),
#  ('в', 'NNP'),
#  ('себе', 'NNP'),
#  ('неприязнь', 'NNP'),
#  ('к', 'NNP'),
#  ('этому', 'NNP'),
#  ('легкомысленному', 'NNP'),
#  ('смеху', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('быстро', 'NNP'),
#  ('взглянул', 'NNP'),
#  ('на', 'NNP'),
#  ('нее', 'NNP'),
#  (',', ','),
#  ('потом', 'NNP'),
#  ('на', 'NNP'),
#  ('Овчинникова', 'NNP'),
#  (',', ','),
#  ('спросил', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Что', 'NNP'),
#  ('у', 'NNP'),
#  ('вас', 'NNP'),
#  ('тут', 'NNP'),
#  ('?', '.'),
#  ('Свадьба', 'NN'),
#  ('?', '.'),
#  ('..', 'JJ'),
#  ('Он', 'NN'),
#  ('произнес', 'NNP'),
#  ('это', 'NNP'),
#  (',', ','),
#  ('должно', 'NNP'),
#  ('быть', 'NNP'),
#  (',', ','),
#  ('грубо', 'NNP'),
#  ('—', 'NNP'),
#  ('все', 'NNP'),
#  ('замолчали', 'NNP'),
#  ('.', '.'),
#  ('Лена', 'VB'),
#  ('вопросительно', 'JJ'),
#  ('перевела', 'NNP'),
#  ('на', 'NNP'),
#  ('него', 'NNP'),
#  ('взгляд', 'NNP'),
#  ('и', 'NNP'),
#  ('вдруг', 'NNP'),
#  ('легко', 'NNP'),
#  ('и', 'NNP'),
#  ('гибко', 'NNP'),
#  ('спрыгнула', 'NNP'),
#  ('с', 'NNP'),
#  ('нар', 'NNP'),
#  (',', ','),
#  ('взяла', 'NNP'),
#  ('со', 'NNP'),
#  ('стола', 'NNP'),
#  ('чей-то', 'JJ'),
#  ('стакан', 'NNP'),
#  (',', ','),
#  ('подошла', 'NNP'),
#  ('к', 'NNP'),
#  ('Новикову', 'NNP'),
#  (',', ','),
#  ('блестя', 'NNP'),
#  ('яркими', 'NNP'),
#  (',', ','),
#  ('чуть', 'NNP'),
#  ('прищуренными', 'NNP'),
#  (',', ','),
#  ('улыбающимися', 'NNP'),
#  ('глазами', 'NNP'),
#  ('.', '.'),
#  ('—', 'NN'),
#  ('Да', 'NN'),
#  (',', ','),
#  ('именно', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('сказала', 'NNP'),
#  (',', ','),
#  ('откидывая', 'NNP'),
#  ('голову', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('здесь', 'NNP'),
#  ('свадьба', 'NNP'),
#  ('.', '.'),
#  ('Поздравьте', 'VB'),
#  ('меня', 'JJ'),
#  ('и', 'NNP'),
#  ('Овчинникова', 'NNP'),
#  ('.', '.'),
#  ('Лейтенант', 'VB'),
#  ('Овчинников', 'JJ'),
#  ('!', '.'),
#  ('—', 'JJ'),
#  ('приказала', 'JJ'),
#  ('она', 'NN'),
#  ('.', '.'),
#  ('—', 'CC'),
#  ('Дайте', 'JJ'),
#  ('водки', 'NNP'),
#  ('капитану', 'NN'),
#  ('!', '.'),
#  ('«', 'JJ'),
#  ('Что', 'JJ'),
#  ('это', 'NN'),
#  ('с', 'NNP'),
#  ('ней', 'NNP'),
#  ('?', '.'),
#  ('»', 'NNP'),
#  ('Она', 'NNP'),
#  ('не', 'NNP'),
#  ('была', 'NNP'),
#  ('пьяна', 'NNP'),
#  (',', ','),
#  ('кажется', 'NNP'),
#  ('(', '('),
#  ('а', 'NNP'),
#  ('вообще', 'NNP'),
#  ('не', 'NNP'),
#  ('поймешь', 'NNP'),
#  ('!', '.'),
#  (')', ')'),
#  (',', ','),
#  ('и', 'JJ'),
#  ('дерзко', 'NNP'),
#  ('глядела', 'NNP'),
#  ('на', 'NNP'),
#  ('него', 'NNP'),
#  ('снизу', 'NNP'),
#  ('вверх', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('тонкая', 'NNP'),
#  ('нежная', 'NNP'),
#  ('шея', 'NNP'),
#  ('окаймлена', 'NNP'),
#  ('воротом', 'NNP'),
#  (',', ','),
#  ('узкие', 'NNP'),
#  ('плечи', 'NNP'),
#  (',', ','),
#  ('крепкая', 'NNP'),
#  ('маленькая', 'NNP'),
#  ('грудь', 'NNP'),
#  ('обтянута', 'NNP'),
#  ('суконной', 'NNP'),
#  ('гимнастеркой', 'NNP'),
#  (',', ','),
#  ('сжатой', 'NNP'),
#  ('в', 'NNP'),
#  ('талии', 'NNP'),
#  ('широким', 'NNP'),
#  ('ремнем', 'NNP'),
#  ('.', '.'),
#  ('Не', 'VB'),
#  ('раз', 'JJ'),
#  ('ловил', 'NNP'),
#  ('себя', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('на', 'NNP'),
#  ('том', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('его', 'NNP'),
#  ('непривычно', 'NNP'),
#  ('смущала', 'NNP'),
#  ('постоянная', 'NNP'),
#  ('вызывающая', 'NNP'),
#  ('смелость', 'NNP'),
#  ('санинструктора', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('он', 'NNP'),
#  ('почувствовал', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('покраснел', 'NNP'),
#  ('на', 'NNP'),
#  ('виду', 'NNP'),
#  ('мгновенно', 'NNP'),
#  ('притихших', 'NNP'),
#  ('солдат', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('разозленный', 'NNP'),
#  ('на', 'NNP'),
#  ('себя', 'NNP'),
#  ('за', 'NNP'),
#  ('это', 'NNP'),
#  (',', ','),
#  ('резко', 'NNP'),
#  ('сказал', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Вы', 'NNP'),
#  ('всегда', 'NNP'),
#  ('неудачно', 'NNP'),
#  ('шутите', 'NNP'),
#  (',', ','),
#  ('товарищ', 'NNP'),
#  ('санинструктор', 'NN'),
#  ('!', '.'),
#  ('—', 'NN'),
#  ('И', 'NN'),
#  (',', ','),
#  ('повернувшись', 'NNP'),
#  ('к', 'NNP'),
#  ('лейтенанту', 'NNP'),
#  ('Овчинникову', 'NNP'),
#  (',', ','),
#  ('договорил', 'NNP'),
#  ('тоном', 'NNP'),
#  ('приказа', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Прекратить', 'NN'),
#  ('!', '.'),
#  ('Что', 'JJ'),
#  ('это', 'JJ'),
#  ('за', 'NN'),
#  ('веселье', 'NN'),
#  ('?', '.'),
#  ('С', 'JJ'),
#  ('какой', 'NN'),
#  ('радости', 'NN'),
#  ('?', '.'),
#  ('Всем', 'JJ'),
#  ('отдыхать', 'NN'),
#  ('!', '.'),
#  ('Лейтенант', 'NN'),
#  ('Овчинников', 'NN'),
#  (',', ','),
#  ('самолюбиво', 'NNP'),
#  ('сузив', 'NNP'),
#  ('светло', 'NNP'),
#  ('трезвые', 'NNP'),
#  ('глаза', 'NNP'),
#  ('на', 'NNP'),
#  ('недопитый', 'NNP'),
#  ('стакан', 'NNP'),
#  (',', ','),
#  ('спросил', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('За', 'NNP'),
#  ('что', 'NNP'),
#  ('вы', 'NNP'),
#  (',', ','),
#  ('товарищ', 'NNP'),
#  ('капитан', 'NNP'),
#  ('?', '.'),
#  ('Мой', 'NNP'),
#  ('день', 'NNP'),
#  ('рождения', 'NNP'),
#  ('.', '.'),
#  ('Не', 'VB'),
#  ('признаете', 'NN'),
#  ('?', '.'),
#  ('Двадцать', 'JJ'),
#  ('шесть', 'NN'),
#  ('стукнуло', 'NNP'),
#  ('.', '.'),
#  ('Лягалов', 'NN'),
#  (',', ','),
#  ('налей', 'NNP'),
#  ('комбату', 'NN'),
#  ('!', '.'),
#  ('Ломанем', 'NN'),
#  (',', ','),
#  ('товарищ', 'NNP'),
#  ('капитан', 'NNP'),
#  ('?', '.'),
#  ('..', 'NNP'),
#  ('Чтоб', 'NNP'),
#  ('пыль', 'NNP'),
#  ('на', 'NNP'),
#  ('всю', 'NNP'),
#  ('Европу', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('?', '.'),
#  ('Замковый', 'NNP'),
#  ('Лягалов', 'NNP'),
#  (',', ','),
#  ('солдат', 'NNP'),
#  ('пожилой', 'NNP'),
#  (',', ','),
#  ('некрасивый', 'NNP'),
#  (',', ','),
#  ('низкорослый', 'NNP'),
#  (',', ','),
#  ('обросший', 'NNP'),
#  ('золотистой', 'NNP'),
#  ('щетинкой', 'NNP'),
#  ('на', 'NNP'),
#  ('худых', 'NNP'),
#  ('щеках', 'NNP'),
#  (',', ','),
#  ('помигал', 'NNP'),
#  ('конфузливо', 'NNP'),
#  ('на', 'NNP'),
#  ('Овчинникова', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('комбата', 'NNP'),
#  (',', ','),
#  ('неуверенно', 'NNP'),
#  ('налил', 'NNP'),
#  ('из', 'NNP'),
#  ('фляги', 'NNP'),
#  ('полную', 'NNP'),
#  ('кружку', 'NNP'),
#  (',', ','),
#  ('протянул', 'NNP'),
#  ('Новикову', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Товарищ', 'NNP'),
#  ('капитан', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('побрезгуйте', 'NNP'),
#  (',', ','),
#  ('стадо', 'NNP'),
#  ('быть…', 'NNP'),
#  ('Чистая-а', 'JJ'),
#  ('!', '.'),
#  ('Считался', 'JJ'),
#  ('Лягалов', 'NNP'),
#  ('непьющим', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('то', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('он', 'NNP'),
#  ('пил', 'NNP'),
#  ('сейчас', 'NNP'),
#  ('и', 'NNP'),
#  ('протягивал', 'NNP'),
#  ('кружку', 'NNP'),
#  (',', ','),
#  ('вконец', 'NNP'),
#  ('испортило', 'NNP'),
#  ('настроение', 'NNP'),
#  ('Новикову', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('оттолкнул', 'JJ'),
#  ('руку', 'NNP'),
#  ('Лягалова', 'NNP'),
#  (',', ','),
#  ('криво', 'NNP'),
#  ('усмехнулся', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Поздравляю', 'NN'),
#  ('.', '.'),
#  ('—', 'JJ'),
#  ('И', 'NN'),
#  (',', ','),
#  ('ссутулившись', 'NNP'),
#  (',', ','),
#  ('шагнул', 'NNP'),
#  ('к', 'NNP'),
#  ('двери', 'NNP'),
#  ...]

# %%
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
lemmatized = [lemm.lemmatize(word) for word in tokenized]
lemmatized
# Out:
# ['1',
#  'Глава',
#  'Завещаю',
#  'в',
#  'той',
#  'жизни',
#  'Вам',
#  'счастливыми',
#  'быть',
#  'И',
#  'родимой',
#  'Отчизне',
#  'С',
#  'честью',
#  'дальше',
#  'служить',
#  '.',
#  'Горевать',
#  '—',
#  'горделиво',
#  ',',
#  'Не',
#  'клонясь',
#  'головой',
#  '.',
#  'Ликовать',
#  '—',
#  'не',
#  'хвастливо',
#  'В',
#  'час',
#  'победы',
#  'самой',
#  '.',
#  'И',
#  'беречь',
#  'ее',
#  'свято',
#  ',',
#  'Братья',
#  ',',
#  'счастье',
#  'свое',
#  '—',
#  'В',
#  'память',
#  'воина-брата',
#  ',',
#  'Что',
#  'погиб',
#  'за',
#  'нее',
#  '.',
#  'А.',
#  'Твардовский',
#  'В',
#  'двенадцатом',
#  'часу',
#  'ночи',
#  'капитан',
#  'Новиков',
#  'проверял',
#  'посты',
#  '.',
#  'Он',
#  'шел',
#  'по',
#  'высоте',
#  'в',
#  'черной',
#  'осенней',
#  'тьме',
#  ',',
#  'над',
#  'головой',
#  'густо',
#  'шумели',
#  'вершины',
#  'сосен',
#  '.',
#  'Острым',
#  'северным',
#  'холодом',
#  'дуло',
#  'с',
#  'Карпат',
#  ',',
#  'вся',
#  'высота',
#  'гудела',
#  ',',
#  'точно',
#  'гулко',
#  'вибрировала',
#  'под',
#  'непрерывными',
#  'ударами',
#  'воздушных',
#  'потоков',
#  '.',
#  'Пахло',
#  'снегом',
#  '.',
#  'Редкие',
#  'ракеты',
#  'извивались',
#  'над',
#  'немецкой',
#  'передовой',
#  ',',
#  'сносимые',
#  'ветром',
#  ',',
#  'догорали',
#  'за',
#  'темным',
#  'полукружьем',
#  'соседней',
#  'высоты',
#  '.',
#  'В',
#  'низине',
#  'справа',
#  ',',
#  'где',
#  'лежал',
#  'польский',
#  'город',
#  'Касно',
#  ',',
#  'беззвучно',
#  'вспыхивали',
#  ',',
#  'гасли',
#  'неопределенные',
#  'светы',
#  ',',
#  'как',
#  'будто',
#  'задувало',
#  'их',
#  '.',
#  'Молчали',
#  'пулеметы',
#  '.',
#  'Новиков',
#  'не',
#  'видел',
#  'в',
#  'темноте',
#  'ни',
#  'орудия',
#  ',',
#  'ни',
#  'часовых',
#  ',',
#  'шел',
#  '—',
#  'руки',
#  'в',
#  'карманах',
#  ',',
#  'ветер',
#  'неистово',
#  'трепал',
#  'полы',
#  'шинели',
#  ',',
#  '—',
#  'и',
#  'странное',
#  'чувство',
#  'тоски',
#  ',',
#  'глухой',
#  'затерянности',
#  'в',
#  'этих',
#  'мрачных',
#  ',',
#  'холодных',
#  'Карпатах',
#  'охватывало',
#  'его',
#  '.',
#  'Приступы',
#  'тоски',
#  'появлялись',
#  'в',
#  'последнюю',
#  'неделю',
#  'не',
#  'раз',
#  '—',
#  'и',
#  'всегда',
#  'ночью',
#  ',',
#  'в',
#  'короткие',
#  'затишья',
#  ',',
#  'и',
#  'объяснялись',
#  'главным',
#  'образом',
#  'тем',
#  ',',
#  'что',
#  'четыре',
#  'дня',
#  'назад',
#  ',',
#  'при',
#  'взятии',
#  'города',
#  'Касно',
#  ',',
#  'батарея',
#  'Новикова',
#  'впервые',
#  'потеряла',
#  'девять',
#  'человек',
#  'сразу',
#  ',',
#  'в',
#  'том',
#  'числе',
#  'командира',
#  'взвода',
#  'управления',
#  ',',
#  'и',
#  'Новиков',
#  'не',
#  'мог',
#  'простить',
#  'себе',
#  'этого',
#  '.',
#  '—',
#  'Часовой',
#  '!',
#  '—',
#  'строго',
#  'окликнул',
#  'Новиков',
#  ',',
#  'останавливаясь',
#  ',',
#  'по',
#  'звуку',
#  'голосов',
#  'угадывая',
#  'впереди',
#  'землянку',
#  'первого',
#  'взвода',
#  ',',
#  'вырытую',
#  'в',
#  'скате',
#  'высоты',
#  '.',
#  'Ответа',
#  'не',
#  'было',
#  '.',
#  '—',
#  'Часовой',
#  '!',
#  '—',
#  'повторил',
#  'он',
#  'громче',
#  '.',
#  '—',
#  'А',
#  '?',
#  'Что-то',
#  'черное',
#  'завозилось',
#  ',',
#  'шурша',
#  'плащ-палаткой',
#  ',',
#  'возле',
#  'входа',
#  'в',
#  'землянку',
#  ',',
#  'голос',
#  'из',
#  'темноты',
#  'отозвался',
#  'сдавленно',
#  ':',
#  '—',
#  'А',
#  '!',
#  'Кто',
#  'тут',
#  '?',
#  '—',
#  'Что',
#  'это',
#  'за',
#  '«',
#  'а',
#  '»',
#  '?',
#  'Черт',
#  'бы',
#  'драл',
#  '!',
#  '—',
#  'выругался',
#  'Новиков',
#  '.',
#  '—',
#  'В',
#  'прятки',
#  'играете',
#  '?',
#  '—',
#  'Стой',
#  '!',
#  'Кто',
#  'идет',
#  '?',
#  '—',
#  'преувеличенно',
#  'грозно',
#  'выкрикнул',
#  'часовой',
#  'и',
#  'щелкнул',
#  'затвором',
#  'автомата',
#  '.',
#  '—',
#  'Проснулись',
#  '?',
#  'Что',
#  'там',
#  'за',
#  'колготня',
#  'в',
#  'землянке',
#  '?',
#  '—',
#  'спросил',
#  'Новиков',
#  'недовольным',
#  'тоном',
#  '.',
#  '—',
#  'Что',
#  'молчите',
#  '?',
#  '—',
#  'Овчинников',
#  'чегой-то',
#  'шумит',
#  ',',
#  'товарищ',
#  'капитан',
#  ',',
#  '—',
#  'робко',
#  'кашлянув',
#  ',',
#  'забормотал',
#  'часовой',
#  '.',
#  '—',
#  'И',
#  'чего',
#  'они',
#  'разоряются',
#  '?',
#  'Новиков',
#  'толкнул',
#  'дверь',
#  'в',
#  'землянку',
#  '.',
#  'Плотный',
#  'гул',
#  'голосов',
#  'колыхался',
#  'под',
#  'низкими',
#  'накатами',
#  '.',
#  'Среди',
#  'дыма',
#  'плавали',
#  'фиолетовые',
#  'огни',
#  'немецких',
#  'плошек',
#  ',',
#  'мутно',
#  'проступали',
#  'за',
#  'столом',
#  'и',
#  'на',
#  'нарах',
#  'красно-багровые',
#  'лица',
#  'солдат',
#  '—',
#  'все',
#  'говорили',
#  'разом',
#  ',',
#  'нещадно',
#  'курили',
#  '.',
#  'Командир',
#  'первого',
#  'взвода',
#  'лейтенант',
#  'Овчинников',
#  ',',
#  'с',
#  'тонким',
#  ',',
#  'красивым',
#  ',',
#  'самолюбивым',
#  'ртом',
#  ',',
#  'ударил',
#  'кулаком',
#  'по',
#  'столу',
#  ',',
#  'покачиваясь',
#  ',',
#  'встал',
#  ',',
#  'затем',
#  ',',
#  'небрежно',
#  'оттолкнув',
#  'на',
#  'бедре',
#  'тяжелую',
#  'кобуру',
#  'пистолета',
#  ',',
#  'скомандовал',
#  ':',
#  'сипло',
#  'и',
#  'властно',
#  ':',
#  '—',
#  'Прекратить',
#  'галдеж',
#  'и',
#  'слушай',
#  'тост',
#  '!',
#  'За',
#  'Леночку',
#  '!',
#  'А',
#  ',',
#  'братцы',
#  '?',
#  'Пить',
#  'всем',
#  '!',
#  'Смутный',
#  'рев',
#  'голосов',
#  'ответил',
#  'ему',
#  'и',
#  'стих',
#  ':',
#  'все',
#  'увидели',
#  'молча',
#  'стоявшего',
#  'в',
#  'дверях',
#  'капитана',
#  'Новикова',
#  '.',
#  'Он',
#  'медленно',
#  'обвел',
#  'взглядом',
#  'лица',
#  'солдат',
#  '.',
#  '—',
#  'Значит',
#  ',',
#  'пыль',
#  'столбом',
#  '?',
#  '—',
#  'произнес',
#  'он',
#  ',',
#  'хмурясь',
#  '.',
#  '—',
#  'И',
#  'санинструктор',
#  'здесь',
#  '?',
#  'То',
#  ',',
#  'что',
#  'веселье',
#  'это',
#  'происходило',
#  'в',
#  'восьмистах',
#  'метрах',
#  'от',
#  'немецкой',
#  'передовой',
#  'и',
#  'люди',
#  ',',
#  'зная',
#  'это',
#  ',',
#  'не',
#  'сдерживали',
#  'себя',
#  ',',
#  'не',
#  'удивило',
#  'Новикова',
#  '.',
#  'Удивило',
#  'то',
#  ',',
#  'что',
#  'здесь',
#  ',',
#  'среди',
#  'едкого',
#  'махорочного',
#  'дыма',
#  ',',
#  'среди',
#  'этого',
#  'нетрезвого',
#  'шума',
#  ',',
#  'сидела',
#  'на',
#  'нарах',
#  'санинструктор',
#  'Лена',
#  'Колоскова',
#  '.',
#  'Сидела',
#  'она',
#  ',',
#  'охватив',
#  'руками',
#  'колени',
#  'и',
#  'покачиваясь',
#  'взад',
#  'и',
#  'вперед',
#  ',',
#  'разговаривала',
#  'с',
#  'умиленно',
#  'расплывшимся',
#  'замковым',
#  'Лягаловым',
#  ',',
#  'смеялась',
#  'тихим',
#  ',',
#  'трудным',
#  ',',
#  'ласковым',
#  'смехом',
#  '.',
#  '«',
#  'Смеется',
#  'каким-то',
#  'жемчужным',
#  'смехом',
#  ',',
#  '—',
#  'не',
#  'без',
#  'раздражения',
#  'подумал',
#  'Новиков',
#  '.',
#  '—',
#  'Она',
#  'пьяна',
#  'или',
#  'хочет',
#  'понравиться',
#  'лейтенанту',
#  'Овчинникову',
#  '.',
#  'Зачем',
#  'ей',
#  'это',
#  '?',
#  '»',
#  'И',
#  ',',
#  'стараясь',
#  'еще',
#  'более',
#  'возбудить',
#  'в',
#  'себе',
#  'неприязнь',
#  'к',
#  'этому',
#  'легкомысленному',
#  'смеху',
#  ',',
#  'он',
#  'быстро',
#  'взглянул',
#  'на',
#  'нее',
#  ',',
#  'потом',
#  'на',
#  'Овчинникова',
#  ',',
#  'спросил',
#  ':',
#  '—',
#  'Что',
#  'у',
#  'вас',
#  'тут',
#  '?',
#  'Свадьба',
#  '?',
#  '..',
#  'Он',
#  'произнес',
#  'это',
#  ',',
#  'должно',
#  'быть',
#  ',',
#  'грубо',
#  '—',
#  'все',
#  'замолчали',
#  '.',
#  'Лена',
#  'вопросительно',
#  'перевела',
#  'на',
#  'него',
#  'взгляд',
#  'и',
#  'вдруг',
#  'легко',
#  'и',
#  'гибко',
#  'спрыгнула',
#  'с',
#  'нар',
#  ',',
#  'взяла',
#  'со',
#  'стола',
#  'чей-то',
#  'стакан',
#  ',',
#  'подошла',
#  'к',
#  'Новикову',
#  ',',
#  'блестя',
#  'яркими',
#  ',',
#  'чуть',
#  'прищуренными',
#  ',',
#  'улыбающимися',
#  'глазами',
#  '.',
#  '—',
#  'Да',
#  ',',
#  'именно',
#  ',',
#  '—',
#  'сказала',
#  ',',
#  'откидывая',
#  'голову',
#  ',',
#  '—',
#  'здесь',
#  'свадьба',
#  '.',
#  'Поздравьте',
#  'меня',
#  'и',
#  'Овчинникова',
#  '.',
#  'Лейтенант',
#  'Овчинников',
#  '!',
#  '—',
#  'приказала',
#  'она',
#  '.',
#  '—',
#  'Дайте',
#  'водки',
#  'капитану',
#  '!',
#  '«',
#  'Что',
#  'это',
#  'с',
#  'ней',
#  '?',
#  '»',
#  'Она',
#  'не',
#  'была',
#  'пьяна',
#  ',',
#  'кажется',
#  '(',
#  'а',
#  'вообще',
#  'не',
#  'поймешь',
#  '!',
#  ')',
#  ',',
#  'и',
#  'дерзко',
#  'глядела',
#  'на',
#  'него',
#  'снизу',
#  'вверх',
#  ',',
#  '—',
#  'тонкая',
#  'нежная',
#  'шея',
#  'окаймлена',
#  'воротом',
#  ',',
#  'узкие',
#  'плечи',
#  ',',
#  'крепкая',
#  'маленькая',
#  'грудь',
#  'обтянута',
#  'суконной',
#  'гимнастеркой',
#  ',',
#  'сжатой',
#  'в',
#  'талии',
#  'широким',
#  'ремнем',
#  '.',
#  'Не',
#  'раз',
#  'ловил',
#  'себя',
#  'Новиков',
#  'на',
#  'том',
#  ',',
#  'что',
#  'его',
#  'непривычно',
#  'смущала',
#  'постоянная',
#  'вызывающая',
#  'смелость',
#  'санинструктора',
#  ',',
#  '—',
#  'он',
#  'почувствовал',
#  ',',
#  'что',
#  'покраснел',
#  'на',
#  'виду',
#  'мгновенно',
#  'притихших',
#  'солдат',
#  ',',
#  'и',
#  ',',
#  'разозленный',
#  'на',
#  'себя',
#  'за',
#  'это',
#  ',',
#  'резко',
#  'сказал',
#  ':',
#  '—',
#  'Вы',
#  'всегда',
#  'неудачно',
#  'шутите',
#  ',',
#  'товарищ',
#  'санинструктор',
#  '!',
#  '—',
#  'И',
#  ',',
#  'повернувшись',
#  'к',
#  'лейтенанту',
#  'Овчинникову',
#  ',',
#  'договорил',
#  'тоном',
#  'приказа',
#  ':',
#  '—',
#  'Прекратить',
#  '!',
#  'Что',
#  'это',
#  'за',
#  'веселье',
#  '?',
#  'С',
#  'какой',
#  'радости',
#  '?',
#  'Всем',
#  'отдыхать',
#  '!',
#  'Лейтенант',
#  'Овчинников',
#  ',',
#  'самолюбиво',
#  'сузив',
#  'светло',
#  'трезвые',
#  'глаза',
#  'на',
#  'недопитый',
#  'стакан',
#  ',',
#  'спросил',
#  ':',
#  '—',
#  'За',
#  'что',
#  'вы',
#  ',',
#  'товарищ',
#  'капитан',
#  '?',
#  'Мой',
#  'день',
#  'рождения',
#  '.',
#  'Не',
#  'признаете',
#  '?',
#  'Двадцать',
#  'шесть',
#  'стукнуло',
#  '.',
#  'Лягалов',
#  ',',
#  'налей',
#  'комбату',
#  '!',
#  'Ломанем',
#  ',',
#  'товарищ',
#  'капитан',
#  '?',
#  '..',
#  'Чтоб',
#  'пыль',
#  'на',
#  'всю',
#  'Европу',
#  ',',
#  'а',
#  '?',
#  'Замковый',
#  'Лягалов',
#  ',',
#  'солдат',
#  'пожилой',
#  ',',
#  'некрасивый',
#  ',',
#  'низкорослый',
#  ',',
#  'обросший',
#  'золотистой',
#  'щетинкой',
#  'на',
#  'худых',
#  'щеках',
#  ',',
#  'помигал',
#  'конфузливо',
#  'на',
#  'Овчинникова',
#  ',',
#  'на',
#  'комбата',
#  ',',
#  'неуверенно',
#  'налил',
#  'из',
#  'фляги',
#  'полную',
#  'кружку',
#  ',',
#  'протянул',
#  'Новикову',
#  ':',
#  '—',
#  'Товарищ',
#  'капитан',
#  ',',
#  'не',
#  'побрезгуйте',
#  ',',
#  'стадо',
#  'быть…',
#  'Чистая-а',
#  '!',
#  'Считался',
#  'Лягалов',
#  'непьющим',
#  ',',
#  'и',
#  'то',
#  ',',
#  'что',
#  'он',
#  'пил',
#  'сейчас',
#  'и',
#  'протягивал',
#  'кружку',
#  ',',
#  'вконец',
#  'испортило',
#  'настроение',
#  'Новикову',
#  '.',
#  'Он',
#  'оттолкнул',
#  'руку',
#  'Лягалова',
#  ',',
#  'криво',
#  'усмехнулся',
#  ':',
#  '—',
#  'Поздравляю',
#  '.',
#  '—',
#  'И',
#  ',',
#  'ссутулившись',
#  ',',
#  'шагнул',
#  'к',
#  'двери',
#  ...]

# %%
def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    elif nltk_tag.startswith('C'):
        return nltk.corpus.wordnet.CD
    else:          
        return None

tagged
# Out:
# [('1', 'CD'),
#  ('Глава', 'JJ'),
#  ('Завещаю', 'NNP'),
#  ('в', 'NNP'),
#  ('той', 'NNP'),
#  ('жизни', 'NNP'),
#  ('Вам', 'NNP'),
#  ('счастливыми', 'NNP'),
#  ('быть', 'NNP'),
#  ('И', 'NNP'),
#  ('родимой', 'NNP'),
#  ('Отчизне', 'NNP'),
#  ('С', 'NNP'),
#  ('честью', 'NNP'),
#  ('дальше', 'NNP'),
#  ('служить', 'NNP'),
#  ('.', '.'),
#  ('Горевать', 'VB'),
#  ('—', 'JJ'),
#  ('горделиво', 'NNP'),
#  (',', ','),
#  ('Не', 'NNP'),
#  ('клонясь', 'NNP'),
#  ('головой', 'NNP'),
#  ('.', '.'),
#  ('Ликовать', 'VB'),
#  ('—', 'JJ'),
#  ('не', 'NNP'),
#  ('хвастливо', 'NNP'),
#  ('В', 'NNP'),
#  ('час', 'NNP'),
#  ('победы', 'NNP'),
#  ('самой', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('беречь', 'JJ'),
#  ('ее', 'NNP'),
#  ('свято', 'NNP'),
#  (',', ','),
#  ('Братья', 'NNP'),
#  (',', ','),
#  ('счастье', 'NNP'),
#  ('свое', 'NNP'),
#  ('—', 'NNP'),
#  ('В', 'NNP'),
#  ('память', 'NNP'),
#  ('воина-брата', 'NNP'),
#  (',', ','),
#  ('Что', 'NNP'),
#  ('погиб', 'NNP'),
#  ('за', 'NNP'),
#  ('нее', 'NNP'),
#  ('.', '.'),
#  ('А.', 'VB'),
#  ('Твардовский', 'JJ'),
#  ('В', 'NNP'),
#  ('двенадцатом', 'NNP'),
#  ('часу', 'NNP'),
#  ('ночи', 'NNP'),
#  ('капитан', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('проверял', 'NNP'),
#  ('посты', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('шел', 'JJ'),
#  ('по', 'NNP'),
#  ('высоте', 'NNP'),
#  ('в', 'NNP'),
#  ('черной', 'NNP'),
#  ('осенней', 'NNP'),
#  ('тьме', 'NNP'),
#  (',', ','),
#  ('над', 'NNP'),
#  ('головой', 'NNP'),
#  ('густо', 'NNP'),
#  ('шумели', 'NNP'),
#  ('вершины', 'NNP'),
#  ('сосен', 'NNP'),
#  ('.', '.'),
#  ('Острым', 'VB'),
#  ('северным', 'JJ'),
#  ('холодом', 'NNP'),
#  ('дуло', 'NNP'),
#  ('с', 'NNP'),
#  ('Карпат', 'NNP'),
#  (',', ','),
#  ('вся', 'NNP'),
#  ('высота', 'NNP'),
#  ('гудела', 'NNP'),
#  (',', ','),
#  ('точно', 'NNP'),
#  ('гулко', 'NNP'),
#  ('вибрировала', 'NNP'),
#  ('под', 'NNP'),
#  ('непрерывными', 'NNP'),
#  ('ударами', 'NNP'),
#  ('воздушных', 'NNP'),
#  ('потоков', 'NNP'),
#  ('.', '.'),
#  ('Пахло', 'NN'),
#  ('снегом', 'NN'),
#  ('.', '.'),
#  ('Редкие', 'CC'),
#  ('ракеты', 'JJ'),
#  ('извивались', 'NNP'),
#  ('над', 'NNP'),
#  ('немецкой', 'NNP'),
#  ('передовой', 'NNP'),
#  (',', ','),
#  ('сносимые', 'NNP'),
#  ('ветром', 'NNP'),
#  (',', ','),
#  ('догорали', 'NNP'),
#  ('за', 'NNP'),
#  ('темным', 'NNP'),
#  ('полукружьем', 'NNP'),
#  ('соседней', 'NNP'),
#  ('высоты', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('низине', 'JJ'),
#  ('справа', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('лежал', 'NNP'),
#  ('польский', 'NNP'),
#  ('город', 'NNP'),
#  ('Касно', 'NNP'),
#  (',', ','),
#  ('беззвучно', 'NNP'),
#  ('вспыхивали', 'NNP'),
#  (',', ','),
#  ('гасли', 'NNP'),
#  ('неопределенные', 'NNP'),
#  ('светы', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('будто', 'NNP'),
#  ('задувало', 'NNP'),
#  ('их', 'NNP'),
#  ('.', '.'),
#  ('Молчали', 'NN'),
#  ('пулеметы', 'NN'),
#  ('.', '.'),
#  ('Новиков', 'CC'),
#  ('не', 'JJ'),
#  ('видел', 'NNP'),
#  ('в', 'NNP'),
#  ('темноте', 'NNP'),
#  ('ни', 'NNP'),
#  ('орудия', 'NNP'),
#  (',', ','),
#  ('ни', 'NNP'),
#  ('часовых', 'NNP'),
#  (',', ','),
#  ('шел', 'NNP'),
#  ('—', 'NNP'),
#  ('руки', 'NNP'),
#  ('в', 'NNP'),
#  ('карманах', 'NNP'),
#  (',', ','),
#  ('ветер', 'NNP'),
#  ('неистово', 'NNP'),
#  ('трепал', 'NNP'),
#  ('полы', 'NNP'),
#  ('шинели', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('и', 'NNP'),
#  ('странное', 'NNP'),
#  ('чувство', 'NNP'),
#  ('тоски', 'NNP'),
#  (',', ','),
#  ('глухой', 'NNP'),
#  ('затерянности', 'NNP'),
#  ('в', 'NNP'),
#  ('этих', 'NNP'),
#  ('мрачных', 'NNP'),
#  (',', ','),
#  ('холодных', 'NNP'),
#  ('Карпатах', 'NNP'),
#  ('охватывало', 'NNP'),
#  ('его', 'NNP'),
#  ('.', '.'),
#  ('Приступы', 'VB'),
#  ('тоски', 'JJ'),
#  ('появлялись', 'NNP'),
#  ('в', 'NNP'),
#  ('последнюю', 'NNP'),
#  ('неделю', 'NNP'),
#  ('не', 'NNP'),
#  ('раз', 'NNP'),
#  ('—', 'NNP'),
#  ('и', 'NNP'),
#  ('всегда', 'NNP'),
#  ('ночью', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('короткие', 'NNP'),
#  ('затишья', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('объяснялись', 'NNP'),
#  ('главным', 'NNP'),
#  ('образом', 'NNP'),
#  ('тем', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('четыре', 'NNP'),
#  ('дня', 'NNP'),
#  ('назад', 'NNP'),
#  (',', ','),
#  ('при', 'NNP'),
#  ('взятии', 'NNP'),
#  ('города', 'NNP'),
#  ('Касно', 'NNP'),
#  (',', ','),
#  ('батарея', 'NNP'),
#  ('Новикова', 'NNP'),
#  ('впервые', 'NNP'),
#  ('потеряла', 'NNP'),
#  ('девять', 'NNP'),
#  ('человек', 'NNP'),
#  ('сразу', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('том', 'NNP'),
#  ('числе', 'NNP'),
#  ('командира', 'NNP'),
#  ('взвода', 'NNP'),
#  ('управления', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('не', 'NNP'),
#  ('мог', 'NNP'),
#  ('простить', 'NNP'),
#  ('себе', 'NNP'),
#  ('этого', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Часовой', 'JJ'),
#  ('!', '.'),
#  ('—', 'JJ'),
#  ('строго', 'JJ'),
#  ('окликнул', 'NN'),
#  ('Новиков', 'NN'),
#  (',', ','),
#  ('останавливаясь', 'NNP'),
#  (',', ','),
#  ('по', 'NNP'),
#  ('звуку', 'NNP'),
#  ('голосов', 'NNP'),
#  ('угадывая', 'NNP'),
#  ('впереди', 'NNP'),
#  ('землянку', 'NNP'),
#  ('первого', 'NNP'),
#  ('взвода', 'NNP'),
#  (',', ','),
#  ('вырытую', 'NNP'),
#  ('в', 'NNP'),
#  ('скате', 'NNP'),
#  ('высоты', 'NNP'),
#  ('.', '.'),
#  ('Ответа', 'VB'),
#  ('не', 'JJ'),
#  ('было', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Часовой', 'JJ'),
#  ('!', '.'),
#  ('—', 'JJ'),
#  ('повторил', 'JJ'),
#  ('он', 'NN'),
#  ('громче', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('А', 'JJ'),
#  ('?', '.'),
#  ('Что-то', 'JJ'),
#  ('черное', 'NN'),
#  ('завозилось', 'NN'),
#  (',', ','),
#  ('шурша', 'JJ'),
#  ('плащ-палаткой', 'NN'),
#  (',', ','),
#  ('возле', 'NNP'),
#  ('входа', 'NNP'),
#  ('в', 'NNP'),
#  ('землянку', 'NNP'),
#  (',', ','),
#  ('голос', 'NNP'),
#  ('из', 'NNP'),
#  ('темноты', 'NNP'),
#  ('отозвался', 'NNP'),
#  ('сдавленно', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('А', 'NN'),
#  ('!', '.'),
#  ('Кто', 'NN'),
#  ('тут', 'NN'),
#  ('?', '.'),
#  ('—', 'JJ'),
#  ('Что', 'NN'),
#  ('это', 'NNP'),
#  ('за', 'NNP'),
#  ('«', 'NNP'),
#  ('а', 'NNP'),
#  ('»', 'NNP'),
#  ('?', '.'),
#  ('Черт', 'NNP'),
#  ('бы', 'NNP'),
#  ('драл', 'NN'),
#  ('!', '.'),
#  ('—', 'JJ'),
#  ('выругался', 'JJ'),
#  ('Новиков', 'NN'),
#  ('.', '.'),
#  ('—', 'CC'),
#  ('В', 'JJ'),
#  ('прятки', 'NN'),
#  ('играете', 'NN'),
#  ('?', '.'),
#  ('—', 'JJ'),
#  ('Стой', 'NN'),
#  ('!', '.'),
#  ('Кто', 'NN'),
#  ('идет', 'NN'),
#  ('?', '.'),
#  ('—', 'JJ'),
#  ('преувеличенно', 'NN'),
#  ('грозно', 'NNP'),
#  ('выкрикнул', 'NNP'),
#  ('часовой', 'NNP'),
#  ('и', 'NNP'),
#  ('щелкнул', 'NNP'),
#  ('затвором', 'NNP'),
#  ('автомата', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Проснулись', 'NN'),
#  ('?', '.'),
#  ('Что', 'JJ'),
#  ('там', 'NN'),
#  ('за', 'NNP'),
#  ('колготня', 'NNP'),
#  ('в', 'NNP'),
#  ('землянке', 'NNP'),
#  ('?', '.'),
#  ('—', 'NNP'),
#  ('спросил', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('недовольным', 'NNP'),
#  ('тоном', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Что', 'JJ'),
#  ('молчите', 'NNP'),
#  ('?', '.'),
#  ('—', 'JJ'),
#  ('Овчинников', 'JJ'),
#  ('чегой-то', 'JJ'),
#  ('шумит', 'NN'),
#  (',', ','),
#  ('товарищ', 'NNP'),
#  ('капитан', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('робко', 'NNP'),
#  ('кашлянув', 'NNP'),
#  (',', ','),
#  ('забормотал', 'NNP'),
#  ('часовой', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('И', 'JJ'),
#  ('чего', 'NNP'),
#  ('они', 'NNP'),
#  ('разоряются', 'NNP'),
#  ('?', '.'),
#  ('Новиков', 'NNP'),
#  ('толкнул', 'NNP'),
#  ('дверь', 'NNP'),
#  ('в', 'NNP'),
#  ('землянку', 'NNP'),
#  ('.', '.'),
#  ('Плотный', 'VB'),
#  ('гул', 'JJ'),
#  ('голосов', 'NNP'),
#  ('колыхался', 'NNP'),
#  ('под', 'NNP'),
#  ('низкими', 'NNP'),
#  ('накатами', 'NNP'),
#  ('.', '.'),
#  ('Среди', 'VB'),
#  ('дыма', 'JJ'),
#  ('плавали', 'NNP'),
#  ('фиолетовые', 'NNP'),
#  ('огни', 'NNP'),
#  ('немецких', 'NNP'),
#  ('плошек', 'NNP'),
#  (',', ','),
#  ('мутно', 'NNP'),
#  ('проступали', 'NNP'),
#  ('за', 'NNP'),
#  ('столом', 'NNP'),
#  ('и', 'NNP'),
#  ('на', 'NNP'),
#  ('нарах', 'NNP'),
#  ('красно-багровые', 'JJ'),
#  ('лица', 'NNP'),
#  ('солдат', 'NNP'),
#  ('—', 'NNP'),
#  ('все', 'NNP'),
#  ('говорили', 'NNP'),
#  ('разом', 'NNP'),
#  (',', ','),
#  ('нещадно', 'NNP'),
#  ('курили', 'NNP'),
#  ('.', '.'),
#  ('Командир', 'VB'),
#  ('первого', 'JJ'),
#  ('взвода', 'NNP'),
#  ('лейтенант', 'NNP'),
#  ('Овчинников', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('тонким', 'NNP'),
#  (',', ','),
#  ('красивым', 'NNP'),
#  (',', ','),
#  ('самолюбивым', 'NNP'),
#  ('ртом', 'NNP'),
#  (',', ','),
#  ('ударил', 'NNP'),
#  ('кулаком', 'NNP'),
#  ('по', 'NNP'),
#  ('столу', 'NNP'),
#  (',', ','),
#  ('покачиваясь', 'NNP'),
#  (',', ','),
#  ('встал', 'NNP'),
#  (',', ','),
#  ('затем', 'NNP'),
#  (',', ','),
#  ('небрежно', 'NNP'),
#  ('оттолкнув', 'NNP'),
#  ('на', 'NNP'),
#  ('бедре', 'NNP'),
#  ('тяжелую', 'NNP'),
#  ('кобуру', 'NNP'),
#  ('пистолета', 'NNP'),
#  (',', ','),
#  ('скомандовал', 'NN'),
#  (':', ':'),
#  ('сипло', 'JJ'),
#  ('и', 'JJ'),
#  ('властно', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Прекратить', 'NNP'),
#  ('галдеж', 'NNP'),
#  ('и', 'NNP'),
#  ('слушай', 'NNP'),
#  ('тост', 'NN'),
#  ('!', '.'),
#  ('За', 'JJ'),
#  ('Леночку', 'NN'),
#  ('!', '.'),
#  ('А', 'NN'),
#  (',', ','),
#  ('братцы', 'VB'),
#  ('?', '.'),
#  ('Пить', 'JJ'),
#  ('всем', 'NN'),
#  ('!', '.'),
#  ('Смутный', 'JJ'),
#  ('рев', 'JJ'),
#  ('голосов', 'NN'),
#  ('ответил', 'NNP'),
#  ('ему', 'NNP'),
#  ('и', 'NNP'),
#  ('стих', 'NN'),
#  (':', ':'),
#  ('все', 'JJ'),
#  ('увидели', 'NNP'),
#  ('молча', 'NNP'),
#  ('стоявшего', 'NNP'),
#  ('в', 'NNP'),
#  ('дверях', 'NNP'),
#  ('капитана', 'NNP'),
#  ('Новикова', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('медленно', 'JJ'),
#  ('обвел', 'NNP'),
#  ('взглядом', 'NNP'),
#  ('лица', 'NNP'),
#  ('солдат', 'NNP'),
#  ('.', '.'),
#  ('—', 'NN'),
#  ('Значит', 'NN'),
#  (',', ','),
#  ('пыль', 'NNP'),
#  ('столбом', 'NNP'),
#  ('?', '.'),
#  ('—', 'NNP'),
#  ('произнес', 'NNP'),
#  ('он', 'NNP'),
#  (',', ','),
#  ('хмурясь', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('И', 'JJ'),
#  ('санинструктор', 'NNP'),
#  ('здесь', 'NNP'),
#  ('?', '.'),
#  ('То', 'NN'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('веселье', 'NNP'),
#  ('это', 'NNP'),
#  ('происходило', 'NNP'),
#  ('в', 'NNP'),
#  ('восьмистах', 'NNP'),
#  ('метрах', 'NNP'),
#  ('от', 'NNP'),
#  ('немецкой', 'NNP'),
#  ('передовой', 'NNP'),
#  ('и', 'NNP'),
#  ('люди', 'NNP'),
#  (',', ','),
#  ('зная', 'NNP'),
#  ('это', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('сдерживали', 'NNP'),
#  ('себя', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('удивило', 'NNP'),
#  ('Новикова', 'NNP'),
#  ('.', '.'),
#  ('Удивило', 'NN'),
#  ('то', 'NN'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('здесь', 'NNP'),
#  (',', ','),
#  ('среди', 'NNP'),
#  ('едкого', 'NNP'),
#  ('махорочного', 'NNP'),
#  ('дыма', 'NNP'),
#  (',', ','),
#  ('среди', 'NNP'),
#  ('этого', 'NNP'),
#  ('нетрезвого', 'NNP'),
#  ('шума', 'NNP'),
#  (',', ','),
#  ('сидела', 'NNP'),
#  ('на', 'NNP'),
#  ('нарах', 'NNP'),
#  ('санинструктор', 'NNP'),
#  ('Лена', 'NNP'),
#  ('Колоскова', 'NNP'),
#  ('.', '.'),
#  ('Сидела', 'NN'),
#  ('она', 'NN'),
#  (',', ','),
#  ('охватив', 'NNP'),
#  ('руками', 'NNP'),
#  ('колени', 'NNP'),
#  ('и', 'NNP'),
#  ('покачиваясь', 'NNP'),
#  ('взад', 'NNP'),
#  ('и', 'NNP'),
#  ('вперед', 'NNP'),
#  (',', ','),
#  ('разговаривала', 'NNP'),
#  ('с', 'NNP'),
#  ('умиленно', 'NNP'),
#  ('расплывшимся', 'NNP'),
#  ('замковым', 'NNP'),
#  ('Лягаловым', 'NNP'),
#  (',', ','),
#  ('смеялась', 'NNP'),
#  ('тихим', 'NNP'),
#  (',', ','),
#  ('трудным', 'NNP'),
#  (',', ','),
#  ('ласковым', 'NNP'),
#  ('смехом', 'NNP'),
#  ('.', '.'),
#  ('«', 'VB'),
#  ('Смеется', 'JJ'),
#  ('каким-то', 'JJ'),
#  ('жемчужным', 'NN'),
#  ('смехом', 'NN'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('не', 'NNP'),
#  ('без', 'NNP'),
#  ('раздражения', 'NNP'),
#  ('подумал', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Она', 'JJ'),
#  ('пьяна', 'NNP'),
#  ('или', 'NNP'),
#  ('хочет', 'NNP'),
#  ('понравиться', 'NNP'),
#  ('лейтенанту', 'NNP'),
#  ('Овчинникову', 'NNP'),
#  ('.', '.'),
#  ('Зачем', 'VB'),
#  ('ей', 'JJ'),
#  ('это', 'NNP'),
#  ('?', '.'),
#  ('»', 'NNP'),
#  ('И', 'NNP'),
#  (',', ','),
#  ('стараясь', 'NNP'),
#  ('еще', 'NNP'),
#  ('более', 'NNP'),
#  ('возбудить', 'NNP'),
#  ('в', 'NNP'),
#  ('себе', 'NNP'),
#  ('неприязнь', 'NNP'),
#  ('к', 'NNP'),
#  ('этому', 'NNP'),
#  ('легкомысленному', 'NNP'),
#  ('смеху', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('быстро', 'NNP'),
#  ('взглянул', 'NNP'),
#  ('на', 'NNP'),
#  ('нее', 'NNP'),
#  (',', ','),
#  ('потом', 'NNP'),
#  ('на', 'NNP'),
#  ('Овчинникова', 'NNP'),
#  (',', ','),
#  ('спросил', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Что', 'NNP'),
#  ('у', 'NNP'),
#  ('вас', 'NNP'),
#  ('тут', 'NNP'),
#  ('?', '.'),
#  ('Свадьба', 'NN'),
#  ('?', '.'),
#  ('..', 'JJ'),
#  ('Он', 'NN'),
#  ('произнес', 'NNP'),
#  ('это', 'NNP'),
#  (',', ','),
#  ('должно', 'NNP'),
#  ('быть', 'NNP'),
#  (',', ','),
#  ('грубо', 'NNP'),
#  ('—', 'NNP'),
#  ('все', 'NNP'),
#  ('замолчали', 'NNP'),
#  ('.', '.'),
#  ('Лена', 'VB'),
#  ('вопросительно', 'JJ'),
#  ('перевела', 'NNP'),
#  ('на', 'NNP'),
#  ('него', 'NNP'),
#  ('взгляд', 'NNP'),
#  ('и', 'NNP'),
#  ('вдруг', 'NNP'),
#  ('легко', 'NNP'),
#  ('и', 'NNP'),
#  ('гибко', 'NNP'),
#  ('спрыгнула', 'NNP'),
#  ('с', 'NNP'),
#  ('нар', 'NNP'),
#  (',', ','),
#  ('взяла', 'NNP'),
#  ('со', 'NNP'),
#  ('стола', 'NNP'),
#  ('чей-то', 'JJ'),
#  ('стакан', 'NNP'),
#  (',', ','),
#  ('подошла', 'NNP'),
#  ('к', 'NNP'),
#  ('Новикову', 'NNP'),
#  (',', ','),
#  ('блестя', 'NNP'),
#  ('яркими', 'NNP'),
#  (',', ','),
#  ('чуть', 'NNP'),
#  ('прищуренными', 'NNP'),
#  (',', ','),
#  ('улыбающимися', 'NNP'),
#  ('глазами', 'NNP'),
#  ('.', '.'),
#  ('—', 'NN'),
#  ('Да', 'NN'),
#  (',', ','),
#  ('именно', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('сказала', 'NNP'),
#  (',', ','),
#  ('откидывая', 'NNP'),
#  ('голову', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('здесь', 'NNP'),
#  ('свадьба', 'NNP'),
#  ('.', '.'),
#  ('Поздравьте', 'VB'),
#  ('меня', 'JJ'),
#  ('и', 'NNP'),
#  ('Овчинникова', 'NNP'),
#  ('.', '.'),
#  ('Лейтенант', 'VB'),
#  ('Овчинников', 'JJ'),
#  ('!', '.'),
#  ('—', 'JJ'),
#  ('приказала', 'JJ'),
#  ('она', 'NN'),
#  ('.', '.'),
#  ('—', 'CC'),
#  ('Дайте', 'JJ'),
#  ('водки', 'NNP'),
#  ('капитану', 'NN'),
#  ('!', '.'),
#  ('«', 'JJ'),
#  ('Что', 'JJ'),
#  ('это', 'NN'),
#  ('с', 'NNP'),
#  ('ней', 'NNP'),
#  ('?', '.'),
#  ('»', 'NNP'),
#  ('Она', 'NNP'),
#  ('не', 'NNP'),
#  ('была', 'NNP'),
#  ('пьяна', 'NNP'),
#  (',', ','),
#  ('кажется', 'NNP'),
#  ('(', '('),
#  ('а', 'NNP'),
#  ('вообще', 'NNP'),
#  ('не', 'NNP'),
#  ('поймешь', 'NNP'),
#  ('!', '.'),
#  (')', ')'),
#  (',', ','),
#  ('и', 'JJ'),
#  ('дерзко', 'NNP'),
#  ('глядела', 'NNP'),
#  ('на', 'NNP'),
#  ('него', 'NNP'),
#  ('снизу', 'NNP'),
#  ('вверх', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('тонкая', 'NNP'),
#  ('нежная', 'NNP'),
#  ('шея', 'NNP'),
#  ('окаймлена', 'NNP'),
#  ('воротом', 'NNP'),
#  (',', ','),
#  ('узкие', 'NNP'),
#  ('плечи', 'NNP'),
#  (',', ','),
#  ('крепкая', 'NNP'),
#  ('маленькая', 'NNP'),
#  ('грудь', 'NNP'),
#  ('обтянута', 'NNP'),
#  ('суконной', 'NNP'),
#  ('гимнастеркой', 'NNP'),
#  (',', ','),
#  ('сжатой', 'NNP'),
#  ('в', 'NNP'),
#  ('талии', 'NNP'),
#  ('широким', 'NNP'),
#  ('ремнем', 'NNP'),
#  ('.', '.'),
#  ('Не', 'VB'),
#  ('раз', 'JJ'),
#  ('ловил', 'NNP'),
#  ('себя', 'NNP'),
#  ('Новиков', 'NNP'),
#  ('на', 'NNP'),
#  ('том', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('его', 'NNP'),
#  ('непривычно', 'NNP'),
#  ('смущала', 'NNP'),
#  ('постоянная', 'NNP'),
#  ('вызывающая', 'NNP'),
#  ('смелость', 'NNP'),
#  ('санинструктора', 'NNP'),
#  (',', ','),
#  ('—', 'NNP'),
#  ('он', 'NNP'),
#  ('почувствовал', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('покраснел', 'NNP'),
#  ('на', 'NNP'),
#  ('виду', 'NNP'),
#  ('мгновенно', 'NNP'),
#  ('притихших', 'NNP'),
#  ('солдат', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('разозленный', 'NNP'),
#  ('на', 'NNP'),
#  ('себя', 'NNP'),
#  ('за', 'NNP'),
#  ('это', 'NNP'),
#  (',', ','),
#  ('резко', 'NNP'),
#  ('сказал', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Вы', 'NNP'),
#  ('всегда', 'NNP'),
#  ('неудачно', 'NNP'),
#  ('шутите', 'NNP'),
#  (',', ','),
#  ('товарищ', 'NNP'),
#  ('санинструктор', 'NN'),
#  ('!', '.'),
#  ('—', 'NN'),
#  ('И', 'NN'),
#  (',', ','),
#  ('повернувшись', 'NNP'),
#  ('к', 'NNP'),
#  ('лейтенанту', 'NNP'),
#  ('Овчинникову', 'NNP'),
#  (',', ','),
#  ('договорил', 'NNP'),
#  ('тоном', 'NNP'),
#  ('приказа', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Прекратить', 'NN'),
#  ('!', '.'),
#  ('Что', 'JJ'),
#  ('это', 'JJ'),
#  ('за', 'NN'),
#  ('веселье', 'NN'),
#  ('?', '.'),
#  ('С', 'JJ'),
#  ('какой', 'NN'),
#  ('радости', 'NN'),
#  ('?', '.'),
#  ('Всем', 'JJ'),
#  ('отдыхать', 'NN'),
#  ('!', '.'),
#  ('Лейтенант', 'NN'),
#  ('Овчинников', 'NN'),
#  (',', ','),
#  ('самолюбиво', 'NNP'),
#  ('сузив', 'NNP'),
#  ('светло', 'NNP'),
#  ('трезвые', 'NNP'),
#  ('глаза', 'NNP'),
#  ('на', 'NNP'),
#  ('недопитый', 'NNP'),
#  ('стакан', 'NNP'),
#  (',', ','),
#  ('спросил', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('За', 'NNP'),
#  ('что', 'NNP'),
#  ('вы', 'NNP'),
#  (',', ','),
#  ('товарищ', 'NNP'),
#  ('капитан', 'NNP'),
#  ('?', '.'),
#  ('Мой', 'NNP'),
#  ('день', 'NNP'),
#  ('рождения', 'NNP'),
#  ('.', '.'),
#  ('Не', 'VB'),
#  ('признаете', 'NN'),
#  ('?', '.'),
#  ('Двадцать', 'JJ'),
#  ('шесть', 'NN'),
#  ('стукнуло', 'NNP'),
#  ('.', '.'),
#  ('Лягалов', 'NN'),
#  (',', ','),
#  ('налей', 'NNP'),
#  ('комбату', 'NN'),
#  ('!', '.'),
#  ('Ломанем', 'NN'),
#  (',', ','),
#  ('товарищ', 'NNP'),
#  ('капитан', 'NNP'),
#  ('?', '.'),
#  ('..', 'NNP'),
#  ('Чтоб', 'NNP'),
#  ('пыль', 'NNP'),
#  ('на', 'NNP'),
#  ('всю', 'NNP'),
#  ('Европу', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('?', '.'),
#  ('Замковый', 'NNP'),
#  ('Лягалов', 'NNP'),
#  (',', ','),
#  ('солдат', 'NNP'),
#  ('пожилой', 'NNP'),
#  (',', ','),
#  ('некрасивый', 'NNP'),
#  (',', ','),
#  ('низкорослый', 'NNP'),
#  (',', ','),
#  ('обросший', 'NNP'),
#  ('золотистой', 'NNP'),
#  ('щетинкой', 'NNP'),
#  ('на', 'NNP'),
#  ('худых', 'NNP'),
#  ('щеках', 'NNP'),
#  (',', ','),
#  ('помигал', 'NNP'),
#  ('конфузливо', 'NNP'),
#  ('на', 'NNP'),
#  ('Овчинникова', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('комбата', 'NNP'),
#  (',', ','),
#  ('неуверенно', 'NNP'),
#  ('налил', 'NNP'),
#  ('из', 'NNP'),
#  ('фляги', 'NNP'),
#  ('полную', 'NNP'),
#  ('кружку', 'NNP'),
#  (',', ','),
#  ('протянул', 'NNP'),
#  ('Новикову', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Товарищ', 'NNP'),
#  ('капитан', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('побрезгуйте', 'NNP'),
#  (',', ','),
#  ('стадо', 'NNP'),
#  ('быть…', 'NNP'),
#  ('Чистая-а', 'JJ'),
#  ('!', '.'),
#  ('Считался', 'JJ'),
#  ('Лягалов', 'NNP'),
#  ('непьющим', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('то', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('он', 'NNP'),
#  ('пил', 'NNP'),
#  ('сейчас', 'NNP'),
#  ('и', 'NNP'),
#  ('протягивал', 'NNP'),
#  ('кружку', 'NNP'),
#  (',', ','),
#  ('вконец', 'NNP'),
#  ('испортило', 'NNP'),
#  ('настроение', 'NNP'),
#  ('Новикову', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('оттолкнул', 'JJ'),
#  ('руку', 'NNP'),
#  ('Лягалова', 'NNP'),
#  (',', ','),
#  ('криво', 'NNP'),
#  ('усмехнулся', 'NN'),
#  (':', ':'),
#  ('—', 'JJ'),
#  ('Поздравляю', 'NN'),
#  ('.', '.'),
#  ('—', 'JJ'),
#  ('И', 'NN'),
#  (',', ','),
#  ('ссутулившись', 'NNP'),
#  (',', ','),
#  ('шагнул', 'NNP'),
#  ('к', 'NNP'),
#  ('двери', 'NNP'),
#  ...]

# %%
# lemmatized = []
# for word, tag in tagged:
#     if tag == None:
#         lemmatized.append(lemm.lemmatize(word))
#     else:
#         lemmatized.append(lemm.lemmatize(word, tag))
# lemmatized

# %%
stemmer = SnowballStemmer(language='russian')
with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
tokenized = nltk.word_tokenize(text)
stemmed = [stemmer.stem(word) for word in tokenized]
stemmed
# Out:
# ['1',
#  'глав',
#  'завеща',
#  'в',
#  'то',
#  'жизн',
#  'вам',
#  'счастлив',
#  'быт',
#  'и',
#  'родим',
#  'отчизн',
#  'с',
#  'чест',
#  'дальш',
#  'служ',
#  '.',
#  'горева',
#  '—',
#  'горделив',
#  ',',
#  'не',
#  'клон',
#  'голов',
#  '.',
#  'ликова',
#  '—',
#  'не',
#  'хвастлив',
#  'в',
#  'час',
#  'побед',
#  'сам',
#  '.',
#  'и',
#  'береч',
#  'е',
#  'свят',
#  ',',
#  'брат',
#  ',',
#  'счаст',
#  'сво',
#  '—',
#  'в',
#  'памя',
#  'воина-брат',
#  ',',
#  'что',
#  'погиб',
#  'за',
#  'не',
#  '.',
#  'а.',
#  'твардовск',
#  'в',
#  'двенадцат',
#  'час',
#  'ноч',
#  'капита',
#  'новик',
#  'проверя',
#  'пост',
#  '.',
#  'он',
#  'шел',
#  'по',
#  'высот',
#  'в',
#  'черн',
#  'осен',
#  'тьме',
#  ',',
#  'над',
#  'голов',
#  'густ',
#  'шумел',
#  'вершин',
#  'сос',
#  '.',
#  'остр',
#  'северн',
#  'холод',
#  'дул',
#  'с',
#  'карпат',
#  ',',
#  'вся',
#  'высот',
#  'гудел',
#  ',',
#  'точн',
#  'гулк',
#  'вибрирова',
#  'под',
#  'непрерывн',
#  'удар',
#  'воздушн',
#  'поток',
#  '.',
#  'пахл',
#  'снег',
#  '.',
#  'редк',
#  'ракет',
#  'извива',
#  'над',
#  'немецк',
#  'передов',
#  ',',
#  'сносим',
#  'ветр',
#  ',',
#  'догора',
#  'за',
#  'темн',
#  'полукруж',
#  'соседн',
#  'высот',
#  '.',
#  'в',
#  'низин',
#  'справ',
#  ',',
#  'где',
#  'лежа',
#  'польск',
#  'город',
#  'касн',
#  ',',
#  'беззвучн',
#  'вспыхива',
#  ',',
#  'гасл',
#  'неопределен',
#  'свет',
#  ',',
#  'как',
#  'будт',
#  'задува',
#  'их',
#  '.',
#  'молча',
#  'пулемет',
#  '.',
#  'новик',
#  'не',
#  'видел',
#  'в',
#  'темнот',
#  'ни',
#  'оруд',
#  ',',
#  'ни',
#  'часов',
#  ',',
#  'шел',
#  '—',
#  'рук',
#  'в',
#  'карман',
#  ',',
#  'ветер',
#  'неистов',
#  'трепа',
#  'пол',
#  'шинел',
#  ',',
#  '—',
#  'и',
#  'стран',
#  'чувств',
#  'тоск',
#  ',',
#  'глух',
#  'затерян',
#  'в',
#  'эт',
#  'мрачн',
#  ',',
#  'холодн',
#  'карпат',
#  'охватыва',
#  'ег',
#  '.',
#  'приступ',
#  'тоск',
#  'появля',
#  'в',
#  'последн',
#  'недел',
#  'не',
#  'раз',
#  '—',
#  'и',
#  'всегд',
#  'ноч',
#  ',',
#  'в',
#  'коротк',
#  'затиш',
#  ',',
#  'и',
#  'объясня',
#  'главн',
#  'образ',
#  'тем',
#  ',',
#  'что',
#  'четыр',
#  'дня',
#  'назад',
#  ',',
#  'при',
#  'взят',
#  'город',
#  'касн',
#  ',',
#  'батаре',
#  'новиков',
#  'вперв',
#  'потеря',
#  'девя',
#  'человек',
#  'сраз',
#  ',',
#  'в',
#  'том',
#  'числ',
#  'командир',
#  'взвод',
#  'управлен',
#  ',',
#  'и',
#  'новик',
#  'не',
#  'мог',
#  'прост',
#  'себ',
#  'эт',
#  '.',
#  '—',
#  'часов',
#  '!',
#  '—',
#  'строг',
#  'окликнул',
#  'новик',
#  ',',
#  'останавлив',
#  ',',
#  'по',
#  'звук',
#  'голос',
#  'угадыв',
#  'вперед',
#  'землянк',
#  'перв',
#  'взвод',
#  ',',
#  'вырыт',
#  'в',
#  'скат',
#  'высот',
#  '.',
#  'ответ',
#  'не',
#  'был',
#  '.',
#  '—',
#  'часов',
#  '!',
#  '—',
#  'повтор',
#  'он',
#  'громч',
#  '.',
#  '—',
#  'а',
#  '?',
#  'что-т',
#  'черн',
#  'завоз',
#  ',',
#  'шурш',
#  'плащ-палатк',
#  ',',
#  'возл',
#  'вход',
#  'в',
#  'землянк',
#  ',',
#  'голос',
#  'из',
#  'темнот',
#  'отозва',
#  'сдавлен',
#  ':',
#  '—',
#  'а',
#  '!',
#  'кто',
#  'тут',
#  '?',
#  '—',
#  'что',
#  'эт',
#  'за',
#  '«',
#  'а',
#  '»',
#  '?',
#  'черт',
#  'бы',
#  'драл',
#  '!',
#  '—',
#  'выруга',
#  'новик',
#  '.',
#  '—',
#  'в',
#  'прятк',
#  'игра',
#  '?',
#  '—',
#  'сто',
#  '!',
#  'кто',
#  'идет',
#  '?',
#  '—',
#  'преувеличен',
#  'грозн',
#  'выкрикнул',
#  'часов',
#  'и',
#  'щелкнул',
#  'затвор',
#  'автомат',
#  '.',
#  '—',
#  'проснул',
#  '?',
#  'что',
#  'там',
#  'за',
#  'колготн',
#  'в',
#  'землянк',
#  '?',
#  '—',
#  'спрос',
#  'новик',
#  'недовольн',
#  'тон',
#  '.',
#  '—',
#  'что',
#  'молч',
#  '?',
#  '—',
#  'овчинник',
#  'чегой-т',
#  'шум',
#  ',',
#  'товарищ',
#  'капита',
#  ',',
#  '—',
#  'робк',
#  'кашлянув',
#  ',',
#  'забормота',
#  'часов',
#  '.',
#  '—',
#  'и',
#  'чег',
#  'он',
#  'разоря',
#  '?',
#  'новик',
#  'толкнул',
#  'двер',
#  'в',
#  'землянк',
#  '.',
#  'плотн',
#  'гул',
#  'голос',
#  'колыха',
#  'под',
#  'низк',
#  'накат',
#  '.',
#  'сред',
#  'дым',
#  'плава',
#  'фиолетов',
#  'огн',
#  'немецк',
#  'плошек',
#  ',',
#  'мутн',
#  'проступа',
#  'за',
#  'стол',
#  'и',
#  'на',
#  'нар',
#  'красно-багров',
#  'лиц',
#  'солдат',
#  '—',
#  'все',
#  'говор',
#  'раз',
#  ',',
#  'нещадн',
#  'кур',
#  '.',
#  'командир',
#  'перв',
#  'взвод',
#  'лейтенант',
#  'овчинник',
#  ',',
#  'с',
#  'тонк',
#  ',',
#  'красив',
#  ',',
#  'самолюбив',
#  'ртом',
#  ',',
#  'удар',
#  'кулак',
#  'по',
#  'стол',
#  ',',
#  'покачив',
#  ',',
#  'встал',
#  ',',
#  'зат',
#  ',',
#  'небрежн',
#  'оттолкнув',
#  'на',
#  'бедр',
#  'тяжел',
#  'кобур',
#  'пистолет',
#  ',',
#  'скомандова',
#  ':',
#  'сипл',
#  'и',
#  'властн',
#  ':',
#  '—',
#  'прекрат',
#  'галдеж',
#  'и',
#  'слуша',
#  'тост',
#  '!',
#  'за',
#  'леночк',
#  '!',
#  'а',
#  ',',
#  'братц',
#  '?',
#  'пит',
#  'всем',
#  '!',
#  'смутн',
#  'рев',
#  'голос',
#  'ответ',
#  'ем',
#  'и',
#  'стих',
#  ':',
#  'все',
#  'увидел',
#  'молч',
#  'стоя',
#  'в',
#  'двер',
#  'капита',
#  'новиков',
#  '.',
#  'он',
#  'медлен',
#  'обвел',
#  'взгляд',
#  'лиц',
#  'солдат',
#  '.',
#  '—',
#  'знач',
#  ',',
#  'пыл',
#  'столб',
#  '?',
#  '—',
#  'произнес',
#  'он',
#  ',',
#  'хмур',
#  '.',
#  '—',
#  'и',
#  'санинструктор',
#  'зде',
#  '?',
#  'то',
#  ',',
#  'что',
#  'весел',
#  'эт',
#  'происход',
#  'в',
#  'восьмист',
#  'метр',
#  'от',
#  'немецк',
#  'передов',
#  'и',
#  'люд',
#  ',',
#  'зна',
#  'эт',
#  ',',
#  'не',
#  'сдержива',
#  'себ',
#  ',',
#  'не',
#  'удив',
#  'новиков',
#  '.',
#  'удив',
#  'то',
#  ',',
#  'что',
#  'зде',
#  ',',
#  'сред',
#  'едк',
#  'махорочн',
#  'дым',
#  ',',
#  'сред',
#  'эт',
#  'нетрезв',
#  'шум',
#  ',',
#  'сидел',
#  'на',
#  'нар',
#  'санинструктор',
#  'лен',
#  'колосков',
#  '.',
#  'сидел',
#  'он',
#  ',',
#  'охват',
#  'рук',
#  'колен',
#  'и',
#  'покачив',
#  'взад',
#  'и',
#  'вперед',
#  ',',
#  'разговарива',
#  'с',
#  'умилен',
#  'распл',
#  'замков',
#  'лягалов',
#  ',',
#  'смея',
#  'тих',
#  ',',
#  'трудн',
#  ',',
#  'ласков',
#  'смех',
#  '.',
#  '«',
#  'смеет',
#  'каким-т',
#  'жемчужн',
#  'смех',
#  ',',
#  '—',
#  'не',
#  'без',
#  'раздражен',
#  'подума',
#  'новик',
#  '.',
#  '—',
#  'он',
#  'пьян',
#  'ил',
#  'хочет',
#  'понрав',
#  'лейтенант',
#  'овчинников',
#  '.',
#  'зач',
#  'е',
#  'эт',
#  '?',
#  '»',
#  'и',
#  ',',
#  'стар',
#  'ещ',
#  'бол',
#  'возбуд',
#  'в',
#  'себ',
#  'неприязн',
#  'к',
#  'эт',
#  'легкомыслен',
#  'смех',
#  ',',
#  'он',
#  'быстр',
#  'взглянул',
#  'на',
#  'не',
#  ',',
#  'пот',
#  'на',
#  'овчинников',
#  ',',
#  'спрос',
#  ':',
#  '—',
#  'что',
#  'у',
#  'вас',
#  'тут',
#  '?',
#  'свадьб',
#  '?',
#  '..',
#  'он',
#  'произнес',
#  'эт',
#  ',',
#  'должн',
#  'быт',
#  ',',
#  'груб',
#  '—',
#  'все',
#  'замолча',
#  '.',
#  'лен',
#  'вопросительн',
#  'перевел',
#  'на',
#  'нег',
#  'взгляд',
#  'и',
#  'вдруг',
#  'легк',
#  'и',
#  'гибк',
#  'спрыгнул',
#  'с',
#  'нар',
#  ',',
#  'взял',
#  'со',
#  'стол',
#  'чей-т',
#  'стака',
#  ',',
#  'подошл',
#  'к',
#  'новиков',
#  ',',
#  'блест',
#  'ярк',
#  ',',
#  'чут',
#  'прищурен',
#  ',',
#  'улыба',
#  'глаз',
#  '.',
#  '—',
#  'да',
#  ',',
#  'имен',
#  ',',
#  '—',
#  'сказа',
#  ',',
#  'откидыв',
#  'голов',
#  ',',
#  '—',
#  'зде',
#  'свадьб',
#  '.',
#  'поздравьт',
#  'мен',
#  'и',
#  'овчинников',
#  '.',
#  'лейтенант',
#  'овчинник',
#  '!',
#  '—',
#  'приказа',
#  'он',
#  '.',
#  '—',
#  'дайт',
#  'водк',
#  'капитан',
#  '!',
#  '«',
#  'что',
#  'эт',
#  'с',
#  'не',
#  '?',
#  '»',
#  'он',
#  'не',
#  'был',
#  'пьян',
#  ',',
#  'кажет',
#  '(',
#  'а',
#  'вообщ',
#  'не',
#  'поймеш',
#  '!',
#  ')',
#  ',',
#  'и',
#  'дерзк',
#  'глядел',
#  'на',
#  'нег',
#  'сниз',
#  'вверх',
#  ',',
#  '—',
#  'тонк',
#  'нежн',
#  'ше',
#  'окаймл',
#  'ворот',
#  ',',
#  'узк',
#  'плеч',
#  ',',
#  'крепк',
#  'маленьк',
#  'груд',
#  'обтянут',
#  'сукон',
#  'гимнастерк',
#  ',',
#  'сжат',
#  'в',
#  'тал',
#  'широк',
#  'ремн',
#  '.',
#  'не',
#  'раз',
#  'лов',
#  'себ',
#  'новик',
#  'на',
#  'том',
#  ',',
#  'что',
#  'ег',
#  'непривычн',
#  'смуща',
#  'постоя',
#  'вызыва',
#  'смелост',
#  'санинструктор',
#  ',',
#  '—',
#  'он',
#  'почувствова',
#  ',',
#  'что',
#  'покраснел',
#  'на',
#  'вид',
#  'мгновен',
#  'притихш',
#  'солдат',
#  ',',
#  'и',
#  ',',
#  'разозлен',
#  'на',
#  'себ',
#  'за',
#  'эт',
#  ',',
#  'резк',
#  'сказа',
#  ':',
#  '—',
#  'вы',
#  'всегд',
#  'неудачн',
#  'шут',
#  ',',
#  'товарищ',
#  'санинструктор',
#  '!',
#  '—',
#  'и',
#  ',',
#  'повернувш',
#  'к',
#  'лейтенант',
#  'овчинников',
#  ',',
#  'договор',
#  'тон',
#  'приказ',
#  ':',
#  '—',
#  'прекрат',
#  '!',
#  'что',
#  'эт',
#  'за',
#  'весел',
#  '?',
#  'с',
#  'как',
#  'радост',
#  '?',
#  'всем',
#  'отдыха',
#  '!',
#  'лейтенант',
#  'овчинник',
#  ',',
#  'самолюбив',
#  'суз',
#  'светл',
#  'трезв',
#  'глаз',
#  'на',
#  'недопит',
#  'стака',
#  ',',
#  'спрос',
#  ':',
#  '—',
#  'за',
#  'что',
#  'вы',
#  ',',
#  'товарищ',
#  'капита',
#  '?',
#  'мо',
#  'ден',
#  'рожден',
#  '.',
#  'не',
#  'призна',
#  '?',
#  'двадца',
#  'шест',
#  'стукнул',
#  '.',
#  'лягал',
#  ',',
#  'нал',
#  'комбат',
#  '!',
#  'ломан',
#  ',',
#  'товарищ',
#  'капита',
#  '?',
#  '..',
#  'чтоб',
#  'пыл',
#  'на',
#  'всю',
#  'европ',
#  ',',
#  'а',
#  '?',
#  'замков',
#  'лягал',
#  ',',
#  'солдат',
#  'пожил',
#  ',',
#  'некрасив',
#  ',',
#  'низкоросл',
#  ',',
#  'обросш',
#  'золотист',
#  'щетинк',
#  'на',
#  'худ',
#  'щек',
#  ',',
#  'помига',
#  'конфузлив',
#  'на',
#  'овчинников',
#  ',',
#  'на',
#  'комбат',
#  ',',
#  'неуверен',
#  'нал',
#  'из',
#  'фляг',
#  'полн',
#  'кружк',
#  ',',
#  'протянул',
#  'новиков',
#  ':',
#  '—',
#  'товарищ',
#  'капита',
#  ',',
#  'не',
#  'побрезг',
#  ',',
#  'стад',
#  'быть…',
#  'чистая-',
#  '!',
#  'счита',
#  'лягал',
#  'непьющ',
#  ',',
#  'и',
#  'то',
#  ',',
#  'что',
#  'он',
#  'пил',
#  'сейчас',
#  'и',
#  'протягива',
#  'кружк',
#  ',',
#  'вконец',
#  'испорт',
#  'настроен',
#  'новиков',
#  '.',
#  'он',
#  'оттолкнул',
#  'рук',
#  'лягалов',
#  ',',
#  'крив',
#  'усмехнул',
#  ':',
#  '—',
#  'поздравля',
#  '.',
#  '—',
#  'и',
#  ',',
#  'ссутул',
#  ',',
#  'шагнул',
#  'к',
#  'двер',
#  ...]

# %%
SnowballStemmer(language="russian")

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
    
type(text)
#morph.parse(text, language='russian')
# Out:
# str

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
tokenized = nltk.word_tokenize(text)
tokenized
morph.parse(text)
# Out:
# [Parse(word='1 глава\nзавещаю в той жизни\n\nвам счастливыми быть\n\nи родимой отчизне\n\nс честью дальше служить.\n\nгоревать — горделиво,\n\nне клонясь головой.\n\nликовать — не хвастливо\n\nв час победы самой.\n\nи беречь ее свято,\n\nбратья, счастье свое —\n\nв память воина-брата,\n\nчто погиб за нее.\n\nа. твардовский\nв двенадцатом часу ночи капитан новиков проверял посты.\n\nон шел по высоте в черной осенней тьме, над головой густо шумели вершины сосен. острым северным холодом дуло с карпат, вся высота гудела, точно гулко вибрировала под непрерывными ударами воздушных потоков. пахло снегом.\n\nредкие ракеты извивались над немецкой передовой, сносимые ветром, догорали за темным полукружьем соседней высоты. в низине справа, где лежал польский город касно, беззвучно вспыхивали, гасли неопределенные светы, как будто задувало их.\n\nмолчали пулеметы.\n\nновиков не видел в темноте ни орудия, ни часовых, шел — руки в карманах, ветер неистово трепал полы шинели, — и странное чувство тоски, глухой затерянности в этих мрачных, холодных карпатах охватывало его. приступы тоски появлялись в последнюю неделю не раз — и всегда ночью, в короткие затишья, и объяснялись главным образом тем, что четыре дня назад, при взятии города касно, батарея новикова впервые потеряла девять человек сразу, в том числе командира взвода управления, и новиков не мог простить себе этого.\n\n— часовой! — строго окликнул новиков, останавливаясь, по звуку голосов угадывая впереди землянку первого взвода, вырытую в скате высоты.\n\nответа не было.\n\n— часовой! — повторил он громче.\n\n— а?\n\nчто-то черное завозилось, шурша плащ-палаткой, возле входа в землянку, голос из темноты отозвался сдавленно:\n\n— а! кто тут?\n\n— что это за «а»? черт бы драл! — выругался новиков. — в прятки играете?\n\n— стой! кто идет? — преувеличенно грозно выкрикнул часовой и щелкнул затвором автомата.\n\n— проснулись? что там за колготня в землянке? — спросил новиков недовольным тоном. — что молчите?\n\n— овчинников чегой-то шумит, товарищ капитан, — робко кашлянув, забормотал часовой. — и чего они разоряются?\n\nновиков толкнул дверь в землянку.\n\nплотный гул голосов колыхался под низкими накатами. среди дыма плавали фиолетовые огни немецких плошек, мутно проступали за столом и на нарах красно-багровые лица солдат — все говорили разом, нещадно курили. командир первого взвода лейтенант овчинников, с тонким, красивым, самолюбивым ртом, ударил кулаком по столу, покачиваясь, встал, затем, небрежно оттолкнув на бедре тяжелую кобуру пистолета, скомандовал: сипло и властно:\n\n— прекратить галдеж и слушай тост! за леночку! а, братцы? пить всем!\n\nсмутный рев голосов ответил ему и стих: все увидели молча стоявшего в дверях капитана новикова. он медленно обвел взглядом лица солдат.\n\n— значит, пыль столбом? — произнес он, хмурясь. — и санинструктор здесь?\n\nто, что веселье это происходило в восьмистах метрах от немецкой передовой и люди, зная это, не сдерживали себя, не удивило новикова. удивило то, что здесь, среди едкого махорочного дыма, среди этого нетрезвого шума, сидела на нарах санинструктор лена колоскова. сидела она, охватив руками колени и покачиваясь взад и вперед, разговаривала с умиленно расплывшимся замковым лягаловым, смеялась тихим, трудным, ласковым смехом.\n\n«смеется каким-то жемчужным смехом, — не без раздражения подумал новиков. — она пьяна или хочет понравиться лейтенанту овчинникову. зачем ей это?» и, стараясь еще более возбудить в себе неприязнь к этому легкомысленному смеху, он быстро взглянул на нее, потом на овчинникова, спросил:\n\n— что у вас тут? свадьба?..\n\nон произнес это, должно быть, грубо — все замолчали. лена вопросительно перевела на него взгляд и вдруг легко и гибко спрыгнула с нар, взяла со стола чей-то стакан, подошла к новикову, блестя яркими, чуть прищуренными, улыбающимися глазами.\n\n— да, именно, — сказала, откидывая голову, — здесь свадьба. поздравьте меня и овчинникова. лейтенант овчинников! — приказала она. — дайте водки капитану!\n\n« ...

# %%
morph = pymorphy2.MorphAnalyzer()
text='завещаю'
morph.parse(text)
# Out:
# [Parse(word='завещаю', tag=OpencorporaTag('VERB,perf,tran sing,1per,futr,indc'), normal_form='завещать', score=0.5, methods_stack=((DictionaryAnalyzer(), 'завещаю', 703, 5),)),
#  Parse(word='завещаю', tag=OpencorporaTag('VERB,impf,tran sing,1per,pres,indc'), normal_form='завещать', score=0.5, methods_stack=((DictionaryAnalyzer(), 'завещаю', 703, 15),))]

# %%
text_1='служить'
morph.parse(text_1)
# Out:
# [Parse(word='служить', tag=OpencorporaTag('INFN,impf,tran'), normal_form='служить', score=1.0, methods_stack=((DictionaryAnalyzer(), 'служить', 2899, 0),))]

# %%
morph.parse('снарядов')
# Out:
# [Parse(word='снарядов', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='снаряд', score=1.0, methods_stack=((DictionaryAnalyzer(), 'снарядов', 34, 7),))]

# %%
morph.parse('бруствере')
# Out:
# [Parse(word='бруствере', tag=OpencorporaTag('NOUN,inan,masc sing,loct'), normal_form='бруствер', score=1.0, methods_stack=((DictionaryAnalyzer(), 'бруствере', 300, 5),))]

# %%
morph.parse('орудия')
# Out:
# [Parse(word='орудия', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='орудие', score=0.729729, methods_stack=((DictionaryAnalyzer(), 'орудия', 77, 2),)),
#  Parse(word='орудия', tag=OpencorporaTag('NOUN,inan,neut plur,nomn'), normal_form='орудие', score=0.243243, methods_stack=((DictionaryAnalyzer(), 'орудия', 77, 13),)),
#  Parse(word='орудия', tag=OpencorporaTag('NOUN,inan,neut plur,accs'), normal_form='орудие', score=0.027027, methods_stack=((DictionaryAnalyzer(), 'орудия', 77, 18),))]

# %%
morph.parse('капитан')
# Out:
# [Parse(word='капитан', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='капитан', score=1.0, methods_stack=((DictionaryAnalyzer(), 'капитан', 52, 0),))]

# %%
morph.parse('сузив')
# Out:
# [Parse(word='сузив', tag=OpencorporaTag('GRND,perf,tran past'), normal_form='сузить', score=1.0, methods_stack=((DictionaryAnalyzer(), 'сузив', 860, 69),))]

# %%
m=Mystem()
m.analyze('1 Глава Завещаю в той жизни Вам счастливыми быть И родимой Отчизне С честью дальше служить. Горевать — горделиво, Не клонясь головой. Ликовать — не хвастливоВ час победы самой. И беречь ее свято, Братья, счастье свое — В память воина-брата, Что погиб за нее.')
# Out:
# Installing mystem to C:\Users\Дима Титаренко/.local/bin\mystem.exe from http://download.cdn.yandex.net/mystem/mystem-3.1-win-64bit.zip
# [{'text': '1'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'главазавещать',
#     'wt': 1,
#     'qual': 'bastard',
#     'gr': 'V,пе=(непрош,ед,изъяв,1-л,несов|непрош,ед,изъяв,1-л,сов)'}],
#   'text': 'ГлаваЗавещаю'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тот',
#     'wt': 0.9998024292,
#     'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)'}],
#   'text': 'той'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'жизнь',
#     'wt': 1,
#     'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}],
#   'text': 'жизни'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вы', 'wt': 1, 'gr': 'SPRO,мн,2-л=дат'}],
#   'text': 'Вам'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'счастливый', 'wt': 1, 'gr': 'A=твор,мн,полн'}],
#   'text': 'счастливыми'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'быть', 'wt': 1, 'gr': 'V,нп=инф,несов'}],
#   'text': 'быть'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'И'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'родимый',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'родимой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'отчизна', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'Отчизне'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'с', 'wt': 0.999977831, 'gr': 'PR='}], 'text': 'С'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'честь', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'честью'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'далеко', 'wt': 0.9853805472, 'gr': 'ADV=срав'}],
#   'text': 'дальше'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'служить', 'wt': 1, 'gr': 'V,несов,пе=инф'}],
#   'text': 'служить'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'горевать', 'wt': 1, 'gr': 'V,несов,нп=инф'}],
#   'text': 'Горевать'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'горделиво', 'wt': 0.9888980944, 'gr': 'ADV='}],
#   'text': 'горделиво'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'не', 'wt': 1, 'gr': 'PART='}], 'text': 'Не'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'клониться', 'wt': 1, 'gr': 'V,несов,нп=непрош,деепр'}],
#   'text': 'клонясь'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'голова',
#     'wt': 0.999760014,
#     'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'головой'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'ликовать', 'wt': 1, 'gr': 'V,несов,нп=инф'}],
#   'text': 'Ликовать'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'не', 'wt': 1, 'gr': 'PART='}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'хвастлив',
#     'wt': 1,
#     'qual': 'bastard',
#     'gr': 'S,муж,неод=род,мн'}],
#   'text': 'хвастливоВ'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'час', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'час'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'победа',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'победы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'самый',
#     'wt': 0.7116324335,
#     'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)'}],
#   'text': 'самой'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'И'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'беречь', 'wt': 1, 'gr': 'V,несов,пе=инф'}],
#   'text': 'беречь'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'она',
#     'wt': 0.9999876545,
#     'gr': 'SPRO,ед,3-л,жен=(вин|род)'}],
#   'text': 'ее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'святой', 'wt': 1, 'gr': 'A=ед,кр,сред'}],
#   'text': 'свято'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'брат', 'wt': 0.9991304413, 'gr': 'S,муж,од=им,мн'}],
#   'text': 'Братья'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'счастие',
#     'wt': 1,
#     'gr': 'S,сред,неод=(пр,ед|вин,ед|им,ед)'}],
#   'text': 'счастье'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'свой',
#     'wt': 0.9940018867,
#     'gr': 'APRO=(вин,ед,сред|им,ед,сред)'}],
#   'text': 'свое'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'В'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'память', 'wt': 1, 'gr': 'S,жен,неод=(вин,ед|им,ед)'}],
#   'text': 'память'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'воин', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}],
#   'text': 'воина'},
#  {'text': '-'},
#  {'analysis': [{'lex': 'брат', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}],
#   'text': 'брата'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'что', 'wt': 0.688532576, 'gr': 'CONJ='}],
#   'text': 'Что'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'погибать',
#     'wt': 0.9970774786,
#     'gr': 'V,нп=прош,ед,изъяв,муж,сов'}],
#   'text': 'погиб'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'за', 'wt': 1, 'gr': 'PR='}], 'text': 'за'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'она',
#     'wt': 0.9999228494,
#     'gr': 'SPRO,ед,3-л,жен=(вин|род)'}],
#   'text': 'нее'},
#  {'text': '.'},
#  {'text': '\n'}]

# %%
m=Mystem()
m.analyze('В двенадцатом часу ночи капитан Новиков проверял посты. Он шел по высоте в черной осенней тьме, над головой густо шумели вершины сосен. Острым северным холодом дуло с Карпат, вся высота гудела, точно гулко вибрировала под непрерывными ударами воздушных потоков. Пахло снегом. Редкие ракеты извивались над немецкой передовой, сносимые ветром, догорали за темным полукружьем соседней высоты. В низине справа, где лежал польский город Касно, беззвучно вспыхивали, гасли неопределенные светы, как будто задувало их. Молчали пулеметы. Новиков не видел в темноте ни орудия, ни часовых, шел — руки в карманах, ветер неистово трепал полы шинели, — и странное чувство тоски, глухой затерянности в этих мрачных, холодных Карпатах охватывало его. Приступы тоски появлялись в последнюю неделю не раз — и всегда ночью, в короткие затишья, и объяснялись главным образом тем, что четыре дня назад, при взятии города Касно, батарея Новикова впервые потеряла девять человек сразу, в том числе командира взвода управления, и Новиков не мог простить себе этого. — Часовой! — строго окликнул Новиков, останавливаясь, по звуку голосов угадывая впереди землянку первого взвода, вырытую в скате высоты. Ответа не было. — Часовой! — повторил он громче. — А? Что-то черное завозилось, шурша плащ-палаткой, возле входа в землянку, голос из темноты отозвался сдавленно: — А! Кто тут? — Что это за «а»? Черт бы драл! — выругался Новиков. — В прятки играете? — Стой! Кто идет? — преувеличенно грозно выкрикнул часовой и щелкнул затвором автомата.')
# Out:
# [{'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'В'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'двенадцатый',
#     'wt': 1,
#     'gr': 'ANUM=(пр,ед,муж|пр,ед,сред)'}],
#   'text': 'двенадцатом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'час',
#     'wt': 1,
#     'gr': 'S,муж,неод=(дат,ед|парт,ед|местн,ед)'}],
#   'text': 'часу'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ночь',
#     'wt': 1,
#     'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн|местн,ед)'}],
#   'text': 'ночи'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'капитан', 'wt': 1, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'капитан'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'новиков',
#     'wt': 0.9926376892,
#     'gr': 'S,фам,муж,од=им,ед'}],
#   'text': 'Новиков'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'проверять',
#     'wt': 1,
#     'gr': 'V,пе=прош,ед,изъяв,муж,несов'}],
#   'text': 'проверял'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пост', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#   'text': 'посты'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'он', 'wt': 1, 'gr': 'SPRO,ед,3-л,муж=им'}],
#   'text': 'Он'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'идти', 'wt': 1, 'gr': 'V,несов,нп=прош,ед,изъяв,муж'}],
#   'text': 'шел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'по', 'wt': 1, 'gr': 'PR='}], 'text': 'по'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'высота', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'высоте'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'черный',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'черной'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'осенний',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'осенней'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тьма', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'тьме'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'над', 'wt': 0.9999998394, 'gr': 'PR='}],
#   'text': 'над'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'голова',
#     'wt': 0.999760014,
#     'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'головой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'густо', 'wt': 0.9060006608, 'gr': 'ADV='}],
#   'text': 'густо'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'шуметь', 'wt': 1, 'gr': 'V,несов,нп=прош,мн,изъяв'}],
#   'text': 'шумели'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вершина',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'вершины'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сосна',
#     'wt': 0.9990704965,
#     'gr': 'S,жен,неод=род,мн'}],
#   'text': 'сосен'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'острый',
#     'wt': 1,
#     'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}],
#   'text': 'Острым'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'северный',
#     'wt': 1,
#     'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}],
#   'text': 'северным'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'холод', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}],
#   'text': 'холодом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дуло',
#     'wt': 0.6081028818,
#     'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'дуло'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'с', 'wt': 0.999977831, 'gr': 'PR='}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'карпаты',
#     'wt': 0.5658046892,
#     'qual': 'bastard',
#     'gr': 'S,мн,неод=род'}],
#   'text': 'Карпат'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'весь', 'wt': 1, 'gr': 'APRO=им,ед,жен'}],
#   'text': 'вся'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'высота', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'высота'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'гудеть',
#     'wt': 1,
#     'gr': 'V,несов,нп=прош,ед,изъяв,жен'}],
#   'text': 'гудела'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'точно', 'wt': 0.5527026186, 'gr': 'ADV='}],
#   'text': 'точно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'гулко', 'wt': 0.9710459342, 'gr': 'ADV='}],
#   'text': 'гулко'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вибрировать',
#     'wt': 1,
#     'gr': 'V,несов,нп=прош,ед,изъяв,жен'}],
#   'text': 'вибрировала'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'под', 'wt': 0.9996470485, 'gr': 'PR='}],
#   'text': 'под'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'непрерывный', 'wt': 1, 'gr': 'A=твор,мн,полн'}],
#   'text': 'непрерывными'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'удар', 'wt': 1, 'gr': 'S,муж,неод=твор,мн'}],
#   'text': 'ударами'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'воздушный',
#     'wt': 1,
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'воздушных'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'поток',
#     'wt': 0.9850240209,
#     'gr': 'S,муж,неод=род,мн'}],
#   'text': 'потоков'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'пахнуть',
#     'wt': 1,
#     'gr': 'V,несов,нп=прош,ед,изъяв,сред'}],
#   'text': 'Пахло'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'снег', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}],
#   'text': 'снегом'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'редкий',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'Редкие'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ракета',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'ракеты'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'извиваться',
#     'wt': 1,
#     'gr': 'V,нп=прош,мн,изъяв,несов'}],
#   'text': 'извивались'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'над', 'wt': 0.9999998394, 'gr': 'PR='}],
#   'text': 'над'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'немецкий',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'немецкой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'передовой',
#     'wt': 0.9294190871,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'передовой'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'сносить',
#     'wt': 1,
#     'gr': 'V,несов,пе=(непрош,вин,мн,прич,полн,страд,неод|непрош,им,мн,прич,полн,страд)'}],
#   'text': 'сносимые'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ветер', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}],
#   'text': 'ветром'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'догорать', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,несов'}],
#   'text': 'догорали'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'за', 'wt': 1, 'gr': 'PR='}], 'text': 'за'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'темный',
#     'wt': 0.9999721841,
#     'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}],
#   'text': 'темным'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'полукружие', 'wt': 1, 'gr': 'S,сред,неод=твор,ед'}],
#   'text': 'полукружьем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'соседний',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'соседней'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'высота',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'высоты'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'В'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'низина', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'низине'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'справа', 'wt': 0.9957508201, 'gr': 'ADV='}],
#   'text': 'справа'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'где', 'wt': 1, 'gr': 'ADVPRO='}], 'text': 'где'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лежать',
#     'wt': 0.999830923,
#     'gr': 'V,несов,нп=прош,ед,изъяв,муж'}],
#   'text': 'лежал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'польский',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'польский'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'город', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'город'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'касный',
#     'wt': 1,
#     'qual': 'bastard',
#     'gr': 'A=ед,кр,сред'}],
#   'text': 'Касно'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'беззвучно', 'wt': 0.983101119, 'gr': 'ADV='}],
#   'text': 'беззвучно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вспыхивать',
#     'wt': 1,
#     'gr': 'V,нп=прош,мн,изъяв,несов'}],
#   'text': 'вспыхивали'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'гаснуть', 'wt': 1, 'gr': 'V,несов,нп=прош,мн,изъяв'}],
#   'text': 'гасли'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'неопределенный',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'неопределенные'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'света', 'wt': 1, 'gr': 'S,имя,жен,од=(род,ед|им,мн)'}],
#   'text': 'светы'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'как', 'wt': 0.3756069802, 'gr': 'ADVPRO='}],
#   'text': 'как'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'будто', 'wt': 0.6150145335, 'gr': 'PART='}],
#   'text': 'будто'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'задувать',
#     'wt': 1,
#     'gr': 'V,пе=прош,ед,изъяв,сред,несов'}],
#   'text': 'задувало'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'они', 'wt': 0.8863636364, 'gr': 'SPRO,мн=(вин|род)'}],
#   'text': 'их'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'молчать', 'wt': 1, 'gr': 'V,несов,нп=прош,мн,изъяв'}],
#   'text': 'Молчали'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пулемет', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#   'text': 'пулеметы'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'новиков',
#     'wt': 0.9926376892,
#     'gr': 'S,фам,муж,од=им,ед'}],
#   'text': 'Новиков'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'не', 'wt': 1, 'gr': 'PART='}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'видеть',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,муж'}],
#   'text': 'видел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'темнота', 'wt': 1, 'gr': 'S,ед,жен,неод=(пр|дат)'}],
#   'text': 'темноте'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ни', 'wt': 0.4403619901, 'gr': 'CONJ='}],
#   'text': 'ни'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'орудие',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'орудия'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'ни', 'wt': 0.4403619901, 'gr': 'CONJ='}],
#   'text': 'ни'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'часовой',
#     'wt': 0.8125570834,
#     'gr': 'S,муж,од=(пр,мн|вин,мн|род,мн)'}],
#   'text': 'часовых'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'идти', 'wt': 1, 'gr': 'V,несов,нп=прош,ед,изъяв,муж'}],
#   'text': 'шел'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'рука',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'руки'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'карман',
#     'wt': 0.9999343786,
#     'gr': 'S,муж,неод=пр,мн'}],
#   'text': 'карманах'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'ветер', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'ветер'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'неистово', 'wt': 0.9693218108, 'gr': 'ADV='}],
#   'text': 'неистово'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'трепать',
#     'wt': 0.9703075707,
#     'gr': 'V,несов,пе=прош,ед,изъяв,муж'}],
#   'text': 'трепал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пола',
#     'wt': 0.1253326963,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'полы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'шинель',
#     'wt': 1,
#     'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}],
#   'text': 'шинели'},
#  {'text': ', — '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'странный',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}],
#   'text': 'странное'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'чувство',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'чувство'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тоска',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'тоски'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'глухой',
#     'wt': 0.9230394095,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'глухой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'затерянность',
#     'wt': 1,
#     'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}],
#   'text': 'затерянности'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'этот',
#     'wt': 1,
#     'gr': 'APRO=(пр,мн|род,мн|вин,мн,од)'}],
#   'text': 'этих'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мрачный',
#     'wt': 1,
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'мрачных'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'холодный',
#     'wt': 0.9997531581,
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'холодных'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'карпаты',
#     'wt': 0.6785880402,
#     'qual': 'bastard',
#     'gr': 'S,мн,неод=пр'}],
#   'text': 'Карпатах'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'охватывать',
#     'wt': 1,
#     'gr': 'V,пе=прош,ед,изъяв,сред,несов'}],
#   'text': 'охватывало'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'он',
#     'wt': 0.9242062374,
#     'gr': 'SPRO,ед,3-л,муж=(вин|род)'}],
#   'text': 'его'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'приступ', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#   'text': 'Приступы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тоска',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'тоски'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'появляться',
#     'wt': 1,
#     'gr': 'V,нп=прош,мн,изъяв,несов'}],
#   'text': 'появлялись'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'последний', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}],
#   'text': 'последнюю'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'неделя', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'неделю'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'не', 'wt': 1, 'gr': 'PART='}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'раз',
#     'wt': 0.9278416023,
#     'gr': 'S,муж,неод=(вин,ед|род,мн|им,ед)'}],
#   'text': 'раз'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'всегда', 'wt': 1, 'gr': 'ADVPRO='}], 'text': 'всегда'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ночь',
#     'wt': 0.9985439166,
#     'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'ночью'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'короткий',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'короткие'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'затишье',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'затишья'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'объясняться',
#     'wt': 1,
#     'gr': 'V,нп=прош,мн,изъяв,несов'}],
#   'text': 'объяснялись'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'главный',
#     'wt': 0.8994633919,
#     'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}],
#   'text': 'главным'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'образ', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}],
#   'text': 'образом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'то',
#     'wt': 0.6993998155,
#     'gr': 'SPRO,ед,сред,неод=твор'}],
#   'text': 'тем'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'что', 'wt': 0.688532576, 'gr': 'CONJ='}],
#   'text': 'что'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'четыре', 'wt': 1, 'gr': 'NUM=(им|вин,неод)'}],
#   'text': 'четыре'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'день', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'дня'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'назад', 'wt': 0.9988998843, 'gr': 'ADV='}],
#   'text': 'назад'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'при', 'wt': 0.9999956493, 'gr': 'PR='}],
#   'text': 'при'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'взятие', 'wt': 1, 'gr': 'S,сред,неод=пр,ед'}],
#   'text': 'взятии'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'город',
#     'wt': 1,
#     'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'города'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'касный',
#     'wt': 1,
#     'qual': 'bastard',
#     'gr': 'A=ед,кр,сред'}],
#   'text': 'Касно'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'батарея', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'батарея'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'новиков',
#     'wt': 0.9873232849,
#     'gr': 'S,фам,муж,од=(вин,ед|род,ед)'}],
#   'text': 'Новикова'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'впервые', 'wt': 1, 'gr': 'ADV='}], 'text': 'впервые'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'потерять',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,жен'}],
#   'text': 'потеряла'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'девять', 'wt': 1, 'gr': 'NUM=(вин|им)'}],
#   'text': 'девять'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'человек',
#     'wt': 1,
#     'gr': 'S,муж,од=(вин,мн|род,мн|им,ед)'}],
#   'text': 'человек'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сразу', 'wt': 1, 'gr': 'ADV='}], 'text': 'сразу'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тот',
#     'wt': 0.2567690293,
#     'gr': 'APRO=(пр,ед,муж|пр,ед,сред)'}],
#   'text': 'том'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'число', 'wt': 1, 'gr': 'S,сред,неод=пр,ед'}],
#   'text': 'числе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'командир', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}],
#   'text': 'командира'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'взвод', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'взвода'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'управление',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'управления'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'новиков',
#     'wt': 0.9926376892,
#     'gr': 'S,фам,муж,од=им,ед'}],
#   'text': 'Новиков'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'не', 'wt': 1, 'gr': 'PART='}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мочь', 'wt': 1, 'gr': 'V,несов,нп=прош,ед,изъяв,муж'}],
#   'text': 'мог'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'прощать', 'wt': 1, 'gr': 'V=инф,сов'}],
#   'text': 'простить'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'себя', 'wt': 0.9438010556, 'gr': 'SPRO=(пр|дат)'}],
#   'text': 'себе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'это',
#     'wt': 0.5385233383,
#     'gr': 'SPRO,ед,сред,неод=род'}],
#   'text': 'этого'},
#  {'text': '. '},
#  {'text': '— '},
#  {'analysis': [{'lex': 'часовой', 'wt': 0.7012682282, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'Часовой'},
#  {'text': '!'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'строго', 'wt': 0.9921210623, 'gr': 'ADV='}],
#   'text': 'строго'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'окликать',
#     'wt': 1,
#     'gr': 'V,пе=прош,ед,изъяв,муж,сов'}],
#   'text': 'окликнул'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'новиков',
#     'wt': 0.9926376892,
#     'gr': 'S,фам,муж,од=им,ед'}],
#   'text': 'Новиков'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'останавливаться',
#     'wt': 1,
#     'gr': 'V,нп=непрош,деепр,несов'}],
#   'text': 'останавливаясь'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'по', 'wt': 1, 'gr': 'PR='}], 'text': 'по'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'звук', 'wt': 1, 'gr': 'S,муж,неод=дат,ед'}],
#   'text': 'звуку'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'голос', 'wt': 1, 'gr': 'S,муж,неод=род,мн'}],
#   'text': 'голосов'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'угадывать', 'wt': 1, 'gr': 'V,пе=непрош,деепр,несов'}],
#   'text': 'угадывая'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'впереди', 'wt': 0.2500867277, 'gr': 'PR='}],
#   'text': 'впереди'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'землянка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'землянку'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'первый',
#     'wt': 0.9947747557,
#     'gr': 'ANUM=(вин,ед,муж,од|род,ед,муж|род,ед,сред)'}],
#   'text': 'первого'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'взвод', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'взвода'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'вырыть',
#     'wt': 0,
#     'gr': 'V,сов=прош,вин,ед,прич,полн,жен,страд'}],
#   'text': 'вырытую'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'скат', 'wt': 0.9904943142, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'скате'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'высота',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'высоты'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'ответ', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'Ответа'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'не', 'wt': 1, 'gr': 'PART='}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'быть',
#     'wt': 0.975680698,
#     'gr': 'V,нп=прош,ед,изъяв,сред,несов'}],
#   'text': 'было'},
#  {'text': '. '},
#  {'text': '— '},
#  {'analysis': [{'lex': 'часовой', 'wt': 0.7012682282, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'Часовой'},
#  {'text': '!'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'повторять',
#     'wt': 1,
#     'gr': 'V,пе=прош,ед,изъяв,муж,сов'}],
#   'text': 'повторил'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'он', 'wt': 1, 'gr': 'SPRO,ед,3-л,муж=им'}],
#   'text': 'он'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'громко', 'wt': 0.9475757585, 'gr': 'ADV=срав'}],
#   'text': 'громче'},
#  {'text': '. '},
#  {'text': '— '},
#  {'analysis': [{'lex': 'а', 'wt': 0.01124958978, 'gr': 'PART='}], 'text': 'А'},
#  {'text': '? '},
#  {'analysis': [{'lex': 'что-то', 'wt': 1, 'gr': 'SPRO,ед,сред,неод=(вин|им)'}],
#   'text': 'Что-то'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'черный',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}],
#   'text': 'черное'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'завозиться',
#     'wt': 0.6203326012,
#     'gr': 'V,сов,нп=прош,ед,изъяв,сред'}],
#   'text': 'завозилось'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'шуршать', 'wt': 1, 'gr': 'V,несов,нп=непрош,деепр'}],
#   'text': 'шурша'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'плащ-палатка', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'плащ-палаткой'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'возле', 'wt': 0.9863990327, 'gr': 'PR='}],
#   'text': 'возле'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вход', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'входа'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'землянка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'землянку'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'голос', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'голос'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'из', 'wt': 0.9999999775, 'gr': 'PR='}], 'text': 'из'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'темнота', 'wt': 1, 'gr': 'S,ед,жен,неод=род'}],
#   'text': 'темноты'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'отзываться',
#     'wt': 1,
#     'gr': 'V,нп=прош,ед,изъяв,муж,сов'}],
#   'text': 'отозвался'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сдавленно', 'wt': 0.9976816286, 'gr': 'ADV='}],
#   'text': 'сдавленно'},
#  {'text': ': — '},
#  {'analysis': [{'lex': 'а',
#     'wt': 2.785256224e-05,
#     'gr': 'S,сокр=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}],
#   'text': 'А'},
#  {'text': '! '},
#  {'analysis': [{'lex': 'кто', 'wt': 1, 'gr': 'SPRO,ед,муж,од=им'}],
#   'text': 'Кто'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тут', 'wt': 0.999928806, 'gr': 'ADVPRO='}],
#   'text': 'тут'},
#  {'text': '? '},
#  {'text': '— '},
#  {'analysis': [{'lex': 'что',
#     'wt': 0.2934446278,
#     'gr': 'SPRO,ед,сред,неод=(вин|им)'}],
#   'text': 'Что'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'это',
#     'wt': 0.7809833731,
#     'gr': 'SPRO,ед,сред,неод=(вин|им)'}],
#   'text': 'это'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'за', 'wt': 1, 'gr': 'PR='}], 'text': 'за'},
#  {'text': ' «'},
#  {'analysis': [{'lex': 'а',
#     'wt': 2.785256224e-05,
#     'gr': 'S,сокр=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}],
#   'text': 'а'},
#  {'text': '»'},
#  {'text': '? '},
#  {'analysis': [{'lex': 'черт', 'wt': 0.9593876497, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'Черт'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'бы', 'wt': 1, 'gr': 'PART='}], 'text': 'бы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'драть',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,муж'}],
#   'text': 'драл'},
#  {'text': '!'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'выругаться',
#     'wt': 1,
#     'gr': 'V,сов,нп=прош,ед,изъяв,муж'}],
#   'text': 'выругался'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'новиков',
#     'wt': 0.9926376892,
#     'gr': 'S,фам,муж,од=им,ед'}],
#   'text': 'Новиков'},
#  {'text': '. '},
#  {'text': '— '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'В'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'прятки', 'wt': 1, 'gr': 'S,мн,неод=(вин|им)'}],
#   'text': 'прятки'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'играть',
#     'wt': 1,
#     'gr': 'V,несов,пе=непрош,мн,изъяв,2-л'}],
#   'text': 'играете'},
#  {'text': '? '},
#  {'text': '— '},
#  {'analysis': [{'lex': 'стоять',
#     'wt': 0.9826836327,
#     'gr': 'V,несов,нп=ед,пов,2-л'}],
#   'text': 'Стой'},
#  {'text': '! '},
#  {'analysis': [{'lex': 'кто', 'wt': 1, 'gr': 'SPRO,ед,муж,од=им'}],
#   'text': 'Кто'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'идти',
#     'wt': 1,
#     'gr': 'V,несов,нп=непрош,ед,изъяв,3-л'}],
#   'text': 'идет'},
#  {'text': '?'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'преувеличенно', 'wt': 0.9993026161, 'gr': 'ADV='}],
#   'text': 'преувеличенно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'грозно', 'wt': 0.8855416745, 'gr': 'ADV='}],
#   'text': 'грозно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'выкрикивать',
#     'wt': 1,
#     'gr': 'V,пе=прош,ед,изъяв,муж,сов'}],
#   'text': 'выкрикнул'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'часовой', 'wt': 0.7012682282, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'часовой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'щелкнуть',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,муж'}],
#   'text': 'щелкнул'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'затвор', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}],
#   'text': 'затвором'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'автомат', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'автомата'},
#  {'text': '.'},
#  {'text': '\n'}]

# %%
m=Mystem()
m.analyze('1 Глава Завещаю в той')
#  'жизни',
#  'Вам',
#  'счастливыми',
#  'быть',
#  'И',
#  'родимой',
#  'Отчизне',
#  'С',
#  'честью',
#  'дальше',
#  'служить',
#  '.',
#  'Горевать',
#  '—',
#  'горделиво',
#  ',',
#  'Не',
#  'клонясь',
#  'головой',
#  '.',
#  'Ликовать',
#  '—',
#  'не',
#  'хвастливо',
#  'В',
#  'час',
#  'победы',
#  'самой',
#  '.',
#  'И',
#  'беречь',
#  'ее',
#  'свято',
#  ',',
#  'Братья',
#  ',',
#  'счастье',
#  'свое',
#  '—',
#  'В',
#  'память',
#  'воина-брата',
#  ',',
#  'Что',
#  'погиб',
#  'за',
#  'нее',
#  '.',
#  'А.',
#  'Твардовский',
#  'В',
#  'двенадцатом',
#  'часу',
#  'ночи',
#  'капитан',
#  'Новиков',
#  'проверял',
#  'посты',
#  '.',
#  'Он',
#  'шел',
#  'по',
#  'высоте',
#  'в',
#  'черной',
#  'осенней',
#  'тьме',
#  ',',
#  'над',
#  'головой',
#  'густо',
#  'шумели',
#  'вершины',
#  'сосен',
#  '.',
#  'Острым',
#  'северным',
#  'холодом',
#  'дуло',
#  'с',
#  'Карпат',
#  ',',
#  'вся',
#  'высота',
#  'гудела',
#  ',',
#  'точно',
#  'гулко',
#  'вибрировала',
#  'под',
#  'непрерывными',
#  'ударами',
#  'воздушных',
#  'потоков',
#  '.',
#  'Пахло',
#  'снегом',
#  '.',
#  'Редкие',
#  'ракеты',
#  'извивались',
#  'над',
#  'немецкой',
#  'передовой',
#  ',',
#  'сносимые',
#  'ветром',
#  ',',
#  'догорали',
#  'за',
#  'темным',
#  'полукружьем',
#  'соседней',
#  'высоты',
#  '.',
#  'В',
#  'низине',
#  'справа',
#  ',',
#  'где',
#  'лежал',
#  'польский',
#  'город',
#  'Касно',
#  ',',
#  'беззвучно',
#  'вспыхивали',
#  ',',
#  'гасли',
#  'неопределенные',
#  'светы',
#  ',',
#  'как',
#  'будто',
#  'задувало',
#  'их',
#  '.',
#  'Молчали',
#  'пулеметы',
#  '.',
#  'Новиков',
#  'не',
#  'видел',
#  'в',
#  'темноте',
#  'ни',
#  'орудия',
#  ',',
#  'ни',
#  'часовых',
#  ',',
#  'шел',
#  '—',
#  'руки',
#  'в',
#  'карманах',
#  ',',
#  'ветер',
#  'неистово',
#  'трепал',
#  'полы',
#  'шинели',
#  ',',
#  '—',
#  'и',
#  'странное',
#  'чувство',
#  'тоски',
#  ',',
#  'глухой',
#  'затерянности',
#  'в',
#  'этих',
#  'мрачных',
#  ',',
#  'холодных',
#  'Карпатах',
#  'охватывало',
#  'его',
#  '.',
#  'Приступы',
#  'тоски',
#  'появлялись',
#  'в',
#  'последнюю',
#  'неделю',
#  'не',
#  'раз',
#  '—',
#  'и',
#  'всегда',
#  'ночью',
#  ',',
#  'в',
#  'короткие',
#  'затишья',
#  ',',
#  'и',
#  'объяснялись',
#  'главным',
#  'образом',
#  'тем',
#  ',',
#  'что',
#  'четыре',
#  'дня',
#  'назад',
#  ',',
#  'при',
#  'взятии',
#  'города',
#  'Касно',
#  ',',
#  'батарея',
#  'Новикова',
#  'впервые',
#  'потеряла',
#  'девять',
#  'человек',
#  'сразу',
#  ',',
#  'в',
#  'том',
#  'числе',
#  'командира',
#  'взвода',
#  'управления',
#  ',',
#  'и',
#  'Новиков',
#  'не',
#  'мог',
#  'простить',
#  'себе',
#  'этого',
#  '.',
#  '—',
#  'Часовой',
#  '!',
#  '—',
#  'строго',
#  'окликнул',
#  'Новиков',
#  ',',
#  'останавливаясь',
#  ',',
#  'по',
#  'звуку',
#  'голосов',
#  'угадывая',
#  'впереди',
#  'землянку',
#  'первого',
#  'взвода',
#  ',',
#  'вырытую',
#  'в',
#  'скате',
#  'высоты',
#  '.',
#  'Ответа',
#  'не',
#  'было',
#  '.',
#  '—',
#  'Часовой',
#  '!',
#  '—',
#  'повторил',
#  'он',
#  'громче',
#  '.',
#  '—',
#  'А',
#  '?',
#  'Что-то',
#  'черное',
#  'завозилось',
#  ',',
#  'шурша',
#  'плащ-палаткой',
#  ',',
#  'возле',
#  'входа',
#  'в',
#  'землянку',
#  ',',
#  'голос',
#  'из',
#  'темноты',
#  'отозвался',
#  'сдавленно',
#  ':',
#  '—',
#  'А',
#  '!',
#  'Кто',
#  'тут',
#  '?',
#  '—',
#  'Что',
#  'это',
#  'за',
#  '«',
#  'а',
#  '»',
#  '?',
#  'Черт',
#  'бы',
#  'драл',
#  '!',
#  '—',
#  'выругался',
#  'Новиков',
#  '.',
#  '—',
#  'В',
#  'прятки',
#  'играете',
#  '?',
#  '—',
#  'Стой',
#  '!',
#  'Кто',
#  'идет',
#  '?',
#  '—',
#  'преувеличенно',
#  'грозно',
#  'выкрикнул',
#  'часовой',
#  'и',
#  'щелкнул',
#  'затвором',
#  'автомата',
#  '.',
#  '—',
#  'Проснулись',
#  '?',
#  'Что',
#  'там',
#  'за',
#  'колготня',
#  'в',
#  'землянке',
#  '?',
#  '—',
#  'спросил',
#  'Новиков',
#  'недовольным',
#  'тоном',
#  '.',
#  '—',
#  'Что',
#  'молчите',
#  '?',
#  '—',
#  'Овчинников',
#  'чегой-то',
#  'шумит',
#  ',',
#  'товарищ',
#  'капитан',
#  ',',
#  '—',
#  'робко',
#  'кашлянув',
#  ',',
#  'забормотал',
#  'часовой',
#  '.',
#  '—',
#  'И',
#  'чего',
#  'они',
#  'разоряются',
#  '?',
#  'Новиков',
#  'толкнул',
#  'дверь',
#  'в',
#  'землянку',
#  '.',
#  'Плотный',
#  'гул',
#  'голосов',
#  'колыхался',
#  'под',
#  'низкими',
#  'накатами',
#  '.',
#  'Среди',
#  'дыма',
#  'плавали',
#  'фиолетовые',
#  'огни',
#  'немецких',
#  'плошек',
#  ',',
#  'мутно',
#  'проступали',
#  'за',
#  'столом',
#  'и',
#  'на',
#  'нарах',
#  'красно-багровые',
#  'лица',
#  'солдат',
#  '—',
#  'все',
#  'говорили',
#  'разом',
#  ',',
#  'нещадно',
#  'курили',
#  '.',
#  'Командир',
#  'первого',
#  'взвода',
#  'лейтенант',
#  'Овчинников',
#  ',',
#  'с',
#  'тонким',
#  ',',
#  'красивым',
#  ',',
#  'самолюбивым',
#  'ртом',
#  ',',
#  'ударил',
#  'кулаком',
#  'по',
#  'столу',
#  ',',
#  'покачиваясь',
#  ',',
#  'встал',
#  ',',
#  'затем',
#  ',',
#  'небрежно',
#  'оттолкнув',
#  'на',
#  'бедре',
#  'тяжелую',
#  'кобуру',
#  'пистолета',
#  ',',
#  'скомандовал',
#  ':',
#  'сипло',
#  'и',
#  'властно',
#  ':',
#  '—',
#  'Прекратить',
#  'галдеж',
#  'и',
#  'слушай',
#  'тост',
#  '!',
#  'За',
#  'Леночку',
#  '!',
#  'А',
#  ',',
#  'братцы',
#  '?',
#  'Пить',
#  'всем',
#  '!',
#  'Смутный',
#  'рев',
#  'голосов',
#  'ответил',
#  'ему',
#  'и',
#  'стих',
#  ':',
#  'все',
#  'увидели',
#  'молча',
#  'стоявшего',
#  'в',
#  'дверях',
#  'капитана',
#  'Новикова',
#  '.',
#  'Он',
#  'медленно',
#  'обвел',
#  'взглядом',
#  'лица',
#  'солдат',
#  '.',
#  '—',
#  'Значит',
#  ',',
#  'пыль',
#  'столбом',
#  '?',
#  '—',
#  'произнес',
#  'он',
#  ',',
#  'хмурясь',
#  '.',
#  '—',
#  'И',
#  'санинструктор',
#  'здесь',
#  '?',
#  'То',
#  ',',
#  'что',
#  'веселье',
#  'это',
#  'происходило',
#  'в',
#  'восьмистах',
#  'метрах',
#  'от',
#  'немецкой',
#  'передовой',
#  'и',
#  'люди',
#  ',',
#  'зная',
#  'это',
#  ',',
#  'не',
#  'сдерживали',
#  'себя',
#  ',',
#  'не',
#  'удивило',
#  'Новикова',
#  '.',
#  'Удивило',
#  'то',
#  ',',
#  'что',
#  'здесь',
#  ',',
#  'среди',
#  'едкого',
#  'махорочного',
#  'дыма',
#  ',',
#  'среди',
#  'этого',
#  'нетрезвого',
#  'шума',
#  ',',
#  'сидела',
#  'на',
#  'нарах',
#  'санинструктор',
#  'Лена',
#  'Колоскова',
#  '.',
#  'Сидела',
#  'она',
#  ',',
#  'охватив',
#  'руками',
#  'колени',
#  'и',
#  'покачиваясь',
#  'взад',
#  'и',
#  'вперед',
#  ',',
#  'разговаривала',
#  'с',
#  'умиленно',
#  'расплывшимся',
#  'замковым',
#  'Лягаловым',
#  ',',
#  'смеялась',
#  'тихим',
#  ',',
#  'трудным',
#  ',',
#  'ласковым',
#  'смехом',
#  '.',
#  '«',
#  'Смеется',
#  'каким-то',
#  'жемчужным',
#  'смехом',
#  ',',
#  '—',
#  'не',
#  'без',
#  'раздражения',
#  'подумал',
#  'Новиков',
#  '.',
#  '—',
#  'Она',
#  'пьяна',
#  'или',
#  'хочет',
#  'понравиться',
#  'лейтенанту',
#  'Овчинникову',
#  '.',
#  'Зачем',
#  'ей',
#  'это',
#  '?',
#  '»',
#  'И',
#  ',',
#  'стараясь',
#  'еще',
#  'более',
#  'возбудить',
#  'в',
#  'себе',
#  'неприязнь',
#  'к',
#  'этому',
#  'легкомысленному',
#  'смеху',
#  ',',
#  'он',
#  'быстро',
#  'взглянул',
#  'на',
#  'нее',
#  ',',
#  'потом',
#  'на',
#  'Овчинникова',
#  ',',
#  'спросил',
#  ':',
#  '—',
#  'Что',
#  'у',
#  'вас',
#  'тут',
#  '?',
#  'Свадьба',
#  '?',
#  '..',
#  'Он',
#  'произнес',
#  'это',
#  ',',
#  'должно',
#  'быть',
#  ',',
#  'грубо',
#  '—',
#  'все',
#  'замолчали',
#  '.',
#  'Лена',
#  'вопросительно',
#  'перевела',
#  'на',
#  'него',
#  'взгляд',
#  'и',
#  'вдруг',
#  'легко',
#  'и',
#  'гибко',
#  'спрыгнула',
#  'с',
#  'нар',
#  ',',
#  'взяла',
#  'со',
#  'стола',
#  'чей-то',
#  'стакан',
#  ',',
#  'подошла',
#  'к',
#  'Новикову',
#  ',',
#  'блестя',
#  'яркими',
#  ',',
#  'чуть',
#  'прищуренными',
#  ',',
#  'улыбающимися',
#  'глазами',
#  '.',
#  '—',
#  'Да',
#  ',',
#  'именно',
#  ',',
#  '—',
#  'сказала',
#  ',',
#  'откидывая',
#  'голову',
#  ',',
#  '—',
#  'здесь',
#  'свадьба',
#  '.',
#  'Поздравьте',
#  'меня',
#  'и',
#  'Овчинникова',
#  '.',
#  'Лейтенант',
#  'Овчинников',
#  '!',
#  '—',
#  'приказала',
#  'она',
#  '.',
#  '—',
#  'Дайте',
#  'водки',
#  'капитану',
#  '!',
#  '«',
#  'Что',
#  'это',
#  'с',
#  'ней',
#  '?',
#  '»',
#  'Она',
#  'не',
#  'была',
#  'пьяна',
#  ',',
#  'кажется',
#  '(',
#  'а',
#  'вообще',
#  'не',
#  'поймешь',
#  '!',
#  ')',
#  ',',
#  'и',
#  'дерзко',
#  'глядела',
#  'на',
#  'него',
#  'снизу',
#  'вверх',
#  ',',
#  '—',
#  'тонкая',
#  'нежная',
#  'шея',
#  'окаймлена',
#  'воротом',
#  ',',
#  'узкие',
#  'плечи',
#  ',',
#  'крепкая',
#  'маленькая',
#  'грудь',
#  'обтянута',
#  'суконной',
#  'гимнастеркой',
#  ',',
#  'сжатой',
#  'в',
#  'талии',
#  'широким',
#  'ремнем',
#  '.',
#  'Не',
#  'раз',
#  'ловил',
#  'себя',
#  'Новиков',
#  'на',
#  'том',
#  ',',
#  'что',
#  'его',
#  'непривычно',
#  'смущала',
#  'постоянная',
#  'вызывающая',
#  'смелость',
#  'санинструктора',
#  ',',
#  '—',
#  'он',
#  'почувствовал',
#  ',',
#  'что',
#  'покраснел',
#  'на',
#  'виду',
#  'мгновенно',
#  'притихших',
#  'солдат',
#  ',',
#  'и',
#  ',',
#  'разозленный',
#  'на',
#  'себя',
#  'за',
#  'это',
#  ',',
#  'резко',
#  'сказал',
#  ':',
#  '—',
#  'Вы',
#  'всегда',
#  'неудачно',
#  'шутите',
#  ',',
#  'товарищ',
#  'санинструктор',
#  '!',
#  '—',
#  'И',
#  ',',
#  'повернувшись',
#  'к',
#  'лейтенанту',
#  'Овчинникову',
#  ',',
#  'договорил',
#  'тоном',
#  'приказа',
#  ':',
#  '—',
#  'Прекратить',
#  '!',
#  'Что',
#  'это',
#  'за',
#  'веселье',
#  '?',
#  'С',
#  'какой',
#  'радости',
#  '?',
#  'Всем',
#  'отдыхать',
#  '!',
#  'Лейтенант',
#  'Овчинников',
#  ',',
#  'самолюбиво',
#  'сузив',
#  'светло',
#  'трезвые',
#  'глаза',
#  'на',
#  'недопитый',
#  'стакан',
#  ',',
#  'спросил',
#  ':',
#  '—',
#  'За',
#  'что',
#  'вы',
#  ',',
#  'товарищ',
#  'капитан',
#  '?',
#  'Мой',
#  'день',
#  'рождения',
#  '.',
#  'Не',
#  'признаете',
#  '?',
#  'Двадцать',
#  'шесть',
#  'стукнуло',
#  '.',
#  'Лягалов',
#  ',',
#  'налей',
#  'комбату',
#  '!',
#  'Ломанем',
#  ',',
#  'товарищ',
#  'капитан',
#  '?',
#  '..',
#  'Чтоб',
#  'пыль',
#  'на',
#  'всю',
#  'Европу',
#  ',',
#  'а',
#  '?',
#  'Замковый',
#  'Лягалов',
#  ',',
#  'солдат',
#  'пожилой',
#  ',',
#  'некрасивый',
#  ',',
#  'низкорослый',
#  ',',
#  'обросший',
#  'золотистой',
#  'щетинкой',
#  'на',
#  'худых',
#  'щеках',
#  ',',
#  'помигал',
#  'конфузливо',
#  'на',
#  'Овчинникова',
#  ',',
#  'на',
#  'комбата',
#  ',',
#  'неуверенно',
#  'налил',
#  'из',
#  'фляги',
#  'полную',
#  'кружку',
#  ',',
#  'протянул',
#  'Новикову',
#  ':',
#  '—',
#  'Товарищ',
#  'капитан',
#  ',',
#  'не',
#  'побрезгуйте',
#  ',',
#  'стадо',
#  'быть…',
#  'Чистая-а',
#  '!',
#  'Считался',
#  'Лягалов',
#  'непьющим',
#  ',',
#  'и',
#  'то',
#  ',',
#  'что',
#  'он',
#  'пил',
#  'сейчас',
#  'и',
#  'протягивал',
#  'кружку',
#  ',',
#  'вконец',
#  'испортило',
#  'настроение',
#  'Новикову',
#  '.',
#  'Он',
#  'оттолкнул',
#  'руку',
#  'Лягалова',
#  ',',
#  'криво',
#  'усмехнулся',
#  ':',
#  '—',
#  'Поздравляю',
#  '.',
#  '—',
#  'И',
#  ',',
#  'ссутулившись',
#  ',',
#  'шагнул',
#  'к',
#  'двери')
# Out:
# [{'text': '1'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'глава', 'wt': 0.5182047872, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'Глава'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'завещать',
#     'wt': 1,
#     'gr': 'V,пе=(непрош,ед,изъяв,1-л,несов|непрош,ед,изъяв,1-л,сов)'}],
#   'text': 'Завещаю'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тот',
#     'wt': 0.9998024292,
#     'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)'}],
#   'text': 'той'},
#  {'text': '\n'}]

# %%
text=' Витя'
words = text.split()

# %%
for word in words:
    analysis = morph.parse(word)

# %%
for result in analysis:
    parsed_word = result.word   
    normal_form = result.normal_form
    pos = result.tag.POS
    case = result.tag.case

# %%
print(f"Слово: {parsed_word}, нормальная форма: {normal_form}, часть речи: {pos}, падеж: {case}")
# Out:
# Слово: витя, нормальная форма: витя, часть речи: NOUN, падеж: nomn

# %%
with open("Forgive_us!.txt", encoding="utf-8") as file:
    text = file.read()
tokenized = nltk.word_tokenize(text)
tokenized
# Out:
# ['Юрий',
#  'Бондарев',
#  '«',
#  'ПРОСТИТЕ',
#  'НАС',
#  '!',
#  '»',
#  'Южный',
#  'экспресс',
#  'задержался',
#  'здесь',
#  'не',
#  'более',
#  'пяти',
#  'минут',
#  '.',
#  'Павел',
#  'Георгиевич',
#  'долго',
#  'стоял',
#  'на',
#  'безлюдной',
#  'платформе',
#  'и',
#  'слушал',
#  'горячую',
#  'трескотню',
#  'кузнечиков',
#  'за',
#  'насыпью',
#  'степного',
#  'разъезда',
#  '.',
#  'После',
#  'духоты',
#  'вагона',
#  ',',
#  'утомительных',
#  'дорожных',
#  'разговоров',
#  'в',
#  'накуренном',
#  'купе',
#  'за',
#  'полночным',
#  'преферансом',
#  ',',
#  'ненужных',
#  'знакомств',
#  ',',
#  'после',
#  'надоедливого',
#  'поскрипывания',
#  'полок',
#  'Павла',
#  'Георгиевича',
#  'охватила',
#  'неправдоподобная',
#  'тишина',
#  ',',
#  'казалось',
#  ',',
#  'совсем',
#  'как',
#  'в',
#  'детстве',
#  '.',
#  'Он',
#  'не',
#  'без',
#  'удовольствия',
#  'сел',
#  'на',
#  'чемодан',
#  ',',
#  'перекинул',
#  'плащ',
#  'через',
#  'плечо',
#  'и',
#  'сидел',
#  'так',
#  ',',
#  'оглядываясь',
#  'со',
#  'счастливым',
#  'облегчением',
#  '.',
#  'Хотя',
#  'по',
#  'роду',
#  'своей',
#  'профессии',
#  'ему',
#  'не',
#  'так',
#  'много',
#  'приходилось',
#  'ездить',
#  ',',
#  'он',
#  'непонятно',
#  'почему',
#  'любил',
#  'нефтяной',
#  'запах',
#  'шпал',
#  ',',
#  'гудки',
#  'паровозов',
#  ',',
#  'спешащий',
#  'перестук',
#  'колес',
#  ',',
#  'мотание',
#  'из',
#  'стороны',
#  'в',
#  'сторону',
#  'последней',
#  'площадки',
#  ',',
#  'где',
#  'в',
#  'руке',
#  'кондуктора',
#  'мелькал',
#  'выцветший',
#  'свернутый',
#  'флажок',
#  ',',
#  'теплый',
#  'ветер',
#  'от',
#  'бегущих',
#  'вагонов',
#  '—',
#  'все',
#  'это',
#  'будило',
#  'смутное',
#  'желание',
#  'к',
#  'движению',
#  ',',
#  'к',
#  'перемене',
#  'мест',
#  '.',
#  'Иногда',
#  'в',
#  'Москве',
#  ',',
#  'до',
#  'глубокой',
#  'ночи',
#  'засиживаясь',
#  'над',
#  'чертежами',
#  ',',
#  'он',
#  'подымал',
#  'голову',
#  ',',
#  'глядя',
#  'в',
#  'распахнутое',
#  'в',
#  'тополя',
#  'окно',
#  ',',
#  'и',
#  ',',
#  'задумавшись',
#  ',',
#  'подолгу',
#  'слушал',
#  ',',
#  'как',
#  'вкрадчиво',
#  'над',
#  'спящим',
#  'городом',
#  'перекликались',
#  'на',
#  'вокзалах',
#  'ночные',
#  'поезда',
#  '.',
#  'Порой',
#  'гудки',
#  'мешали',
#  'ему',
#  ',',
#  'будоражили',
#  'его',
#  ',',
#  'и',
#  'отчего-то',
#  'тогда',
#  'вспоминалась',
#  'вечереющая',
#  'степь',
#  'с',
#  'пыльным',
#  'закатом',
#  'над',
#  'темными',
#  'стогами',
#  ',',
#  'и',
#  ',',
#  'подхваченный',
#  'волнением',
#  ',',
#  'он',
#  'бросал',
#  'работу',
#  ',',
#  'на',
#  'цыпочках',
#  ',',
#  'чтобы',
#  'не',
#  'разбудить',
#  'жену',
#  ',',
#  'уходил',
#  'из',
#  'дому',
#  ',',
#  'бродил',
#  'по',
#  'пустынным',
#  'и',
#  'тихим',
#  'улицам',
#  '.',
#  'Павел',
#  'Георгиевич',
#  'Сафонов',
#  'работал',
#  'на',
#  'большом',
#  'заводе',
#  'конструктором',
#  ',',
#  'был',
#  'известен',
#  ',',
#  'с',
#  'годами',
#  'привык',
#  'к',
#  'этой',
#  'известности',
#  'и',
#  ',',
#  'казалось',
#  ',',
#  'даже',
#  'немного',
#  'устал',
#  'от',
#  'нее',
#  ',',
#  'как',
#  'порой',
#  'устают',
#  'люди',
#  ',',
#  'когда',
#  'к',
#  'ним',
#  'рано',
#  'приходит',
#  'успех',
#  'и',
#  'удовлетворение',
#  '.',
#  'В',
#  'этом',
#  'году',
#  'Сафонов',
#  ',',
#  'утомленный',
#  'сложной',
#  'зимней',
#  'работой',
#  ',',
#  'был',
#  'в',
#  'санатории',
#  'на',
#  'Южном',
#  'берегу',
#  'Крыма',
#  '.',
#  'Ослепительно-солнечный',
#  'юг',
#  'с',
#  'его',
#  'острой',
#  ',',
#  'сухой',
#  'жарой',
#  ',',
#  'неестественно',
#  'экзотическими',
#  'пальмами',
#  'на',
#  'бульварах',
#  ',',
#  'прокаленный',
#  'песок',
#  'пляжа',
#  ',',
#  'купание',
#  'и',
#  'процедурное',
#  'лежание',
#  'под',
#  'теплым',
#  'йодистым',
#  'дуновением',
#  'моря',
#  ',',
#  'весь',
#  'санаторный',
#  'режим',
#  'располагали',
#  'к',
#  'безделью',
#  ',',
#  'одолевала',
#  'курортная',
#  'лень',
#  ',',
#  'и',
#  'мысли',
#  'в',
#  'эту',
#  'жару',
#  'тоже',
#  'были',
#  'притупленные',
#  ',',
#  'ленивые',
#  ',',
#  'и',
#  'хотелось',
#  'быстрее',
#  'в',
#  'Москву',
#  ',',
#  'к',
#  'осенним',
#  'дождям',
#  ',',
#  'к',
#  'мокрому',
#  'асфальту',
#  ',',
#  'к',
#  'блеску',
#  'фонарей',
#  'в',
#  'лужах',
#  '.',
#  'Южный',
#  'экспресс',
#  ',',
#  'на',
#  'котором',
#  'Сафонов',
#  'возвращался',
#  'из',
#  'санатория',
#  ',',
#  'мчал',
#  'его',
#  'по',
#  'знакомым',
#  'местам',
#  ',',
#  'где',
#  'Павел',
#  'Георгиевич',
#  'родился',
#  ',',
#  'вырос',
#  ',',
#  'где',
#  'он',
#  'не',
#  'был',
#  'много',
#  'лет',
#  '.',
#  'Утром',
#  ',',
#  'глядя',
#  'в',
#  'овлажненные',
#  'окна',
#  'тамбура',
#  'на',
#  'прохладную',
#  'степь',
#  ',',
#  'Сафонов',
#  'с',
#  'какой-то',
#  'грустной',
#  'обостренностью',
#  'вспоминал',
#  'то',
#  ',',
#  'что',
#  'уже',
#  'было',
#  'полузабыто',
#  ':',
#  'вот',
#  'он',
#  ',',
#  'мальчишка',
#  ',',
#  'в',
#  'грязной',
#  'сатиновой',
#  'рубашке',
#  ',',
#  'с',
#  'цыпками',
#  'на',
#  'руках',
#  ',',
#  'бежит',
#  'по',
#  'этой',
#  'ледяной',
#  'от',
#  'росы',
#  'степи',
#  ',',
#  'бежит',
#  'вслед',
#  'за',
#  'поездом',
#  'неизвестно',
#  'куда',
#  ',',
#  'и',
#  'отяжелевшая',
#  'от',
#  'влаги',
#  'трава',
#  'хлещет',
#  'его',
#  'по',
#  'коленям',
#  ',',
#  'приятно',
#  'холодит',
#  'ноги…',
#  'Сколько',
#  'тогда',
#  'ему',
#  'было',
#  'лет',
#  '?',
#  'Порой',
#  'ясно',
#  'чудилось',
#  ',',
#  'будто',
#  'вместе',
#  'с',
#  'Верой',
#  'он',
#  'идет',
#  'по',
#  'лунным',
#  'косякам',
#  'на',
#  'Шахтинском',
#  'холме',
#  ',',
#  'внятно',
#  'и',
#  'резко',
#  'пахнет',
#  'из',
#  'низин',
#  'полынью',
#  ',',
#  'и',
#  'потрескавшиеся',
#  ',',
#  'обветренные',
#  'губы',
#  'Веры',
#  'тоже',
#  'пахнут',
#  'полынью',
#  '.',
#  'Воспоминания',
#  'возвращали',
#  'его',
#  'в',
#  'давний',
#  'прожитый',
#  '(',
#  'а',
#  'может',
#  'быть',
#  ',',
#  'непрожитый',
#  ')',
#  'мир',
#  ',',
#  'говорили',
#  ',',
#  'напоминали',
#  ',',
#  'что',
#  'ему',
#  'уже',
#  'за',
#  'сорок',
#  'и',
#  'что',
#  'не',
#  'так',
#  'много',
#  'сделано',
#  'в',
#  'его',
#  'жизни',
#  ',',
#  'где',
#  'давно',
#  ',',
#  'отмеченная',
#  'прочными',
#  'вехами',
#  ',',
#  'первая',
#  'молодость',
#  'прошла',
#  '.',
#  'И',
#  'вдруг',
#  'его',
#  'непреодолимо',
#  'потянуло',
#  'побывать',
#  'в',
#  'родном',
#  'своем',
#  'степном',
#  'городке',
#  ':',
#  'побродить',
#  'по',
#  'нему',
#  ',',
#  'почитать',
#  'афиши',
#  'на',
#  'заборах',
#  ',',
#  'увидеть',
#  'старые',
#  'названия',
#  'улиц',
#  ',',
#  'узнать',
#  ',',
#  'что',
#  'изменилось',
#  'в',
#  'нем',
#  'за',
#  'многие',
#  'годы',
#  ',',
#  'непременно',
#  'встретить',
#  'знакомых',
#  'школьных',
#  'лет',
#  ',',
#  'таких',
#  'далеких',
#  ',',
#  'словно',
#  'их',
#  'и',
#  'не',
#  'было',
#  '.',
#  'Ему',
#  'страстно',
#  'захотелось',
#  'посидеть',
#  'с',
#  'другом',
#  'юности',
#  'Витькой',
#  'Снегиревым',
#  'где-нибудь',
#  'в',
#  'летнем',
#  'кафе',
#  ',',
#  'под',
#  'тентом',
#  ',',
#  'за',
#  'холодным',
#  'пивом',
#  ',',
#  'вспомнить',
#  'то',
#  'наивное',
#  ',',
#  'давнее',
#  'и',
#  'милое',
#  ',',
#  'что',
#  'уже',
#  'никогда',
#  'не',
#  'повторится',
#  ',',
#  'но',
#  'что',
#  'все-таки',
#  'было',
#  'когда-то',
#  'в',
#  'его',
#  'жизни',
#  '.',
#  'И',
#  'хотя',
#  'это',
#  'желание',
#  'победило',
#  ',',
#  'Павел',
#  'Георгиевич',
#  'с',
#  'ироническим',
#  'видом',
#  'потер',
#  'нос',
#  '(',
#  'в',
#  'свои',
#  'годы',
#  'он',
#  'иногда',
#  'подтрунивал',
#  'над',
#  'собственными',
#  'желаниями',
#  ')',
#  ',',
#  'вошел',
#  'в',
#  'купе',
#  ',',
#  'где',
#  'все',
#  'спали',
#  ',',
#  'подумал',
#  'еще',
#  'раз',
#  ',',
#  'уложил',
#  'чемодан',
#  ',',
#  'взял',
#  'плащ',
#  'и',
#  ',',
#  'к',
#  'удивлению',
#  'заспанного',
#  'проводника',
#  ',',
#  'бесшумно',
#  'подметающего',
#  'в',
#  'коридоре',
#  ',',
#  'сошел',
#  'на',
#  'маленьком',
#  'разъезде',
#  'этим',
#  'ранним',
#  'августовским',
#  'утром',
#  '.',
#  'Он',
#  'сошел',
#  'не',
#  'на',
#  'вокзале',
#  'в',
#  'городе',
#  ',',
#  'а',
#  'именно',
#  'здесь',
#  ',',
#  'чтобы',
#  'дойти',
#  'до',
#  'города',
#  'пешком',
#  '.',
#  'Южный',
#  'экспресс',
#  'с',
#  'жаркими',
#  'от',
#  'зари',
#  'стеклами',
#  ',',
#  'с',
#  'запыленными',
#  'занавесками',
#  'тронулся',
#  ',',
#  'полетели',
#  'вдоль',
#  'насыпи',
#  'бумажки',
#  ',',
#  'поднятые',
#  'ветром',
#  ',',
#  'и',
#  'ушел',
#  'быстро',
#  ';',
#  'дымки',
#  'почти',
#  'беззвучного',
#  'паровоза',
#  'таяли',
#  'среди',
#  'сиренево',
#  'стекленеющего',
#  'неба',
#  'далеко',
#  'на',
#  'западе',
#  ',',
#  'все',
#  'стихло',
#  '.',
#  'Только',
#  'у',
#  'самой',
#  'насыпи',
#  'неумолчно',
#  'звенели',
#  ',',
#  'трещали',
#  'в',
#  'неестественной',
#  'тишине',
#  'кузнечики',
#  '.',
#  'Сидя',
#  'на',
#  'чемодане',
#  ',',
#  'Сафонов',
#  'не',
#  'без',
#  'волнения',
#  'выкурил',
#  'папиросу',
#  ',',
#  'подумал',
#  ':',
#  '«',
#  'Необычайно',
#  'хорошо',
#  '!',
#  '»',
#  '—',
#  'и',
#  'с',
#  'наслаждением',
#  'вдохнул',
#  'на',
#  'полную',
#  'грудь',
#  'зябкий',
#  'и',
#  'чистый',
#  ',',
#  'как',
#  'ключевая',
#  'вода',
#  ',',
#  'воздух',
#  '.',
#  'Степь',
#  ',',
#  'по-летнему',
#  'пестрая',
#  ',',
#  'в',
#  'этот',
#  'спокойный',
#  'час',
#  'утра',
#  'тепло',
#  'и',
#  'ало',
#  'краснела',
#  'за',
#  'холмами',
#  'на',
#  'востоке',
#  '.',
#  'Там',
#  ',',
#  'в',
#  'эту',
#  'пылающую',
#  ',',
#  'мнилось',
#  ',',
#  'бесконечность',
#  'пылила',
#  'вдали',
#  'по',
#  'косогору',
#  'грузовая',
#  'машина',
#  ',',
#  'и',
#  ',',
#  'четко',
#  'вырезанные',
#  'по',
#  'красному',
#  ',',
#  'проступали',
#  'терриконики',
#  ',',
#  'дальние',
#  'силуэты',
#  'водонапорной',
#  'башни',
#  ',',
#  'оазисы',
#  'беленьких',
#  'домов',
#  ',',
#  'острые',
#  'верхушки',
#  'тополей',
#  '.',
#  'С',
#  'насыпи',
#  'Павел',
#  'Георгиевич',
#  'не',
#  'торопясь',
#  'спустился',
#  'в',
#  'степь',
#  ',',
#  'как',
#  'в',
#  'чашу',
#  ',',
#  'полную',
#  'еще',
#  'сырой',
#  'прохлады',
#  ';',
#  'тугой',
#  'волной',
#  'обдавало',
#  'горьковатым',
#  'запахом',
#  'полыни',
#  '.',
#  'И',
#  'пока',
#  'он',
#  'выбрался',
#  'на',
#  'дорогу',
#  ',',
#  'колени',
#  'его',
#  'стали',
#  'влажными',
#  'от',
#  'росы',
#  ',',
#  'на',
#  'плащ',
#  ',',
#  'на',
#  'брюки',
#  'нацеплялись',
#  'репейники',
#  ',',
#  'чемодан',
#  'облепили',
#  'мокрые',
#  'лепестки',
#  '.',
#  'Он',
#  'шагал',
#  'по',
#  'дороге',
#  ',',
#  'приятно',
#  'утопая',
#  'ботинками',
#  'в',
#  'мягкой',
#  'пыли',
#  ',',
#  'затем',
#  'сорвал',
#  'прутик',
#  'с',
#  'молодой',
#  'липкой',
#  'кожицей',
#  ';',
#  'по-мальчишески',
#  'сбивая',
#  'росу',
#  ',',
#  'ударил',
#  'им',
#  'по',
#  'головке',
#  'какого-то',
#  'фиолетового',
#  'цветка',
#  'у',
#  'обочины',
#  '(',
#  'название',
#  'которого',
#  'в',
#  'детстве',
#  'знал',
#  ',',
#  'но',
#  'теперь',
#  'забыл',
#  ')',
#  '.',
#  'Из',
#  'глубины',
#  'цветка',
#  'неожиданно',
#  'поднялся',
#  'сонный',
#  'золотистый',
#  'шмель',
#  ',',
#  'весь',
#  'в',
#  'намокшей',
#  'пыльце',
#  ',',
#  'и',
#  'тяжело',
#  ',',
#  'сердито',
#  'прогудел',
#  'мимо',
#  '.',
#  '—',
#  'Ишь',
#  'ты',
#  '!',
#  ...]

# %%
tagged = nltk.pos_tag(tokenized)
tagged
# Out:
# [('Юрий', 'JJ'),
#  ('Бондарев', 'NNP'),
#  ('«', 'NNP'),
#  ('ПРОСТИТЕ', 'NNP'),
#  ('НАС', 'NN'),
#  ('!', '.'),
#  ('»', 'JJ'),
#  ('Южный', 'JJ'),
#  ('экспресс', 'NN'),
#  ('задержался', 'NNP'),
#  ('здесь', 'NNP'),
#  ('не', 'NNP'),
#  ('более', 'NNP'),
#  ('пяти', 'NNP'),
#  ('минут', 'NNP'),
#  ('.', '.'),
#  ('Павел', 'VB'),
#  ('Георгиевич', 'JJ'),
#  ('долго', 'NNP'),
#  ('стоял', 'NNP'),
#  ('на', 'NNP'),
#  ('безлюдной', 'NNP'),
#  ('платформе', 'NNP'),
#  ('и', 'NNP'),
#  ('слушал', 'NNP'),
#  ('горячую', 'NNP'),
#  ('трескотню', 'NNP'),
#  ('кузнечиков', 'NNP'),
#  ('за', 'NNP'),
#  ('насыпью', 'NNP'),
#  ('степного', 'NNP'),
#  ('разъезда', 'NNP'),
#  ('.', '.'),
#  ('После', 'VB'),
#  ('духоты', 'JJ'),
#  ('вагона', 'NNP'),
#  (',', ','),
#  ('утомительных', 'NNP'),
#  ('дорожных', 'NNP'),
#  ('разговоров', 'NNP'),
#  ('в', 'NNP'),
#  ('накуренном', 'NNP'),
#  ('купе', 'NNP'),
#  ('за', 'NNP'),
#  ('полночным', 'NNP'),
#  ('преферансом', 'NNP'),
#  (',', ','),
#  ('ненужных', 'NNP'),
#  ('знакомств', 'NNP'),
#  (',', ','),
#  ('после', 'NNP'),
#  ('надоедливого', 'NNP'),
#  ('поскрипывания', 'NNP'),
#  ('полок', 'NNP'),
#  ('Павла', 'NNP'),
#  ('Георгиевича', 'NNP'),
#  ('охватила', 'NNP'),
#  ('неправдоподобная', 'NNP'),
#  ('тишина', 'NNP'),
#  (',', ','),
#  ('казалось', 'NNP'),
#  (',', ','),
#  ('совсем', 'NNP'),
#  ('как', 'NNP'),
#  ('в', 'NNP'),
#  ('детстве', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('не', 'JJ'),
#  ('без', 'NNP'),
#  ('удовольствия', 'NNP'),
#  ('сел', 'NNP'),
#  ('на', 'NNP'),
#  ('чемодан', 'NNP'),
#  (',', ','),
#  ('перекинул', 'NNP'),
#  ('плащ', 'NNP'),
#  ('через', 'NNP'),
#  ('плечо', 'NNP'),
#  ('и', 'NNP'),
#  ('сидел', 'NNP'),
#  ('так', 'NNP'),
#  (',', ','),
#  ('оглядываясь', 'NNP'),
#  ('со', 'NNP'),
#  ('счастливым', 'NNP'),
#  ('облегчением', 'NNP'),
#  ('.', '.'),
#  ('Хотя', 'VB'),
#  ('по', 'JJ'),
#  ('роду', 'NNP'),
#  ('своей', 'NNP'),
#  ('профессии', 'NNP'),
#  ('ему', 'NNP'),
#  ('не', 'NNP'),
#  ('так', 'NNP'),
#  ('много', 'NNP'),
#  ('приходилось', 'NNP'),
#  ('ездить', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('непонятно', 'NNP'),
#  ('почему', 'NNP'),
#  ('любил', 'NNP'),
#  ('нефтяной', 'NNP'),
#  ('запах', 'NNP'),
#  ('шпал', 'NNP'),
#  (',', ','),
#  ('гудки', 'NNP'),
#  ('паровозов', 'NNP'),
#  (',', ','),
#  ('спешащий', 'NNP'),
#  ('перестук', 'NNP'),
#  ('колес', 'NNP'),
#  (',', ','),
#  ('мотание', 'NNP'),
#  ('из', 'NNP'),
#  ('стороны', 'NNP'),
#  ('в', 'NNP'),
#  ('сторону', 'NNP'),
#  ('последней', 'NNP'),
#  ('площадки', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('в', 'NNP'),
#  ('руке', 'NNP'),
#  ('кондуктора', 'NNP'),
#  ('мелькал', 'NNP'),
#  ('выцветший', 'NNP'),
#  ('свернутый', 'NNP'),
#  ('флажок', 'NNP'),
#  (',', ','),
#  ('теплый', 'NNP'),
#  ('ветер', 'NNP'),
#  ('от', 'NNP'),
#  ('бегущих', 'NNP'),
#  ('вагонов', 'NNP'),
#  ('—', 'NNP'),
#  ('все', 'NNP'),
#  ('это', 'NNP'),
#  ('будило', 'NNP'),
#  ('смутное', 'NNP'),
#  ('желание', 'NNP'),
#  ('к', 'NNP'),
#  ('движению', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('перемене', 'NNP'),
#  ('мест', 'NNP'),
#  ('.', '.'),
#  ('Иногда', 'VB'),
#  ('в', 'JJ'),
#  ('Москве', 'NNP'),
#  (',', ','),
#  ('до', 'NNP'),
#  ('глубокой', 'NNP'),
#  ('ночи', 'NNP'),
#  ('засиживаясь', 'NNP'),
#  ('над', 'NNP'),
#  ('чертежами', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('подымал', 'NNP'),
#  ('голову', 'NNP'),
#  (',', ','),
#  ('глядя', 'NNP'),
#  ('в', 'NNP'),
#  ('распахнутое', 'NNP'),
#  ('в', 'NNP'),
#  ('тополя', 'NNP'),
#  ('окно', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('задумавшись', 'NNP'),
#  (',', ','),
#  ('подолгу', 'NNP'),
#  ('слушал', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('вкрадчиво', 'NNP'),
#  ('над', 'NNP'),
#  ('спящим', 'NNP'),
#  ('городом', 'NNP'),
#  ('перекликались', 'NNP'),
#  ('на', 'NNP'),
#  ('вокзалах', 'NNP'),
#  ('ночные', 'NNP'),
#  ('поезда', 'NNP'),
#  ('.', '.'),
#  ('Порой', 'VB'),
#  ('гудки', 'JJ'),
#  ('мешали', 'NNP'),
#  ('ему', 'NNP'),
#  (',', ','),
#  ('будоражили', 'NNP'),
#  ('его', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('отчего-то', 'NNP'),
#  ('тогда', 'NNP'),
#  ('вспоминалась', 'NNP'),
#  ('вечереющая', 'NNP'),
#  ('степь', 'NNP'),
#  ('с', 'NNP'),
#  ('пыльным', 'NNP'),
#  ('закатом', 'NNP'),
#  ('над', 'NNP'),
#  ('темными', 'NNP'),
#  ('стогами', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('подхваченный', 'NNP'),
#  ('волнением', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('бросал', 'NNP'),
#  ('работу', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('цыпочках', 'NNP'),
#  (',', ','),
#  ('чтобы', 'NNP'),
#  ('не', 'NNP'),
#  ('разбудить', 'NNP'),
#  ('жену', 'NNP'),
#  (',', ','),
#  ('уходил', 'NNP'),
#  ('из', 'NNP'),
#  ('дому', 'NNP'),
#  (',', ','),
#  ('бродил', 'NNP'),
#  ('по', 'NNP'),
#  ('пустынным', 'NNP'),
#  ('и', 'NNP'),
#  ('тихим', 'NNP'),
#  ('улицам', 'NNP'),
#  ('.', '.'),
#  ('Павел', 'VB'),
#  ('Георгиевич', 'JJ'),
#  ('Сафонов', 'NNP'),
#  ('работал', 'NNP'),
#  ('на', 'NNP'),
#  ('большом', 'NNP'),
#  ('заводе', 'NNP'),
#  ('конструктором', 'NNP'),
#  (',', ','),
#  ('был', 'NNP'),
#  ('известен', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('годами', 'NNP'),
#  ('привык', 'NNP'),
#  ('к', 'NNP'),
#  ('этой', 'NNP'),
#  ('известности', 'NNP'),
#  ('и', 'NNP'),
#  (',', ','),
#  ('казалось', 'NNP'),
#  (',', ','),
#  ('даже', 'NNP'),
#  ('немного', 'NNP'),
#  ('устал', 'NNP'),
#  ('от', 'NNP'),
#  ('нее', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('порой', 'NNP'),
#  ('устают', 'NNP'),
#  ('люди', 'NNP'),
#  (',', ','),
#  ('когда', 'NNP'),
#  ('к', 'NNP'),
#  ('ним', 'NNP'),
#  ('рано', 'NNP'),
#  ('приходит', 'NNP'),
#  ('успех', 'NNP'),
#  ('и', 'NNP'),
#  ('удовлетворение', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('этом', 'JJ'),
#  ('году', 'NNP'),
#  ('Сафонов', 'NNP'),
#  (',', ','),
#  ('утомленный', 'NNP'),
#  ('сложной', 'NNP'),
#  ('зимней', 'NNP'),
#  ('работой', 'NNP'),
#  (',', ','),
#  ('был', 'NNP'),
#  ('в', 'NNP'),
#  ('санатории', 'NNP'),
#  ('на', 'NNP'),
#  ('Южном', 'NNP'),
#  ('берегу', 'NNP'),
#  ('Крыма', 'NNP'),
#  ('.', '.'),
#  ('Ослепительно-солнечный', 'JJ'),
#  ('юг', 'JJ'),
#  ('с', 'NN'),
#  ('его', 'NNP'),
#  ('острой', 'NNP'),
#  (',', ','),
#  ('сухой', 'NNP'),
#  ('жарой', 'NNP'),
#  (',', ','),
#  ('неестественно', 'NNP'),
#  ('экзотическими', 'NNP'),
#  ('пальмами', 'NNP'),
#  ('на', 'NNP'),
#  ('бульварах', 'NNP'),
#  (',', ','),
#  ('прокаленный', 'NNP'),
#  ('песок', 'NNP'),
#  ('пляжа', 'NNP'),
#  (',', ','),
#  ('купание', 'NNP'),
#  ('и', 'NNP'),
#  ('процедурное', 'NNP'),
#  ('лежание', 'NNP'),
#  ('под', 'NNP'),
#  ('теплым', 'NNP'),
#  ('йодистым', 'NNP'),
#  ('дуновением', 'NNP'),
#  ('моря', 'NNP'),
#  (',', ','),
#  ('весь', 'NNP'),
#  ('санаторный', 'NNP'),
#  ('режим', 'NNP'),
#  ('располагали', 'NNP'),
#  ('к', 'NNP'),
#  ('безделью', 'NNP'),
#  (',', ','),
#  ('одолевала', 'NNP'),
#  ('курортная', 'NNP'),
#  ('лень', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('мысли', 'NNP'),
#  ('в', 'NNP'),
#  ('эту', 'NNP'),
#  ('жару', 'NNP'),
#  ('тоже', 'NNP'),
#  ('были', 'NNP'),
#  ('притупленные', 'NNP'),
#  (',', ','),
#  ('ленивые', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('хотелось', 'NNP'),
#  ('быстрее', 'NNP'),
#  ('в', 'NNP'),
#  ('Москву', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('осенним', 'NNP'),
#  ('дождям', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('мокрому', 'NNP'),
#  ('асфальту', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('блеску', 'NNP'),
#  ('фонарей', 'NNP'),
#  ('в', 'NNP'),
#  ('лужах', 'NNP'),
#  ('.', '.'),
#  ('Южный', 'NN'),
#  ('экспресс', 'NN'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('котором', 'NNP'),
#  ('Сафонов', 'NNP'),
#  ('возвращался', 'NNP'),
#  ('из', 'NNP'),
#  ('санатория', 'NNP'),
#  (',', ','),
#  ('мчал', 'NNP'),
#  ('его', 'NNP'),
#  ('по', 'NNP'),
#  ('знакомым', 'NNP'),
#  ('местам', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('Павел', 'NNP'),
#  ('Георгиевич', 'NNP'),
#  ('родился', 'NNP'),
#  (',', ','),
#  ('вырос', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('он', 'NNP'),
#  ('не', 'NNP'),
#  ('был', 'NNP'),
#  ('много', 'NNP'),
#  ('лет', 'NNP'),
#  ('.', '.'),
#  ('Утром', 'NN'),
#  (',', ','),
#  ('глядя', 'NNP'),
#  ('в', 'NNP'),
#  ('овлажненные', 'NNP'),
#  ('окна', 'NNP'),
#  ('тамбура', 'NNP'),
#  ('на', 'NNP'),
#  ('прохладную', 'NNP'),
#  ('степь', 'NNP'),
#  (',', ','),
#  ('Сафонов', 'NNP'),
#  ('с', 'NNP'),
#  ('какой-то', 'JJ'),
#  ('грустной', 'NNP'),
#  ('обостренностью', 'NNP'),
#  ('вспоминал', 'NNP'),
#  ('то', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('уже', 'NNP'),
#  ('было', 'NNP'),
#  ('полузабыто', 'NN'),
#  (':', ':'),
#  ('вот', 'NN'),
#  ('он', 'NN'),
#  (',', ','),
#  ('мальчишка', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('грязной', 'NNP'),
#  ('сатиновой', 'NNP'),
#  ('рубашке', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('цыпками', 'NNP'),
#  ('на', 'NNP'),
#  ('руках', 'NNP'),
#  (',', ','),
#  ('бежит', 'NNP'),
#  ('по', 'NNP'),
#  ('этой', 'NNP'),
#  ('ледяной', 'NNP'),
#  ('от', 'NNP'),
#  ('росы', 'NNP'),
#  ('степи', 'NNP'),
#  (',', ','),
#  ('бежит', 'NNP'),
#  ('вслед', 'NNP'),
#  ('за', 'NNP'),
#  ('поездом', 'NNP'),
#  ('неизвестно', 'NNP'),
#  ('куда', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('отяжелевшая', 'NNP'),
#  ('от', 'NNP'),
#  ('влаги', 'NNP'),
#  ('трава', 'NNP'),
#  ('хлещет', 'NNP'),
#  ('его', 'NNP'),
#  ('по', 'NNP'),
#  ('коленям', 'NNP'),
#  (',', ','),
#  ('приятно', 'NNP'),
#  ('холодит', 'NNP'),
#  ('ноги…', 'NNP'),
#  ('Сколько', 'NNP'),
#  ('тогда', 'NNP'),
#  ('ему', 'NNP'),
#  ('было', 'NNP'),
#  ('лет', 'NNP'),
#  ('?', '.'),
#  ('Порой', 'NNP'),
#  ('ясно', 'NNP'),
#  ('чудилось', 'NNP'),
#  (',', ','),
#  ('будто', 'NNP'),
#  ('вместе', 'NNP'),
#  ('с', 'NNP'),
#  ('Верой', 'NNP'),
#  ('он', 'NNP'),
#  ('идет', 'NNP'),
#  ('по', 'NNP'),
#  ('лунным', 'NNP'),
#  ('косякам', 'NNP'),
#  ('на', 'NNP'),
#  ('Шахтинском', 'NNP'),
#  ('холме', 'NNP'),
#  (',', ','),
#  ('внятно', 'NNP'),
#  ('и', 'NNP'),
#  ('резко', 'NNP'),
#  ('пахнет', 'NNP'),
#  ('из', 'NNP'),
#  ('низин', 'NNP'),
#  ('полынью', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('потрескавшиеся', 'NNP'),
#  (',', ','),
#  ('обветренные', 'NNP'),
#  ('губы', 'NNP'),
#  ('Веры', 'NNP'),
#  ('тоже', 'NNP'),
#  ('пахнут', 'NNP'),
#  ('полынью', 'NNP'),
#  ('.', '.'),
#  ('Воспоминания', 'VB'),
#  ('возвращали', 'JJ'),
#  ('его', 'NNP'),
#  ('в', 'NNP'),
#  ('давний', 'NNP'),
#  ('прожитый', 'NNP'),
#  ('(', '('),
#  ('а', 'NNP'),
#  ('может', 'NNP'),
#  ('быть', 'NNP'),
#  (',', ','),
#  ('непрожитый', 'NNP'),
#  (')', ')'),
#  ('мир', 'NN'),
#  (',', ','),
#  ('говорили', 'NNP'),
#  (',', ','),
#  ('напоминали', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('ему', 'NNP'),
#  ('уже', 'NNP'),
#  ('за', 'NNP'),
#  ('сорок', 'NNP'),
#  ('и', 'NNP'),
#  ('что', 'NNP'),
#  ('не', 'NNP'),
#  ('так', 'NNP'),
#  ('много', 'NNP'),
#  ('сделано', 'NNP'),
#  ('в', 'NNP'),
#  ('его', 'NNP'),
#  ('жизни', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('давно', 'NNP'),
#  (',', ','),
#  ('отмеченная', 'NNP'),
#  ('прочными', 'NNP'),
#  ('вехами', 'NNP'),
#  (',', ','),
#  ('первая', 'NNP'),
#  ('молодость', 'NNP'),
#  ('прошла', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('вдруг', 'JJ'),
#  ('его', 'NNP'),
#  ('непреодолимо', 'NNP'),
#  ('потянуло', 'NNP'),
#  ('побывать', 'NNP'),
#  ('в', 'NNP'),
#  ('родном', 'NNP'),
#  ('своем', 'NNP'),
#  ('степном', 'NNP'),
#  ('городке', 'NN'),
#  (':', ':'),
#  ('побродить', 'JJ'),
#  ('по', 'NNP'),
#  ('нему', 'NNP'),
#  (',', ','),
#  ('почитать', 'NNP'),
#  ('афиши', 'NNP'),
#  ('на', 'NNP'),
#  ('заборах', 'NNP'),
#  (',', ','),
#  ('увидеть', 'NNP'),
#  ('старые', 'NNP'),
#  ('названия', 'NNP'),
#  ('улиц', 'NNP'),
#  (',', ','),
#  ('узнать', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('изменилось', 'NNP'),
#  ('в', 'NNP'),
#  ('нем', 'NNP'),
#  ('за', 'NNP'),
#  ('многие', 'NNP'),
#  ('годы', 'NNP'),
#  (',', ','),
#  ('непременно', 'NNP'),
#  ('встретить', 'NNP'),
#  ('знакомых', 'NNP'),
#  ('школьных', 'NNP'),
#  ('лет', 'NNP'),
#  (',', ','),
#  ('таких', 'NNP'),
#  ('далеких', 'NNP'),
#  (',', ','),
#  ('словно', 'NNP'),
#  ('их', 'NNP'),
#  ('и', 'NNP'),
#  ('не', 'NNP'),
#  ('было', 'NNP'),
#  ('.', '.'),
#  ('Ему', 'VB'),
#  ('страстно', 'JJ'),
#  ('захотелось', 'NNP'),
#  ('посидеть', 'NNP'),
#  ('с', 'NNP'),
#  ('другом', 'NNP'),
#  ('юности', 'NNP'),
#  ('Витькой', 'NNP'),
#  ('Снегиревым', 'NNP'),
#  ('где-нибудь', 'JJ'),
#  ('в', 'NNP'),
#  ('летнем', 'NNP'),
#  ('кафе', 'NNP'),
#  (',', ','),
#  ('под', 'NNP'),
#  ('тентом', 'NNP'),
#  (',', ','),
#  ('за', 'NNP'),
#  ('холодным', 'NNP'),
#  ('пивом', 'NNP'),
#  (',', ','),
#  ('вспомнить', 'NNP'),
#  ('то', 'NNP'),
#  ('наивное', 'NNP'),
#  (',', ','),
#  ('давнее', 'NNP'),
#  ('и', 'NNP'),
#  ('милое', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('уже', 'NNP'),
#  ('никогда', 'NNP'),
#  ('не', 'NNP'),
#  ('повторится', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('что', 'NNP'),
#  ('все-таки', 'JJ'),
#  ('было', 'NNP'),
#  ('когда-то', 'JJ'),
#  ('в', 'NNP'),
#  ('его', 'NNP'),
#  ('жизни', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('хотя', 'JJ'),
#  ('это', 'NNP'),
#  ('желание', 'NNP'),
#  ('победило', 'NNP'),
#  (',', ','),
#  ('Павел', 'NNP'),
#  ('Георгиевич', 'NNP'),
#  ('с', 'NNP'),
#  ('ироническим', 'NNP'),
#  ('видом', 'NNP'),
#  ('потер', 'NNP'),
#  ('нос', 'NNP'),
#  ('(', '('),
#  ('в', 'NNP'),
#  ('свои', 'NNP'),
#  ('годы', 'NNP'),
#  ('он', 'NNP'),
#  ('иногда', 'NNP'),
#  ('подтрунивал', 'NNP'),
#  ('над', 'NNP'),
#  ('собственными', 'NNP'),
#  ('желаниями', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('вошел', 'JJ'),
#  ('в', 'NNP'),
#  ('купе', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('все', 'NNP'),
#  ('спали', 'NNP'),
#  (',', ','),
#  ('подумал', 'NNP'),
#  ('еще', 'NNP'),
#  ('раз', 'NNP'),
#  (',', ','),
#  ('уложил', 'NNP'),
#  ('чемодан', 'NNP'),
#  (',', ','),
#  ('взял', 'NNP'),
#  ('плащ', 'NNP'),
#  ('и', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('удивлению', 'NNP'),
#  ('заспанного', 'NNP'),
#  ('проводника', 'NNP'),
#  (',', ','),
#  ('бесшумно', 'NNP'),
#  ('подметающего', 'NNP'),
#  ('в', 'NNP'),
#  ('коридоре', 'NNP'),
#  (',', ','),
#  ('сошел', 'NNP'),
#  ('на', 'NNP'),
#  ('маленьком', 'NNP'),
#  ('разъезде', 'NNP'),
#  ('этим', 'NNP'),
#  ('ранним', 'NNP'),
#  ('августовским', 'NNP'),
#  ('утром', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('сошел', 'JJ'),
#  ('не', 'NNP'),
#  ('на', 'NNP'),
#  ('вокзале', 'NNP'),
#  ('в', 'NNP'),
#  ('городе', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('именно', 'NNP'),
#  ('здесь', 'NNP'),
#  (',', ','),
#  ('чтобы', 'NNP'),
#  ('дойти', 'NNP'),
#  ('до', 'NNP'),
#  ('города', 'NNP'),
#  ('пешком', 'NNP'),
#  ('.', '.'),
#  ('Южный', 'VB'),
#  ('экспресс', 'JJ'),
#  ('с', 'NNP'),
#  ('жаркими', 'NNP'),
#  ('от', 'NNP'),
#  ('зари', 'NNP'),
#  ('стеклами', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('запыленными', 'NNP'),
#  ('занавесками', 'NNP'),
#  ('тронулся', 'NNP'),
#  (',', ','),
#  ('полетели', 'NNP'),
#  ('вдоль', 'NNP'),
#  ('насыпи', 'NNP'),
#  ('бумажки', 'NNP'),
#  (',', ','),
#  ('поднятые', 'NNP'),
#  ('ветром', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('ушел', 'NNP'),
#  ('быстро', 'NNP'),
#  (';', ':'),
#  ('дымки', 'NNP'),
#  ('почти', 'NNP'),
#  ('беззвучного', 'NNP'),
#  ('паровоза', 'NNP'),
#  ('таяли', 'NNP'),
#  ('среди', 'NNP'),
#  ('сиренево', 'NNP'),
#  ('стекленеющего', 'NNP'),
#  ('неба', 'NNP'),
#  ('далеко', 'NNP'),
#  ('на', 'NNP'),
#  ('западе', 'NNP'),
#  (',', ','),
#  ('все', 'NNP'),
#  ('стихло', 'NNP'),
#  ('.', '.'),
#  ('Только', 'VB'),
#  ('у', 'JJ'),
#  ('самой', 'NNP'),
#  ('насыпи', 'NNP'),
#  ('неумолчно', 'NNP'),
#  ('звенели', 'NNP'),
#  (',', ','),
#  ('трещали', 'NNP'),
#  ('в', 'NNP'),
#  ('неестественной', 'NNP'),
#  ('тишине', 'NNP'),
#  ('кузнечики', 'NNP'),
#  ('.', '.'),
#  ('Сидя', 'VB'),
#  ('на', 'JJ'),
#  ('чемодане', 'NNP'),
#  (',', ','),
#  ('Сафонов', 'NNP'),
#  ('не', 'NNP'),
#  ('без', 'NNP'),
#  ('волнения', 'NNP'),
#  ('выкурил', 'NNP'),
#  ('папиросу', 'NNP'),
#  (',', ','),
#  ('подумал', 'NN'),
#  (':', ':'),
#  ('«', 'JJ'),
#  ('Необычайно', 'NNP'),
#  ('хорошо', 'NN'),
#  ('!', '.'),
#  ('»', 'JJ'),
#  ('—', 'JJ'),
#  ('и', 'NN'),
#  ('с', 'NNP'),
#  ('наслаждением', 'NNP'),
#  ('вдохнул', 'NNP'),
#  ('на', 'NNP'),
#  ('полную', 'NNP'),
#  ('грудь', 'NNP'),
#  ('зябкий', 'NNP'),
#  ('и', 'NNP'),
#  ('чистый', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('ключевая', 'NNP'),
#  ('вода', 'NNP'),
#  (',', ','),
#  ('воздух', 'NNP'),
#  ('.', '.'),
#  ('Степь', 'NN'),
#  (',', ','),
#  ('по-летнему', 'JJ'),
#  ('пестрая', 'NN'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('этот', 'NNP'),
#  ('спокойный', 'NNP'),
#  ('час', 'NNP'),
#  ('утра', 'NNP'),
#  ('тепло', 'NNP'),
#  ('и', 'NNP'),
#  ('ало', 'NNP'),
#  ('краснела', 'NNP'),
#  ('за', 'NNP'),
#  ('холмами', 'NNP'),
#  ('на', 'NNP'),
#  ('востоке', 'NNP'),
#  ('.', '.'),
#  ('Там', 'NN'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('эту', 'NNP'),
#  ('пылающую', 'NNP'),
#  (',', ','),
#  ('мнилось', 'NNP'),
#  (',', ','),
#  ('бесконечность', 'NNP'),
#  ('пылила', 'NNP'),
#  ('вдали', 'NNP'),
#  ('по', 'NNP'),
#  ('косогору', 'NNP'),
#  ('грузовая', 'NNP'),
#  ('машина', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('четко', 'NNP'),
#  ('вырезанные', 'NNP'),
#  ('по', 'NNP'),
#  ('красному', 'NNP'),
#  (',', ','),
#  ('проступали', 'NNP'),
#  ('терриконики', 'NNP'),
#  (',', ','),
#  ('дальние', 'NNP'),
#  ('силуэты', 'NNP'),
#  ('водонапорной', 'NNP'),
#  ('башни', 'NNP'),
#  (',', ','),
#  ('оазисы', 'NNP'),
#  ('беленьких', 'NNP'),
#  ('домов', 'NNP'),
#  (',', ','),
#  ('острые', 'NNP'),
#  ('верхушки', 'NNP'),
#  ('тополей', 'NNP'),
#  ('.', '.'),
#  ('С', 'VB'),
#  ('насыпи', 'JJ'),
#  ('Павел', 'NNP'),
#  ('Георгиевич', 'NNP'),
#  ('не', 'NNP'),
#  ('торопясь', 'NNP'),
#  ('спустился', 'NNP'),
#  ('в', 'NNP'),
#  ('степь', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('в', 'NNP'),
#  ('чашу', 'NNP'),
#  (',', ','),
#  ('полную', 'NNP'),
#  ('еще', 'NNP'),
#  ('сырой', 'NNP'),
#  ('прохлады', 'NNP'),
#  (';', ':'),
#  ('тугой', 'NNP'),
#  ('волной', 'NNP'),
#  ('обдавало', 'NNP'),
#  ('горьковатым', 'NNP'),
#  ('запахом', 'NNP'),
#  ('полыни', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('пока', 'JJ'),
#  ('он', 'NNP'),
#  ('выбрался', 'NNP'),
#  ('на', 'NNP'),
#  ('дорогу', 'NNP'),
#  (',', ','),
#  ('колени', 'NNP'),
#  ('его', 'NNP'),
#  ('стали', 'NNP'),
#  ('влажными', 'NNP'),
#  ('от', 'NNP'),
#  ('росы', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('плащ', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('брюки', 'NNP'),
#  ('нацеплялись', 'NNP'),
#  ('репейники', 'NNP'),
#  (',', ','),
#  ('чемодан', 'NNP'),
#  ('облепили', 'NNP'),
#  ('мокрые', 'NNP'),
#  ('лепестки', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('шагал', 'JJ'),
#  ('по', 'NNP'),
#  ('дороге', 'NNP'),
#  (',', ','),
#  ('приятно', 'NNP'),
#  ('утопая', 'NNP'),
#  ('ботинками', 'NNP'),
#  ('в', 'NNP'),
#  ('мягкой', 'NNP'),
#  ('пыли', 'NNP'),
#  (',', ','),
#  ('затем', 'NNP'),
#  ('сорвал', 'NNP'),
#  ('прутик', 'NNP'),
#  ('с', 'NNP'),
#  ('молодой', 'NNP'),
#  ('липкой', 'NNP'),
#  ('кожицей', 'NNP'),
#  (';', ':'),
#  ('по-мальчишески', 'JJ'),
#  ('сбивая', 'NNP'),
#  ('росу', 'NNP'),
#  (',', ','),
#  ('ударил', 'NNP'),
#  ('им', 'NNP'),
#  ('по', 'NNP'),
#  ('головке', 'NNP'),
#  ('какого-то', 'JJ'),
#  ('фиолетового', 'NNP'),
#  ('цветка', 'NNP'),
#  ('у', 'NNP'),
#  ('обочины', 'NNP'),
#  ('(', '('),
#  ('название', 'NNP'),
#  ('которого', 'NNP'),
#  ('в', 'NNP'),
#  ('детстве', 'NNP'),
#  ('знал', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('теперь', 'NNP'),
#  ('забыл', 'NNP'),
#  (')', ')'),
#  ('.', '.'),
#  ('Из', 'JJ'),
#  ('глубины', 'JJ'),
#  ('цветка', 'NN'),
#  ('неожиданно', 'NNP'),
#  ('поднялся', 'NNP'),
#  ('сонный', 'NNP'),
#  ('золотистый', 'NNP'),
#  ('шмель', 'NNP'),
#  (',', ','),
#  ('весь', 'NNP'),
#  ('в', 'NNP'),
#  ('намокшей', 'NNP'),
#  ('пыльце', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('тяжело', 'NNP'),
#  (',', ','),
#  ('сердито', 'NNP'),
#  ('прогудел', 'NNP'),
#  ('мимо', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Ишь', 'JJ'),
#  ('ты', 'NN'),
#  ('!', '.'),
#  ...]

# %%
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
lemmatized = [lemm.lemmatize(word) for word in tokenized]
lemmatized
# Out:
# ['Юрий',
#  'Бондарев',
#  '«',
#  'ПРОСТИТЕ',
#  'НАС',
#  '!',
#  '»',
#  'Южный',
#  'экспресс',
#  'задержался',
#  'здесь',
#  'не',
#  'более',
#  'пяти',
#  'минут',
#  '.',
#  'Павел',
#  'Георгиевич',
#  'долго',
#  'стоял',
#  'на',
#  'безлюдной',
#  'платформе',
#  'и',
#  'слушал',
#  'горячую',
#  'трескотню',
#  'кузнечиков',
#  'за',
#  'насыпью',
#  'степного',
#  'разъезда',
#  '.',
#  'После',
#  'духоты',
#  'вагона',
#  ',',
#  'утомительных',
#  'дорожных',
#  'разговоров',
#  'в',
#  'накуренном',
#  'купе',
#  'за',
#  'полночным',
#  'преферансом',
#  ',',
#  'ненужных',
#  'знакомств',
#  ',',
#  'после',
#  'надоедливого',
#  'поскрипывания',
#  'полок',
#  'Павла',
#  'Георгиевича',
#  'охватила',
#  'неправдоподобная',
#  'тишина',
#  ',',
#  'казалось',
#  ',',
#  'совсем',
#  'как',
#  'в',
#  'детстве',
#  '.',
#  'Он',
#  'не',
#  'без',
#  'удовольствия',
#  'сел',
#  'на',
#  'чемодан',
#  ',',
#  'перекинул',
#  'плащ',
#  'через',
#  'плечо',
#  'и',
#  'сидел',
#  'так',
#  ',',
#  'оглядываясь',
#  'со',
#  'счастливым',
#  'облегчением',
#  '.',
#  'Хотя',
#  'по',
#  'роду',
#  'своей',
#  'профессии',
#  'ему',
#  'не',
#  'так',
#  'много',
#  'приходилось',
#  'ездить',
#  ',',
#  'он',
#  'непонятно',
#  'почему',
#  'любил',
#  'нефтяной',
#  'запах',
#  'шпал',
#  ',',
#  'гудки',
#  'паровозов',
#  ',',
#  'спешащий',
#  'перестук',
#  'колес',
#  ',',
#  'мотание',
#  'из',
#  'стороны',
#  'в',
#  'сторону',
#  'последней',
#  'площадки',
#  ',',
#  'где',
#  'в',
#  'руке',
#  'кондуктора',
#  'мелькал',
#  'выцветший',
#  'свернутый',
#  'флажок',
#  ',',
#  'теплый',
#  'ветер',
#  'от',
#  'бегущих',
#  'вагонов',
#  '—',
#  'все',
#  'это',
#  'будило',
#  'смутное',
#  'желание',
#  'к',
#  'движению',
#  ',',
#  'к',
#  'перемене',
#  'мест',
#  '.',
#  'Иногда',
#  'в',
#  'Москве',
#  ',',
#  'до',
#  'глубокой',
#  'ночи',
#  'засиживаясь',
#  'над',
#  'чертежами',
#  ',',
#  'он',
#  'подымал',
#  'голову',
#  ',',
#  'глядя',
#  'в',
#  'распахнутое',
#  'в',
#  'тополя',
#  'окно',
#  ',',
#  'и',
#  ',',
#  'задумавшись',
#  ',',
#  'подолгу',
#  'слушал',
#  ',',
#  'как',
#  'вкрадчиво',
#  'над',
#  'спящим',
#  'городом',
#  'перекликались',
#  'на',
#  'вокзалах',
#  'ночные',
#  'поезда',
#  '.',
#  'Порой',
#  'гудки',
#  'мешали',
#  'ему',
#  ',',
#  'будоражили',
#  'его',
#  ',',
#  'и',
#  'отчего-то',
#  'тогда',
#  'вспоминалась',
#  'вечереющая',
#  'степь',
#  'с',
#  'пыльным',
#  'закатом',
#  'над',
#  'темными',
#  'стогами',
#  ',',
#  'и',
#  ',',
#  'подхваченный',
#  'волнением',
#  ',',
#  'он',
#  'бросал',
#  'работу',
#  ',',
#  'на',
#  'цыпочках',
#  ',',
#  'чтобы',
#  'не',
#  'разбудить',
#  'жену',
#  ',',
#  'уходил',
#  'из',
#  'дому',
#  ',',
#  'бродил',
#  'по',
#  'пустынным',
#  'и',
#  'тихим',
#  'улицам',
#  '.',
#  'Павел',
#  'Георгиевич',
#  'Сафонов',
#  'работал',
#  'на',
#  'большом',
#  'заводе',
#  'конструктором',
#  ',',
#  'был',
#  'известен',
#  ',',
#  'с',
#  'годами',
#  'привык',
#  'к',
#  'этой',
#  'известности',
#  'и',
#  ',',
#  'казалось',
#  ',',
#  'даже',
#  'немного',
#  'устал',
#  'от',
#  'нее',
#  ',',
#  'как',
#  'порой',
#  'устают',
#  'люди',
#  ',',
#  'когда',
#  'к',
#  'ним',
#  'рано',
#  'приходит',
#  'успех',
#  'и',
#  'удовлетворение',
#  '.',
#  'В',
#  'этом',
#  'году',
#  'Сафонов',
#  ',',
#  'утомленный',
#  'сложной',
#  'зимней',
#  'работой',
#  ',',
#  'был',
#  'в',
#  'санатории',
#  'на',
#  'Южном',
#  'берегу',
#  'Крыма',
#  '.',
#  'Ослепительно-солнечный',
#  'юг',
#  'с',
#  'его',
#  'острой',
#  ',',
#  'сухой',
#  'жарой',
#  ',',
#  'неестественно',
#  'экзотическими',
#  'пальмами',
#  'на',
#  'бульварах',
#  ',',
#  'прокаленный',
#  'песок',
#  'пляжа',
#  ',',
#  'купание',
#  'и',
#  'процедурное',
#  'лежание',
#  'под',
#  'теплым',
#  'йодистым',
#  'дуновением',
#  'моря',
#  ',',
#  'весь',
#  'санаторный',
#  'режим',
#  'располагали',
#  'к',
#  'безделью',
#  ',',
#  'одолевала',
#  'курортная',
#  'лень',
#  ',',
#  'и',
#  'мысли',
#  'в',
#  'эту',
#  'жару',
#  'тоже',
#  'были',
#  'притупленные',
#  ',',
#  'ленивые',
#  ',',
#  'и',
#  'хотелось',
#  'быстрее',
#  'в',
#  'Москву',
#  ',',
#  'к',
#  'осенним',
#  'дождям',
#  ',',
#  'к',
#  'мокрому',
#  'асфальту',
#  ',',
#  'к',
#  'блеску',
#  'фонарей',
#  'в',
#  'лужах',
#  '.',
#  'Южный',
#  'экспресс',
#  ',',
#  'на',
#  'котором',
#  'Сафонов',
#  'возвращался',
#  'из',
#  'санатория',
#  ',',
#  'мчал',
#  'его',
#  'по',
#  'знакомым',
#  'местам',
#  ',',
#  'где',
#  'Павел',
#  'Георгиевич',
#  'родился',
#  ',',
#  'вырос',
#  ',',
#  'где',
#  'он',
#  'не',
#  'был',
#  'много',
#  'лет',
#  '.',
#  'Утром',
#  ',',
#  'глядя',
#  'в',
#  'овлажненные',
#  'окна',
#  'тамбура',
#  'на',
#  'прохладную',
#  'степь',
#  ',',
#  'Сафонов',
#  'с',
#  'какой-то',
#  'грустной',
#  'обостренностью',
#  'вспоминал',
#  'то',
#  ',',
#  'что',
#  'уже',
#  'было',
#  'полузабыто',
#  ':',
#  'вот',
#  'он',
#  ',',
#  'мальчишка',
#  ',',
#  'в',
#  'грязной',
#  'сатиновой',
#  'рубашке',
#  ',',
#  'с',
#  'цыпками',
#  'на',
#  'руках',
#  ',',
#  'бежит',
#  'по',
#  'этой',
#  'ледяной',
#  'от',
#  'росы',
#  'степи',
#  ',',
#  'бежит',
#  'вслед',
#  'за',
#  'поездом',
#  'неизвестно',
#  'куда',
#  ',',
#  'и',
#  'отяжелевшая',
#  'от',
#  'влаги',
#  'трава',
#  'хлещет',
#  'его',
#  'по',
#  'коленям',
#  ',',
#  'приятно',
#  'холодит',
#  'ноги…',
#  'Сколько',
#  'тогда',
#  'ему',
#  'было',
#  'лет',
#  '?',
#  'Порой',
#  'ясно',
#  'чудилось',
#  ',',
#  'будто',
#  'вместе',
#  'с',
#  'Верой',
#  'он',
#  'идет',
#  'по',
#  'лунным',
#  'косякам',
#  'на',
#  'Шахтинском',
#  'холме',
#  ',',
#  'внятно',
#  'и',
#  'резко',
#  'пахнет',
#  'из',
#  'низин',
#  'полынью',
#  ',',
#  'и',
#  'потрескавшиеся',
#  ',',
#  'обветренные',
#  'губы',
#  'Веры',
#  'тоже',
#  'пахнут',
#  'полынью',
#  '.',
#  'Воспоминания',
#  'возвращали',
#  'его',
#  'в',
#  'давний',
#  'прожитый',
#  '(',
#  'а',
#  'может',
#  'быть',
#  ',',
#  'непрожитый',
#  ')',
#  'мир',
#  ',',
#  'говорили',
#  ',',
#  'напоминали',
#  ',',
#  'что',
#  'ему',
#  'уже',
#  'за',
#  'сорок',
#  'и',
#  'что',
#  'не',
#  'так',
#  'много',
#  'сделано',
#  'в',
#  'его',
#  'жизни',
#  ',',
#  'где',
#  'давно',
#  ',',
#  'отмеченная',
#  'прочными',
#  'вехами',
#  ',',
#  'первая',
#  'молодость',
#  'прошла',
#  '.',
#  'И',
#  'вдруг',
#  'его',
#  'непреодолимо',
#  'потянуло',
#  'побывать',
#  'в',
#  'родном',
#  'своем',
#  'степном',
#  'городке',
#  ':',
#  'побродить',
#  'по',
#  'нему',
#  ',',
#  'почитать',
#  'афиши',
#  'на',
#  'заборах',
#  ',',
#  'увидеть',
#  'старые',
#  'названия',
#  'улиц',
#  ',',
#  'узнать',
#  ',',
#  'что',
#  'изменилось',
#  'в',
#  'нем',
#  'за',
#  'многие',
#  'годы',
#  ',',
#  'непременно',
#  'встретить',
#  'знакомых',
#  'школьных',
#  'лет',
#  ',',
#  'таких',
#  'далеких',
#  ',',
#  'словно',
#  'их',
#  'и',
#  'не',
#  'было',
#  '.',
#  'Ему',
#  'страстно',
#  'захотелось',
#  'посидеть',
#  'с',
#  'другом',
#  'юности',
#  'Витькой',
#  'Снегиревым',
#  'где-нибудь',
#  'в',
#  'летнем',
#  'кафе',
#  ',',
#  'под',
#  'тентом',
#  ',',
#  'за',
#  'холодным',
#  'пивом',
#  ',',
#  'вспомнить',
#  'то',
#  'наивное',
#  ',',
#  'давнее',
#  'и',
#  'милое',
#  ',',
#  'что',
#  'уже',
#  'никогда',
#  'не',
#  'повторится',
#  ',',
#  'но',
#  'что',
#  'все-таки',
#  'было',
#  'когда-то',
#  'в',
#  'его',
#  'жизни',
#  '.',
#  'И',
#  'хотя',
#  'это',
#  'желание',
#  'победило',
#  ',',
#  'Павел',
#  'Георгиевич',
#  'с',
#  'ироническим',
#  'видом',
#  'потер',
#  'нос',
#  '(',
#  'в',
#  'свои',
#  'годы',
#  'он',
#  'иногда',
#  'подтрунивал',
#  'над',
#  'собственными',
#  'желаниями',
#  ')',
#  ',',
#  'вошел',
#  'в',
#  'купе',
#  ',',
#  'где',
#  'все',
#  'спали',
#  ',',
#  'подумал',
#  'еще',
#  'раз',
#  ',',
#  'уложил',
#  'чемодан',
#  ',',
#  'взял',
#  'плащ',
#  'и',
#  ',',
#  'к',
#  'удивлению',
#  'заспанного',
#  'проводника',
#  ',',
#  'бесшумно',
#  'подметающего',
#  'в',
#  'коридоре',
#  ',',
#  'сошел',
#  'на',
#  'маленьком',
#  'разъезде',
#  'этим',
#  'ранним',
#  'августовским',
#  'утром',
#  '.',
#  'Он',
#  'сошел',
#  'не',
#  'на',
#  'вокзале',
#  'в',
#  'городе',
#  ',',
#  'а',
#  'именно',
#  'здесь',
#  ',',
#  'чтобы',
#  'дойти',
#  'до',
#  'города',
#  'пешком',
#  '.',
#  'Южный',
#  'экспресс',
#  'с',
#  'жаркими',
#  'от',
#  'зари',
#  'стеклами',
#  ',',
#  'с',
#  'запыленными',
#  'занавесками',
#  'тронулся',
#  ',',
#  'полетели',
#  'вдоль',
#  'насыпи',
#  'бумажки',
#  ',',
#  'поднятые',
#  'ветром',
#  ',',
#  'и',
#  'ушел',
#  'быстро',
#  ';',
#  'дымки',
#  'почти',
#  'беззвучного',
#  'паровоза',
#  'таяли',
#  'среди',
#  'сиренево',
#  'стекленеющего',
#  'неба',
#  'далеко',
#  'на',
#  'западе',
#  ',',
#  'все',
#  'стихло',
#  '.',
#  'Только',
#  'у',
#  'самой',
#  'насыпи',
#  'неумолчно',
#  'звенели',
#  ',',
#  'трещали',
#  'в',
#  'неестественной',
#  'тишине',
#  'кузнечики',
#  '.',
#  'Сидя',
#  'на',
#  'чемодане',
#  ',',
#  'Сафонов',
#  'не',
#  'без',
#  'волнения',
#  'выкурил',
#  'папиросу',
#  ',',
#  'подумал',
#  ':',
#  '«',
#  'Необычайно',
#  'хорошо',
#  '!',
#  '»',
#  '—',
#  'и',
#  'с',
#  'наслаждением',
#  'вдохнул',
#  'на',
#  'полную',
#  'грудь',
#  'зябкий',
#  'и',
#  'чистый',
#  ',',
#  'как',
#  'ключевая',
#  'вода',
#  ',',
#  'воздух',
#  '.',
#  'Степь',
#  ',',
#  'по-летнему',
#  'пестрая',
#  ',',
#  'в',
#  'этот',
#  'спокойный',
#  'час',
#  'утра',
#  'тепло',
#  'и',
#  'ало',
#  'краснела',
#  'за',
#  'холмами',
#  'на',
#  'востоке',
#  '.',
#  'Там',
#  ',',
#  'в',
#  'эту',
#  'пылающую',
#  ',',
#  'мнилось',
#  ',',
#  'бесконечность',
#  'пылила',
#  'вдали',
#  'по',
#  'косогору',
#  'грузовая',
#  'машина',
#  ',',
#  'и',
#  ',',
#  'четко',
#  'вырезанные',
#  'по',
#  'красному',
#  ',',
#  'проступали',
#  'терриконики',
#  ',',
#  'дальние',
#  'силуэты',
#  'водонапорной',
#  'башни',
#  ',',
#  'оазисы',
#  'беленьких',
#  'домов',
#  ',',
#  'острые',
#  'верхушки',
#  'тополей',
#  '.',
#  'С',
#  'насыпи',
#  'Павел',
#  'Георгиевич',
#  'не',
#  'торопясь',
#  'спустился',
#  'в',
#  'степь',
#  ',',
#  'как',
#  'в',
#  'чашу',
#  ',',
#  'полную',
#  'еще',
#  'сырой',
#  'прохлады',
#  ';',
#  'тугой',
#  'волной',
#  'обдавало',
#  'горьковатым',
#  'запахом',
#  'полыни',
#  '.',
#  'И',
#  'пока',
#  'он',
#  'выбрался',
#  'на',
#  'дорогу',
#  ',',
#  'колени',
#  'его',
#  'стали',
#  'влажными',
#  'от',
#  'росы',
#  ',',
#  'на',
#  'плащ',
#  ',',
#  'на',
#  'брюки',
#  'нацеплялись',
#  'репейники',
#  ',',
#  'чемодан',
#  'облепили',
#  'мокрые',
#  'лепестки',
#  '.',
#  'Он',
#  'шагал',
#  'по',
#  'дороге',
#  ',',
#  'приятно',
#  'утопая',
#  'ботинками',
#  'в',
#  'мягкой',
#  'пыли',
#  ',',
#  'затем',
#  'сорвал',
#  'прутик',
#  'с',
#  'молодой',
#  'липкой',
#  'кожицей',
#  ';',
#  'по-мальчишески',
#  'сбивая',
#  'росу',
#  ',',
#  'ударил',
#  'им',
#  'по',
#  'головке',
#  'какого-то',
#  'фиолетового',
#  'цветка',
#  'у',
#  'обочины',
#  '(',
#  'название',
#  'которого',
#  'в',
#  'детстве',
#  'знал',
#  ',',
#  'но',
#  'теперь',
#  'забыл',
#  ')',
#  '.',
#  'Из',
#  'глубины',
#  'цветка',
#  'неожиданно',
#  'поднялся',
#  'сонный',
#  'золотистый',
#  'шмель',
#  ',',
#  'весь',
#  'в',
#  'намокшей',
#  'пыльце',
#  ',',
#  'и',
#  'тяжело',
#  ',',
#  'сердито',
#  'прогудел',
#  'мимо',
#  '.',
#  '—',
#  'Ишь',
#  'ты',
#  '!',
#  ...]

# %%
def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged
# Out:
# [('Юрий', 'JJ'),
#  ('Бондарев', 'NNP'),
#  ('«', 'NNP'),
#  ('ПРОСТИТЕ', 'NNP'),
#  ('НАС', 'NN'),
#  ('!', '.'),
#  ('»', 'JJ'),
#  ('Южный', 'JJ'),
#  ('экспресс', 'NN'),
#  ('задержался', 'NNP'),
#  ('здесь', 'NNP'),
#  ('не', 'NNP'),
#  ('более', 'NNP'),
#  ('пяти', 'NNP'),
#  ('минут', 'NNP'),
#  ('.', '.'),
#  ('Павел', 'VB'),
#  ('Георгиевич', 'JJ'),
#  ('долго', 'NNP'),
#  ('стоял', 'NNP'),
#  ('на', 'NNP'),
#  ('безлюдной', 'NNP'),
#  ('платформе', 'NNP'),
#  ('и', 'NNP'),
#  ('слушал', 'NNP'),
#  ('горячую', 'NNP'),
#  ('трескотню', 'NNP'),
#  ('кузнечиков', 'NNP'),
#  ('за', 'NNP'),
#  ('насыпью', 'NNP'),
#  ('степного', 'NNP'),
#  ('разъезда', 'NNP'),
#  ('.', '.'),
#  ('После', 'VB'),
#  ('духоты', 'JJ'),
#  ('вагона', 'NNP'),
#  (',', ','),
#  ('утомительных', 'NNP'),
#  ('дорожных', 'NNP'),
#  ('разговоров', 'NNP'),
#  ('в', 'NNP'),
#  ('накуренном', 'NNP'),
#  ('купе', 'NNP'),
#  ('за', 'NNP'),
#  ('полночным', 'NNP'),
#  ('преферансом', 'NNP'),
#  (',', ','),
#  ('ненужных', 'NNP'),
#  ('знакомств', 'NNP'),
#  (',', ','),
#  ('после', 'NNP'),
#  ('надоедливого', 'NNP'),
#  ('поскрипывания', 'NNP'),
#  ('полок', 'NNP'),
#  ('Павла', 'NNP'),
#  ('Георгиевича', 'NNP'),
#  ('охватила', 'NNP'),
#  ('неправдоподобная', 'NNP'),
#  ('тишина', 'NNP'),
#  (',', ','),
#  ('казалось', 'NNP'),
#  (',', ','),
#  ('совсем', 'NNP'),
#  ('как', 'NNP'),
#  ('в', 'NNP'),
#  ('детстве', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('не', 'JJ'),
#  ('без', 'NNP'),
#  ('удовольствия', 'NNP'),
#  ('сел', 'NNP'),
#  ('на', 'NNP'),
#  ('чемодан', 'NNP'),
#  (',', ','),
#  ('перекинул', 'NNP'),
#  ('плащ', 'NNP'),
#  ('через', 'NNP'),
#  ('плечо', 'NNP'),
#  ('и', 'NNP'),
#  ('сидел', 'NNP'),
#  ('так', 'NNP'),
#  (',', ','),
#  ('оглядываясь', 'NNP'),
#  ('со', 'NNP'),
#  ('счастливым', 'NNP'),
#  ('облегчением', 'NNP'),
#  ('.', '.'),
#  ('Хотя', 'VB'),
#  ('по', 'JJ'),
#  ('роду', 'NNP'),
#  ('своей', 'NNP'),
#  ('профессии', 'NNP'),
#  ('ему', 'NNP'),
#  ('не', 'NNP'),
#  ('так', 'NNP'),
#  ('много', 'NNP'),
#  ('приходилось', 'NNP'),
#  ('ездить', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('непонятно', 'NNP'),
#  ('почему', 'NNP'),
#  ('любил', 'NNP'),
#  ('нефтяной', 'NNP'),
#  ('запах', 'NNP'),
#  ('шпал', 'NNP'),
#  (',', ','),
#  ('гудки', 'NNP'),
#  ('паровозов', 'NNP'),
#  (',', ','),
#  ('спешащий', 'NNP'),
#  ('перестук', 'NNP'),
#  ('колес', 'NNP'),
#  (',', ','),
#  ('мотание', 'NNP'),
#  ('из', 'NNP'),
#  ('стороны', 'NNP'),
#  ('в', 'NNP'),
#  ('сторону', 'NNP'),
#  ('последней', 'NNP'),
#  ('площадки', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('в', 'NNP'),
#  ('руке', 'NNP'),
#  ('кондуктора', 'NNP'),
#  ('мелькал', 'NNP'),
#  ('выцветший', 'NNP'),
#  ('свернутый', 'NNP'),
#  ('флажок', 'NNP'),
#  (',', ','),
#  ('теплый', 'NNP'),
#  ('ветер', 'NNP'),
#  ('от', 'NNP'),
#  ('бегущих', 'NNP'),
#  ('вагонов', 'NNP'),
#  ('—', 'NNP'),
#  ('все', 'NNP'),
#  ('это', 'NNP'),
#  ('будило', 'NNP'),
#  ('смутное', 'NNP'),
#  ('желание', 'NNP'),
#  ('к', 'NNP'),
#  ('движению', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('перемене', 'NNP'),
#  ('мест', 'NNP'),
#  ('.', '.'),
#  ('Иногда', 'VB'),
#  ('в', 'JJ'),
#  ('Москве', 'NNP'),
#  (',', ','),
#  ('до', 'NNP'),
#  ('глубокой', 'NNP'),
#  ('ночи', 'NNP'),
#  ('засиживаясь', 'NNP'),
#  ('над', 'NNP'),
#  ('чертежами', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('подымал', 'NNP'),
#  ('голову', 'NNP'),
#  (',', ','),
#  ('глядя', 'NNP'),
#  ('в', 'NNP'),
#  ('распахнутое', 'NNP'),
#  ('в', 'NNP'),
#  ('тополя', 'NNP'),
#  ('окно', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('задумавшись', 'NNP'),
#  (',', ','),
#  ('подолгу', 'NNP'),
#  ('слушал', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('вкрадчиво', 'NNP'),
#  ('над', 'NNP'),
#  ('спящим', 'NNP'),
#  ('городом', 'NNP'),
#  ('перекликались', 'NNP'),
#  ('на', 'NNP'),
#  ('вокзалах', 'NNP'),
#  ('ночные', 'NNP'),
#  ('поезда', 'NNP'),
#  ('.', '.'),
#  ('Порой', 'VB'),
#  ('гудки', 'JJ'),
#  ('мешали', 'NNP'),
#  ('ему', 'NNP'),
#  (',', ','),
#  ('будоражили', 'NNP'),
#  ('его', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('отчего-то', 'NNP'),
#  ('тогда', 'NNP'),
#  ('вспоминалась', 'NNP'),
#  ('вечереющая', 'NNP'),
#  ('степь', 'NNP'),
#  ('с', 'NNP'),
#  ('пыльным', 'NNP'),
#  ('закатом', 'NNP'),
#  ('над', 'NNP'),
#  ('темными', 'NNP'),
#  ('стогами', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('подхваченный', 'NNP'),
#  ('волнением', 'NNP'),
#  (',', ','),
#  ('он', 'NNP'),
#  ('бросал', 'NNP'),
#  ('работу', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('цыпочках', 'NNP'),
#  (',', ','),
#  ('чтобы', 'NNP'),
#  ('не', 'NNP'),
#  ('разбудить', 'NNP'),
#  ('жену', 'NNP'),
#  (',', ','),
#  ('уходил', 'NNP'),
#  ('из', 'NNP'),
#  ('дому', 'NNP'),
#  (',', ','),
#  ('бродил', 'NNP'),
#  ('по', 'NNP'),
#  ('пустынным', 'NNP'),
#  ('и', 'NNP'),
#  ('тихим', 'NNP'),
#  ('улицам', 'NNP'),
#  ('.', '.'),
#  ('Павел', 'VB'),
#  ('Георгиевич', 'JJ'),
#  ('Сафонов', 'NNP'),
#  ('работал', 'NNP'),
#  ('на', 'NNP'),
#  ('большом', 'NNP'),
#  ('заводе', 'NNP'),
#  ('конструктором', 'NNP'),
#  (',', ','),
#  ('был', 'NNP'),
#  ('известен', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('годами', 'NNP'),
#  ('привык', 'NNP'),
#  ('к', 'NNP'),
#  ('этой', 'NNP'),
#  ('известности', 'NNP'),
#  ('и', 'NNP'),
#  (',', ','),
#  ('казалось', 'NNP'),
#  (',', ','),
#  ('даже', 'NNP'),
#  ('немного', 'NNP'),
#  ('устал', 'NNP'),
#  ('от', 'NNP'),
#  ('нее', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('порой', 'NNP'),
#  ('устают', 'NNP'),
#  ('люди', 'NNP'),
#  (',', ','),
#  ('когда', 'NNP'),
#  ('к', 'NNP'),
#  ('ним', 'NNP'),
#  ('рано', 'NNP'),
#  ('приходит', 'NNP'),
#  ('успех', 'NNP'),
#  ('и', 'NNP'),
#  ('удовлетворение', 'NNP'),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('этом', 'JJ'),
#  ('году', 'NNP'),
#  ('Сафонов', 'NNP'),
#  (',', ','),
#  ('утомленный', 'NNP'),
#  ('сложной', 'NNP'),
#  ('зимней', 'NNP'),
#  ('работой', 'NNP'),
#  (',', ','),
#  ('был', 'NNP'),
#  ('в', 'NNP'),
#  ('санатории', 'NNP'),
#  ('на', 'NNP'),
#  ('Южном', 'NNP'),
#  ('берегу', 'NNP'),
#  ('Крыма', 'NNP'),
#  ('.', '.'),
#  ('Ослепительно-солнечный', 'JJ'),
#  ('юг', 'JJ'),
#  ('с', 'NN'),
#  ('его', 'NNP'),
#  ('острой', 'NNP'),
#  (',', ','),
#  ('сухой', 'NNP'),
#  ('жарой', 'NNP'),
#  (',', ','),
#  ('неестественно', 'NNP'),
#  ('экзотическими', 'NNP'),
#  ('пальмами', 'NNP'),
#  ('на', 'NNP'),
#  ('бульварах', 'NNP'),
#  (',', ','),
#  ('прокаленный', 'NNP'),
#  ('песок', 'NNP'),
#  ('пляжа', 'NNP'),
#  (',', ','),
#  ('купание', 'NNP'),
#  ('и', 'NNP'),
#  ('процедурное', 'NNP'),
#  ('лежание', 'NNP'),
#  ('под', 'NNP'),
#  ('теплым', 'NNP'),
#  ('йодистым', 'NNP'),
#  ('дуновением', 'NNP'),
#  ('моря', 'NNP'),
#  (',', ','),
#  ('весь', 'NNP'),
#  ('санаторный', 'NNP'),
#  ('режим', 'NNP'),
#  ('располагали', 'NNP'),
#  ('к', 'NNP'),
#  ('безделью', 'NNP'),
#  (',', ','),
#  ('одолевала', 'NNP'),
#  ('курортная', 'NNP'),
#  ('лень', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('мысли', 'NNP'),
#  ('в', 'NNP'),
#  ('эту', 'NNP'),
#  ('жару', 'NNP'),
#  ('тоже', 'NNP'),
#  ('были', 'NNP'),
#  ('притупленные', 'NNP'),
#  (',', ','),
#  ('ленивые', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('хотелось', 'NNP'),
#  ('быстрее', 'NNP'),
#  ('в', 'NNP'),
#  ('Москву', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('осенним', 'NNP'),
#  ('дождям', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('мокрому', 'NNP'),
#  ('асфальту', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('блеску', 'NNP'),
#  ('фонарей', 'NNP'),
#  ('в', 'NNP'),
#  ('лужах', 'NNP'),
#  ('.', '.'),
#  ('Южный', 'NN'),
#  ('экспресс', 'NN'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('котором', 'NNP'),
#  ('Сафонов', 'NNP'),
#  ('возвращался', 'NNP'),
#  ('из', 'NNP'),
#  ('санатория', 'NNP'),
#  (',', ','),
#  ('мчал', 'NNP'),
#  ('его', 'NNP'),
#  ('по', 'NNP'),
#  ('знакомым', 'NNP'),
#  ('местам', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('Павел', 'NNP'),
#  ('Георгиевич', 'NNP'),
#  ('родился', 'NNP'),
#  (',', ','),
#  ('вырос', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('он', 'NNP'),
#  ('не', 'NNP'),
#  ('был', 'NNP'),
#  ('много', 'NNP'),
#  ('лет', 'NNP'),
#  ('.', '.'),
#  ('Утром', 'NN'),
#  (',', ','),
#  ('глядя', 'NNP'),
#  ('в', 'NNP'),
#  ('овлажненные', 'NNP'),
#  ('окна', 'NNP'),
#  ('тамбура', 'NNP'),
#  ('на', 'NNP'),
#  ('прохладную', 'NNP'),
#  ('степь', 'NNP'),
#  (',', ','),
#  ('Сафонов', 'NNP'),
#  ('с', 'NNP'),
#  ('какой-то', 'JJ'),
#  ('грустной', 'NNP'),
#  ('обостренностью', 'NNP'),
#  ('вспоминал', 'NNP'),
#  ('то', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('уже', 'NNP'),
#  ('было', 'NNP'),
#  ('полузабыто', 'NN'),
#  (':', ':'),
#  ('вот', 'NN'),
#  ('он', 'NN'),
#  (',', ','),
#  ('мальчишка', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('грязной', 'NNP'),
#  ('сатиновой', 'NNP'),
#  ('рубашке', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('цыпками', 'NNP'),
#  ('на', 'NNP'),
#  ('руках', 'NNP'),
#  (',', ','),
#  ('бежит', 'NNP'),
#  ('по', 'NNP'),
#  ('этой', 'NNP'),
#  ('ледяной', 'NNP'),
#  ('от', 'NNP'),
#  ('росы', 'NNP'),
#  ('степи', 'NNP'),
#  (',', ','),
#  ('бежит', 'NNP'),
#  ('вслед', 'NNP'),
#  ('за', 'NNP'),
#  ('поездом', 'NNP'),
#  ('неизвестно', 'NNP'),
#  ('куда', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('отяжелевшая', 'NNP'),
#  ('от', 'NNP'),
#  ('влаги', 'NNP'),
#  ('трава', 'NNP'),
#  ('хлещет', 'NNP'),
#  ('его', 'NNP'),
#  ('по', 'NNP'),
#  ('коленям', 'NNP'),
#  (',', ','),
#  ('приятно', 'NNP'),
#  ('холодит', 'NNP'),
#  ('ноги…', 'NNP'),
#  ('Сколько', 'NNP'),
#  ('тогда', 'NNP'),
#  ('ему', 'NNP'),
#  ('было', 'NNP'),
#  ('лет', 'NNP'),
#  ('?', '.'),
#  ('Порой', 'NNP'),
#  ('ясно', 'NNP'),
#  ('чудилось', 'NNP'),
#  (',', ','),
#  ('будто', 'NNP'),
#  ('вместе', 'NNP'),
#  ('с', 'NNP'),
#  ('Верой', 'NNP'),
#  ('он', 'NNP'),
#  ('идет', 'NNP'),
#  ('по', 'NNP'),
#  ('лунным', 'NNP'),
#  ('косякам', 'NNP'),
#  ('на', 'NNP'),
#  ('Шахтинском', 'NNP'),
#  ('холме', 'NNP'),
#  (',', ','),
#  ('внятно', 'NNP'),
#  ('и', 'NNP'),
#  ('резко', 'NNP'),
#  ('пахнет', 'NNP'),
#  ('из', 'NNP'),
#  ('низин', 'NNP'),
#  ('полынью', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('потрескавшиеся', 'NNP'),
#  (',', ','),
#  ('обветренные', 'NNP'),
#  ('губы', 'NNP'),
#  ('Веры', 'NNP'),
#  ('тоже', 'NNP'),
#  ('пахнут', 'NNP'),
#  ('полынью', 'NNP'),
#  ('.', '.'),
#  ('Воспоминания', 'VB'),
#  ('возвращали', 'JJ'),
#  ('его', 'NNP'),
#  ('в', 'NNP'),
#  ('давний', 'NNP'),
#  ('прожитый', 'NNP'),
#  ('(', '('),
#  ('а', 'NNP'),
#  ('может', 'NNP'),
#  ('быть', 'NNP'),
#  (',', ','),
#  ('непрожитый', 'NNP'),
#  (')', ')'),
#  ('мир', 'NN'),
#  (',', ','),
#  ('говорили', 'NNP'),
#  (',', ','),
#  ('напоминали', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('ему', 'NNP'),
#  ('уже', 'NNP'),
#  ('за', 'NNP'),
#  ('сорок', 'NNP'),
#  ('и', 'NNP'),
#  ('что', 'NNP'),
#  ('не', 'NNP'),
#  ('так', 'NNP'),
#  ('много', 'NNP'),
#  ('сделано', 'NNP'),
#  ('в', 'NNP'),
#  ('его', 'NNP'),
#  ('жизни', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('давно', 'NNP'),
#  (',', ','),
#  ('отмеченная', 'NNP'),
#  ('прочными', 'NNP'),
#  ('вехами', 'NNP'),
#  (',', ','),
#  ('первая', 'NNP'),
#  ('молодость', 'NNP'),
#  ('прошла', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('вдруг', 'JJ'),
#  ('его', 'NNP'),
#  ('непреодолимо', 'NNP'),
#  ('потянуло', 'NNP'),
#  ('побывать', 'NNP'),
#  ('в', 'NNP'),
#  ('родном', 'NNP'),
#  ('своем', 'NNP'),
#  ('степном', 'NNP'),
#  ('городке', 'NN'),
#  (':', ':'),
#  ('побродить', 'JJ'),
#  ('по', 'NNP'),
#  ('нему', 'NNP'),
#  (',', ','),
#  ('почитать', 'NNP'),
#  ('афиши', 'NNP'),
#  ('на', 'NNP'),
#  ('заборах', 'NNP'),
#  (',', ','),
#  ('увидеть', 'NNP'),
#  ('старые', 'NNP'),
#  ('названия', 'NNP'),
#  ('улиц', 'NNP'),
#  (',', ','),
#  ('узнать', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('изменилось', 'NNP'),
#  ('в', 'NNP'),
#  ('нем', 'NNP'),
#  ('за', 'NNP'),
#  ('многие', 'NNP'),
#  ('годы', 'NNP'),
#  (',', ','),
#  ('непременно', 'NNP'),
#  ('встретить', 'NNP'),
#  ('знакомых', 'NNP'),
#  ('школьных', 'NNP'),
#  ('лет', 'NNP'),
#  (',', ','),
#  ('таких', 'NNP'),
#  ('далеких', 'NNP'),
#  (',', ','),
#  ('словно', 'NNP'),
#  ('их', 'NNP'),
#  ('и', 'NNP'),
#  ('не', 'NNP'),
#  ('было', 'NNP'),
#  ('.', '.'),
#  ('Ему', 'VB'),
#  ('страстно', 'JJ'),
#  ('захотелось', 'NNP'),
#  ('посидеть', 'NNP'),
#  ('с', 'NNP'),
#  ('другом', 'NNP'),
#  ('юности', 'NNP'),
#  ('Витькой', 'NNP'),
#  ('Снегиревым', 'NNP'),
#  ('где-нибудь', 'JJ'),
#  ('в', 'NNP'),
#  ('летнем', 'NNP'),
#  ('кафе', 'NNP'),
#  (',', ','),
#  ('под', 'NNP'),
#  ('тентом', 'NNP'),
#  (',', ','),
#  ('за', 'NNP'),
#  ('холодным', 'NNP'),
#  ('пивом', 'NNP'),
#  (',', ','),
#  ('вспомнить', 'NNP'),
#  ('то', 'NNP'),
#  ('наивное', 'NNP'),
#  (',', ','),
#  ('давнее', 'NNP'),
#  ('и', 'NNP'),
#  ('милое', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('уже', 'NNP'),
#  ('никогда', 'NNP'),
#  ('не', 'NNP'),
#  ('повторится', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('что', 'NNP'),
#  ('все-таки', 'JJ'),
#  ('было', 'NNP'),
#  ('когда-то', 'JJ'),
#  ('в', 'NNP'),
#  ('его', 'NNP'),
#  ('жизни', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('хотя', 'JJ'),
#  ('это', 'NNP'),
#  ('желание', 'NNP'),
#  ('победило', 'NNP'),
#  (',', ','),
#  ('Павел', 'NNP'),
#  ('Георгиевич', 'NNP'),
#  ('с', 'NNP'),
#  ('ироническим', 'NNP'),
#  ('видом', 'NNP'),
#  ('потер', 'NNP'),
#  ('нос', 'NNP'),
#  ('(', '('),
#  ('в', 'NNP'),
#  ('свои', 'NNP'),
#  ('годы', 'NNP'),
#  ('он', 'NNP'),
#  ('иногда', 'NNP'),
#  ('подтрунивал', 'NNP'),
#  ('над', 'NNP'),
#  ('собственными', 'NNP'),
#  ('желаниями', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('вошел', 'JJ'),
#  ('в', 'NNP'),
#  ('купе', 'NNP'),
#  (',', ','),
#  ('где', 'NNP'),
#  ('все', 'NNP'),
#  ('спали', 'NNP'),
#  (',', ','),
#  ('подумал', 'NNP'),
#  ('еще', 'NNP'),
#  ('раз', 'NNP'),
#  (',', ','),
#  ('уложил', 'NNP'),
#  ('чемодан', 'NNP'),
#  (',', ','),
#  ('взял', 'NNP'),
#  ('плащ', 'NNP'),
#  ('и', 'NNP'),
#  (',', ','),
#  ('к', 'NNP'),
#  ('удивлению', 'NNP'),
#  ('заспанного', 'NNP'),
#  ('проводника', 'NNP'),
#  (',', ','),
#  ('бесшумно', 'NNP'),
#  ('подметающего', 'NNP'),
#  ('в', 'NNP'),
#  ('коридоре', 'NNP'),
#  (',', ','),
#  ('сошел', 'NNP'),
#  ('на', 'NNP'),
#  ('маленьком', 'NNP'),
#  ('разъезде', 'NNP'),
#  ('этим', 'NNP'),
#  ('ранним', 'NNP'),
#  ('августовским', 'NNP'),
#  ('утром', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('сошел', 'JJ'),
#  ('не', 'NNP'),
#  ('на', 'NNP'),
#  ('вокзале', 'NNP'),
#  ('в', 'NNP'),
#  ('городе', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('именно', 'NNP'),
#  ('здесь', 'NNP'),
#  (',', ','),
#  ('чтобы', 'NNP'),
#  ('дойти', 'NNP'),
#  ('до', 'NNP'),
#  ('города', 'NNP'),
#  ('пешком', 'NNP'),
#  ('.', '.'),
#  ('Южный', 'VB'),
#  ('экспресс', 'JJ'),
#  ('с', 'NNP'),
#  ('жаркими', 'NNP'),
#  ('от', 'NNP'),
#  ('зари', 'NNP'),
#  ('стеклами', 'NNP'),
#  (',', ','),
#  ('с', 'NNP'),
#  ('запыленными', 'NNP'),
#  ('занавесками', 'NNP'),
#  ('тронулся', 'NNP'),
#  (',', ','),
#  ('полетели', 'NNP'),
#  ('вдоль', 'NNP'),
#  ('насыпи', 'NNP'),
#  ('бумажки', 'NNP'),
#  (',', ','),
#  ('поднятые', 'NNP'),
#  ('ветром', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('ушел', 'NNP'),
#  ('быстро', 'NNP'),
#  (';', ':'),
#  ('дымки', 'NNP'),
#  ('почти', 'NNP'),
#  ('беззвучного', 'NNP'),
#  ('паровоза', 'NNP'),
#  ('таяли', 'NNP'),
#  ('среди', 'NNP'),
#  ('сиренево', 'NNP'),
#  ('стекленеющего', 'NNP'),
#  ('неба', 'NNP'),
#  ('далеко', 'NNP'),
#  ('на', 'NNP'),
#  ('западе', 'NNP'),
#  (',', ','),
#  ('все', 'NNP'),
#  ('стихло', 'NNP'),
#  ('.', '.'),
#  ('Только', 'VB'),
#  ('у', 'JJ'),
#  ('самой', 'NNP'),
#  ('насыпи', 'NNP'),
#  ('неумолчно', 'NNP'),
#  ('звенели', 'NNP'),
#  (',', ','),
#  ('трещали', 'NNP'),
#  ('в', 'NNP'),
#  ('неестественной', 'NNP'),
#  ('тишине', 'NNP'),
#  ('кузнечики', 'NNP'),
#  ('.', '.'),
#  ('Сидя', 'VB'),
#  ('на', 'JJ'),
#  ('чемодане', 'NNP'),
#  (',', ','),
#  ('Сафонов', 'NNP'),
#  ('не', 'NNP'),
#  ('без', 'NNP'),
#  ('волнения', 'NNP'),
#  ('выкурил', 'NNP'),
#  ('папиросу', 'NNP'),
#  (',', ','),
#  ('подумал', 'NN'),
#  (':', ':'),
#  ('«', 'JJ'),
#  ('Необычайно', 'NNP'),
#  ('хорошо', 'NN'),
#  ('!', '.'),
#  ('»', 'JJ'),
#  ('—', 'JJ'),
#  ('и', 'NN'),
#  ('с', 'NNP'),
#  ('наслаждением', 'NNP'),
#  ('вдохнул', 'NNP'),
#  ('на', 'NNP'),
#  ('полную', 'NNP'),
#  ('грудь', 'NNP'),
#  ('зябкий', 'NNP'),
#  ('и', 'NNP'),
#  ('чистый', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('ключевая', 'NNP'),
#  ('вода', 'NNP'),
#  (',', ','),
#  ('воздух', 'NNP'),
#  ('.', '.'),
#  ('Степь', 'NN'),
#  (',', ','),
#  ('по-летнему', 'JJ'),
#  ('пестрая', 'NN'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('этот', 'NNP'),
#  ('спокойный', 'NNP'),
#  ('час', 'NNP'),
#  ('утра', 'NNP'),
#  ('тепло', 'NNP'),
#  ('и', 'NNP'),
#  ('ало', 'NNP'),
#  ('краснела', 'NNP'),
#  ('за', 'NNP'),
#  ('холмами', 'NNP'),
#  ('на', 'NNP'),
#  ('востоке', 'NNP'),
#  ('.', '.'),
#  ('Там', 'NN'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('эту', 'NNP'),
#  ('пылающую', 'NNP'),
#  (',', ','),
#  ('мнилось', 'NNP'),
#  (',', ','),
#  ('бесконечность', 'NNP'),
#  ('пылила', 'NNP'),
#  ('вдали', 'NNP'),
#  ('по', 'NNP'),
#  ('косогору', 'NNP'),
#  ('грузовая', 'NNP'),
#  ('машина', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  (',', ','),
#  ('четко', 'NNP'),
#  ('вырезанные', 'NNP'),
#  ('по', 'NNP'),
#  ('красному', 'NNP'),
#  (',', ','),
#  ('проступали', 'NNP'),
#  ('терриконики', 'NNP'),
#  (',', ','),
#  ('дальние', 'NNP'),
#  ('силуэты', 'NNP'),
#  ('водонапорной', 'NNP'),
#  ('башни', 'NNP'),
#  (',', ','),
#  ('оазисы', 'NNP'),
#  ('беленьких', 'NNP'),
#  ('домов', 'NNP'),
#  (',', ','),
#  ('острые', 'NNP'),
#  ('верхушки', 'NNP'),
#  ('тополей', 'NNP'),
#  ('.', '.'),
#  ('С', 'VB'),
#  ('насыпи', 'JJ'),
#  ('Павел', 'NNP'),
#  ('Георгиевич', 'NNP'),
#  ('не', 'NNP'),
#  ('торопясь', 'NNP'),
#  ('спустился', 'NNP'),
#  ('в', 'NNP'),
#  ('степь', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('в', 'NNP'),
#  ('чашу', 'NNP'),
#  (',', ','),
#  ('полную', 'NNP'),
#  ('еще', 'NNP'),
#  ('сырой', 'NNP'),
#  ('прохлады', 'NNP'),
#  (';', ':'),
#  ('тугой', 'NNP'),
#  ('волной', 'NNP'),
#  ('обдавало', 'NNP'),
#  ('горьковатым', 'NNP'),
#  ('запахом', 'NNP'),
#  ('полыни', 'NNP'),
#  ('.', '.'),
#  ('И', 'VB'),
#  ('пока', 'JJ'),
#  ('он', 'NNP'),
#  ('выбрался', 'NNP'),
#  ('на', 'NNP'),
#  ('дорогу', 'NNP'),
#  (',', ','),
#  ('колени', 'NNP'),
#  ('его', 'NNP'),
#  ('стали', 'NNP'),
#  ('влажными', 'NNP'),
#  ('от', 'NNP'),
#  ('росы', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('плащ', 'NNP'),
#  (',', ','),
#  ('на', 'NNP'),
#  ('брюки', 'NNP'),
#  ('нацеплялись', 'NNP'),
#  ('репейники', 'NNP'),
#  (',', ','),
#  ('чемодан', 'NNP'),
#  ('облепили', 'NNP'),
#  ('мокрые', 'NNP'),
#  ('лепестки', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('шагал', 'JJ'),
#  ('по', 'NNP'),
#  ('дороге', 'NNP'),
#  (',', ','),
#  ('приятно', 'NNP'),
#  ('утопая', 'NNP'),
#  ('ботинками', 'NNP'),
#  ('в', 'NNP'),
#  ('мягкой', 'NNP'),
#  ('пыли', 'NNP'),
#  (',', ','),
#  ('затем', 'NNP'),
#  ('сорвал', 'NNP'),
#  ('прутик', 'NNP'),
#  ('с', 'NNP'),
#  ('молодой', 'NNP'),
#  ('липкой', 'NNP'),
#  ('кожицей', 'NNP'),
#  (';', ':'),
#  ('по-мальчишески', 'JJ'),
#  ('сбивая', 'NNP'),
#  ('росу', 'NNP'),
#  (',', ','),
#  ('ударил', 'NNP'),
#  ('им', 'NNP'),
#  ('по', 'NNP'),
#  ('головке', 'NNP'),
#  ('какого-то', 'JJ'),
#  ('фиолетового', 'NNP'),
#  ('цветка', 'NNP'),
#  ('у', 'NNP'),
#  ('обочины', 'NNP'),
#  ('(', '('),
#  ('название', 'NNP'),
#  ('которого', 'NNP'),
#  ('в', 'NNP'),
#  ('детстве', 'NNP'),
#  ('знал', 'NNP'),
#  (',', ','),
#  ('но', 'NNP'),
#  ('теперь', 'NNP'),
#  ('забыл', 'NNP'),
#  (')', ')'),
#  ('.', '.'),
#  ('Из', 'JJ'),
#  ('глубины', 'JJ'),
#  ('цветка', 'NN'),
#  ('неожиданно', 'NNP'),
#  ('поднялся', 'NNP'),
#  ('сонный', 'NNP'),
#  ('золотистый', 'NNP'),
#  ('шмель', 'NNP'),
#  (',', ','),
#  ('весь', 'NNP'),
#  ('в', 'NNP'),
#  ('намокшей', 'NNP'),
#  ('пыльце', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('тяжело', 'NNP'),
#  (',', ','),
#  ('сердито', 'NNP'),
#  ('прогудел', 'NNP'),
#  ('мимо', 'NNP'),
#  ('.', '.'),
#  ('—', 'VB'),
#  ('Ишь', 'JJ'),
#  ('ты', 'NN'),
#  ('!', '.'),
#  ...]

# %%
stemmer = SnowballStemmer(language='russian')
with open("Forgive_us!.txt", encoding="utf-8") as file:
    text = file.read()
tokenized = nltk.word_tokenize(text)
stemmed = [stemmer.stem(word) for word in tokenized]
stemmed
# Out:
# ['юр',
#  'бондар',
#  '«',
#  'прост',
#  'нас',
#  '!',
#  '»',
#  'южн',
#  'экспресс',
#  'задержа',
#  'зде',
#  'не',
#  'бол',
#  'пят',
#  'минут',
#  '.',
#  'павел',
#  'георгиевич',
#  'долг',
#  'стоя',
#  'на',
#  'безлюдн',
#  'платформ',
#  'и',
#  'слуша',
#  'горяч',
#  'трескотн',
#  'кузнечик',
#  'за',
#  'насып',
#  'степн',
#  'разъезд',
#  '.',
#  'посл',
#  'духот',
#  'вагон',
#  ',',
#  'утомительн',
#  'дорожн',
#  'разговор',
#  'в',
#  'накурен',
#  'куп',
#  'за',
#  'полночн',
#  'преферанс',
#  ',',
#  'ненужн',
#  'знакомств',
#  ',',
#  'посл',
#  'надоедлив',
#  'поскрипыван',
#  'полок',
#  'павл',
#  'георгиевич',
#  'охват',
#  'неправдоподобн',
#  'тишин',
#  ',',
#  'каза',
#  ',',
#  'совс',
#  'как',
#  'в',
#  'детств',
#  '.',
#  'он',
#  'не',
#  'без',
#  'удовольств',
#  'сел',
#  'на',
#  'чемода',
#  ',',
#  'перекинул',
#  'плащ',
#  'через',
#  'плеч',
#  'и',
#  'сидел',
#  'так',
#  ',',
#  'оглядыв',
#  'со',
#  'счастлив',
#  'облегчен',
#  '.',
#  'хот',
#  'по',
#  'род',
#  'сво',
#  'професс',
#  'ем',
#  'не',
#  'так',
#  'мног',
#  'приход',
#  'езд',
#  ',',
#  'он',
#  'непонятн',
#  'поч',
#  'люб',
#  'нефтян',
#  'зап',
#  'шпал',
#  ',',
#  'гудк',
#  'паровоз',
#  ',',
#  'спеша',
#  'перестук',
#  'колес',
#  ',',
#  'мотан',
#  'из',
#  'сторон',
#  'в',
#  'сторон',
#  'последн',
#  'площадк',
#  ',',
#  'где',
#  'в',
#  'рук',
#  'кондуктор',
#  'мелька',
#  'выцветш',
#  'свернут',
#  'флажок',
#  ',',
#  'тепл',
#  'ветер',
#  'от',
#  'бегущ',
#  'вагон',
#  '—',
#  'все',
#  'эт',
#  'буд',
#  'смутн',
#  'желан',
#  'к',
#  'движен',
#  ',',
#  'к',
#  'перемен',
#  'мест',
#  '.',
#  'иногд',
#  'в',
#  'москв',
#  ',',
#  'до',
#  'глубок',
#  'ноч',
#  'засижив',
#  'над',
#  'чертеж',
#  ',',
#  'он',
#  'подыма',
#  'голов',
#  ',',
#  'гляд',
#  'в',
#  'распахнут',
#  'в',
#  'топол',
#  'окн',
#  ',',
#  'и',
#  ',',
#  'задума',
#  ',',
#  'подолг',
#  'слуша',
#  ',',
#  'как',
#  'вкрадчив',
#  'над',
#  'спящ',
#  'город',
#  'переклика',
#  'на',
#  'вокзал',
#  'ночн',
#  'поезд',
#  '.',
#  'пор',
#  'гудк',
#  'меша',
#  'ем',
#  ',',
#  'будораж',
#  'ег',
#  ',',
#  'и',
#  'отчего-т',
#  'тогд',
#  'вспомина',
#  'вечереющ',
#  'степ',
#  'с',
#  'пыльн',
#  'закат',
#  'над',
#  'темн',
#  'стог',
#  ',',
#  'и',
#  ',',
#  'подхвачен',
#  'волнен',
#  ',',
#  'он',
#  'броса',
#  'работ',
#  ',',
#  'на',
#  'цыпочк',
#  ',',
#  'чтоб',
#  'не',
#  'разбуд',
#  'жен',
#  ',',
#  'уход',
#  'из',
#  'дом',
#  ',',
#  'брод',
#  'по',
#  'пустын',
#  'и',
#  'тих',
#  'улиц',
#  '.',
#  'павел',
#  'георгиевич',
#  'сафон',
#  'работа',
#  'на',
#  'больш',
#  'завод',
#  'конструктор',
#  ',',
#  'был',
#  'извест',
#  ',',
#  'с',
#  'год',
#  'привык',
#  'к',
#  'эт',
#  'известн',
#  'и',
#  ',',
#  'каза',
#  ',',
#  'даж',
#  'немн',
#  'уста',
#  'от',
#  'не',
#  ',',
#  'как',
#  'пор',
#  'уста',
#  'люд',
#  ',',
#  'когд',
#  'к',
#  'ним',
#  'ран',
#  'приход',
#  'успех',
#  'и',
#  'удовлетворен',
#  '.',
#  'в',
#  'эт',
#  'год',
#  'сафон',
#  ',',
#  'утомлен',
#  'сложн',
#  'зимн',
#  'работ',
#  ',',
#  'был',
#  'в',
#  'санатор',
#  'на',
#  'южн',
#  'берег',
#  'крым',
#  '.',
#  'ослепительно-солнечн',
#  'юг',
#  'с',
#  'ег',
#  'остр',
#  ',',
#  'сух',
#  'жар',
#  ',',
#  'неестествен',
#  'экзотическ',
#  'пальм',
#  'на',
#  'бульвар',
#  ',',
#  'прокален',
#  'песок',
#  'пляж',
#  ',',
#  'купан',
#  'и',
#  'процедурн',
#  'лежан',
#  'под',
#  'тепл',
#  'йодист',
#  'дуновен',
#  'мор',
#  ',',
#  'ве',
#  'санаторн',
#  'реж',
#  'располага',
#  'к',
#  'бездел',
#  ',',
#  'одолева',
#  'курортн',
#  'лен',
#  ',',
#  'и',
#  'мысл',
#  'в',
#  'эт',
#  'жар',
#  'тож',
#  'был',
#  'притуплен',
#  ',',
#  'ленив',
#  ',',
#  'и',
#  'хотел',
#  'быстр',
#  'в',
#  'москв',
#  ',',
#  'к',
#  'осен',
#  'дожд',
#  ',',
#  'к',
#  'мокр',
#  'асфальт',
#  ',',
#  'к',
#  'блеск',
#  'фонар',
#  'в',
#  'луж',
#  '.',
#  'южн',
#  'экспресс',
#  ',',
#  'на',
#  'котор',
#  'сафон',
#  'возвраща',
#  'из',
#  'санатор',
#  ',',
#  'мчал',
#  'ег',
#  'по',
#  'знаком',
#  'мест',
#  ',',
#  'где',
#  'павел',
#  'георгиевич',
#  'род',
#  ',',
#  'вырос',
#  ',',
#  'где',
#  'он',
#  'не',
#  'был',
#  'мног',
#  'лет',
#  '.',
#  'утр',
#  ',',
#  'гляд',
#  'в',
#  'овлажнен',
#  'окн',
#  'тамбур',
#  'на',
#  'прохладн',
#  'степ',
#  ',',
#  'сафон',
#  'с',
#  'какой-т',
#  'грустн',
#  'обострен',
#  'вспомина',
#  'то',
#  ',',
#  'что',
#  'уж',
#  'был',
#  'полузабыт',
#  ':',
#  'вот',
#  'он',
#  ',',
#  'мальчишк',
#  ',',
#  'в',
#  'грязн',
#  'сатинов',
#  'рубашк',
#  ',',
#  'с',
#  'цыпк',
#  'на',
#  'рук',
#  ',',
#  'беж',
#  'по',
#  'эт',
#  'ледян',
#  'от',
#  'рос',
#  'степ',
#  ',',
#  'беж',
#  'вслед',
#  'за',
#  'поезд',
#  'неизвестн',
#  'куд',
#  ',',
#  'и',
#  'отяжелевш',
#  'от',
#  'влаг',
#  'трав',
#  'хлещет',
#  'ег',
#  'по',
#  'колен',
#  ',',
#  'приятн',
#  'холод',
#  'ноги…',
#  'скольк',
#  'тогд',
#  'ем',
#  'был',
#  'лет',
#  '?',
#  'пор',
#  'ясн',
#  'чуд',
#  ',',
#  'будт',
#  'вмест',
#  'с',
#  'вер',
#  'он',
#  'идет',
#  'по',
#  'лун',
#  'косяк',
#  'на',
#  'шахтинск',
#  'холм',
#  ',',
#  'внятн',
#  'и',
#  'резк',
#  'пахнет',
#  'из',
#  'низин',
#  'полын',
#  ',',
#  'и',
#  'потреска',
#  ',',
#  'обветрен',
#  'губ',
#  'вер',
#  'тож',
#  'пахнут',
#  'полын',
#  '.',
#  'воспоминан',
#  'возвраща',
#  'ег',
#  'в',
#  'давн',
#  'прожит',
#  '(',
#  'а',
#  'может',
#  'быт',
#  ',',
#  'непрожит',
#  ')',
#  'мир',
#  ',',
#  'говор',
#  ',',
#  'напомина',
#  ',',
#  'что',
#  'ем',
#  'уж',
#  'за',
#  'сорок',
#  'и',
#  'что',
#  'не',
#  'так',
#  'мног',
#  'сдела',
#  'в',
#  'ег',
#  'жизн',
#  ',',
#  'где',
#  'давн',
#  ',',
#  'отмечен',
#  'прочн',
#  'вех',
#  ',',
#  'перв',
#  'молод',
#  'прошл',
#  '.',
#  'и',
#  'вдруг',
#  'ег',
#  'непреодолим',
#  'потянул',
#  'побыва',
#  'в',
#  'родн',
#  'сво',
#  'степн',
#  'городк',
#  ':',
#  'поброд',
#  'по',
#  'нем',
#  ',',
#  'почита',
#  'афиш',
#  'на',
#  'забор',
#  ',',
#  'увидет',
#  'стар',
#  'назван',
#  'улиц',
#  ',',
#  'узна',
#  ',',
#  'что',
#  'измен',
#  'в',
#  'нем',
#  'за',
#  'мног',
#  'год',
#  ',',
#  'непремен',
#  'встрет',
#  'знаком',
#  'школьн',
#  'лет',
#  ',',
#  'так',
#  'далек',
#  ',',
#  'словн',
#  'их',
#  'и',
#  'не',
#  'был',
#  '.',
#  'ем',
#  'страстн',
#  'захотел',
#  'посидет',
#  'с',
#  'друг',
#  'юност',
#  'витьк',
#  'снегирев',
#  'где-нибуд',
#  'в',
#  'летн',
#  'каф',
#  ',',
#  'под',
#  'тент',
#  ',',
#  'за',
#  'холодн',
#  'пив',
#  ',',
#  'вспомн',
#  'то',
#  'наивн',
#  ',',
#  'давн',
#  'и',
#  'мил',
#  ',',
#  'что',
#  'уж',
#  'никогд',
#  'не',
#  'повтор',
#  ',',
#  'но',
#  'что',
#  'все-так',
#  'был',
#  'когда-т',
#  'в',
#  'ег',
#  'жизн',
#  '.',
#  'и',
#  'хот',
#  'эт',
#  'желан',
#  'побед',
#  ',',
#  'павел',
#  'георгиевич',
#  'с',
#  'ироническ',
#  'вид',
#  'потер',
#  'нос',
#  '(',
#  'в',
#  'сво',
#  'год',
#  'он',
#  'иногд',
#  'подтрунива',
#  'над',
#  'собствен',
#  'желан',
#  ')',
#  ',',
#  'вошел',
#  'в',
#  'куп',
#  ',',
#  'где',
#  'все',
#  'спал',
#  ',',
#  'подума',
#  'ещ',
#  'раз',
#  ',',
#  'улож',
#  'чемода',
#  ',',
#  'взял',
#  'плащ',
#  'и',
#  ',',
#  'к',
#  'удивлен',
#  'заспа',
#  'проводник',
#  ',',
#  'бесшумн',
#  'подмета',
#  'в',
#  'коридор',
#  ',',
#  'сошел',
#  'на',
#  'маленьк',
#  'разъезд',
#  'эт',
#  'ран',
#  'августовск',
#  'утр',
#  '.',
#  'он',
#  'сошел',
#  'не',
#  'на',
#  'вокзал',
#  'в',
#  'город',
#  ',',
#  'а',
#  'имен',
#  'зде',
#  ',',
#  'чтоб',
#  'дойт',
#  'до',
#  'город',
#  'пешк',
#  '.',
#  'южн',
#  'экспресс',
#  'с',
#  'жарк',
#  'от',
#  'зар',
#  'стекл',
#  ',',
#  'с',
#  'запылен',
#  'занавеск',
#  'тронул',
#  ',',
#  'полетел',
#  'вдол',
#  'насып',
#  'бумажк',
#  ',',
#  'поднят',
#  'ветр',
#  ',',
#  'и',
#  'ушел',
#  'быстр',
#  ';',
#  'дымк',
#  'почт',
#  'беззвучн',
#  'паровоз',
#  'тая',
#  'сред',
#  'сиренев',
#  'стекленеющ',
#  'неб',
#  'далек',
#  'на',
#  'запад',
#  ',',
#  'все',
#  'стихл',
#  '.',
#  'тольк',
#  'у',
#  'сам',
#  'насып',
#  'неумолчн',
#  'звенел',
#  ',',
#  'треща',
#  'в',
#  'неестествен',
#  'тишин',
#  'кузнечик',
#  '.',
#  'сид',
#  'на',
#  'чемодан',
#  ',',
#  'сафон',
#  'не',
#  'без',
#  'волнен',
#  'выкур',
#  'папирос',
#  ',',
#  'подума',
#  ':',
#  '«',
#  'необычайн',
#  'хорош',
#  '!',
#  '»',
#  '—',
#  'и',
#  'с',
#  'наслажден',
#  'вдохнул',
#  'на',
#  'полн',
#  'груд',
#  'зябк',
#  'и',
#  'чист',
#  ',',
#  'как',
#  'ключев',
#  'вод',
#  ',',
#  'воздух',
#  '.',
#  'степ',
#  ',',
#  'по-летн',
#  'пестр',
#  ',',
#  'в',
#  'этот',
#  'спокойн',
#  'час',
#  'утр',
#  'тепл',
#  'и',
#  'ал',
#  'краснел',
#  'за',
#  'холм',
#  'на',
#  'восток',
#  '.',
#  'там',
#  ',',
#  'в',
#  'эт',
#  'пыла',
#  ',',
#  'мнил',
#  ',',
#  'бесконечн',
#  'пыл',
#  'вдал',
#  'по',
#  'косогор',
#  'грузов',
#  'машин',
#  ',',
#  'и',
#  ',',
#  'четк',
#  'выреза',
#  'по',
#  'красн',
#  ',',
#  'проступа',
#  'терриконик',
#  ',',
#  'дальн',
#  'силуэт',
#  'водонапорн',
#  'башн',
#  ',',
#  'оазис',
#  'беленьк',
#  'дом',
#  ',',
#  'остр',
#  'верхушк',
#  'топол',
#  '.',
#  'с',
#  'насып',
#  'павел',
#  'георгиевич',
#  'не',
#  'тороп',
#  'спуст',
#  'в',
#  'степ',
#  ',',
#  'как',
#  'в',
#  'чаш',
#  ',',
#  'полн',
#  'ещ',
#  'сыр',
#  'прохлад',
#  ';',
#  'туг',
#  'волн',
#  'обдава',
#  'горьковат',
#  'запах',
#  'полын',
#  '.',
#  'и',
#  'пок',
#  'он',
#  'выбра',
#  'на',
#  'дорог',
#  ',',
#  'колен',
#  'ег',
#  'стал',
#  'влажн',
#  'от',
#  'рос',
#  ',',
#  'на',
#  'плащ',
#  ',',
#  'на',
#  'брюк',
#  'нацепля',
#  'репейник',
#  ',',
#  'чемода',
#  'облеп',
#  'мокр',
#  'лепестк',
#  '.',
#  'он',
#  'шага',
#  'по',
#  'дорог',
#  ',',
#  'приятн',
#  'утоп',
#  'ботинк',
#  'в',
#  'мягк',
#  'пыл',
#  ',',
#  'зат',
#  'сорва',
#  'прутик',
#  'с',
#  'молод',
#  'липк',
#  'кожиц',
#  ';',
#  'по-мальчишеск',
#  'сбив',
#  'рос',
#  ',',
#  'удар',
#  'им',
#  'по',
#  'головк',
#  'какого-т',
#  'фиолетов',
#  'цветк',
#  'у',
#  'обочин',
#  '(',
#  'назван',
#  'котор',
#  'в',
#  'детств',
#  'знал',
#  ',',
#  'но',
#  'тепер',
#  'заб',
#  ')',
#  '.',
#  'из',
#  'глубин',
#  'цветк',
#  'неожида',
#  'подня',
#  'сон',
#  'золотист',
#  'шмел',
#  ',',
#  'ве',
#  'в',
#  'намокш',
#  'пыльц',
#  ',',
#  'и',
#  'тяжел',
#  ',',
#  'сердит',
#  'прогудел',
#  'мим',
#  '.',
#  '—',
#  'иш',
#  'ты',
#  '!',
#  ...]

# %%
import nltk
sentence = "There is floating a brick from the town of Byron"
tokenized = nltk.tokenize.NLTKWordTokenizer().tokenize(sentence)
tagged = nltk.pos_tag(tokenized)
tagged
# Out:
# [('There', 'EX'),
#  ('is', 'VBZ'),
#  ('floating', 'VBG'),
#  ('a', 'DT'),
#  ('brick', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('town', 'NN'),
#  ('of', 'IN'),
#  ('Byron', 'NNP')]

# %%
grammar = "NP:{<DT>?<JJ>*<NN>}"
reg_parser = nltk.RegexpParser(grammar)
output = reg_parser.parse(tagged)
output.draw()
