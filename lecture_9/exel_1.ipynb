# %%
# %pip install -q numpy pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./real_estate_data.csv', sep='\t')
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# 1          11.0      2.0   посёлок Шушары           12817.0
# 2           8.3      0.0  Санкт-Петербург           21741.0
# 3           NaN      0.0  Санкт-Петербург           28098.0
# 4          41.0      NaN  Санкт-Петербург           31856.0
#
#   cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0             16028.0               1.0          482.0               2.0
# 1             18603.0               0.0            NaN               0.0
# 2             13933.0               1.0           90.0               2.0
# 3              6800.0               2.0           84.0               3.0
# 4              8098.0               2.0          112.0               1.0
#
#    ponds_nearest  days_exposition
# 0          755.0              NaN
# 1            NaN             81.0
# 2          574.0            558.0
# 3          234.0            424.0
# 4           48.0            121.0
#
# [5 rows x 22 columns]

# %%
df.info()
df.head(10)
print(f'{(1-len(df.dropna(subset=["is_apartment"])) / len(df))}%')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 42 to 23671
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          250 non-null    bool
#  1   last_price            250 non-null    bool
#  2   total_area            250 non-null    bool
#  3   first_day_exposition  250 non-null    object
#  4   rooms                 250 non-null    bool
#  5   ceiling_height        250 non-null    bool
#  6   floors_total          250 non-null    bool
#  7   living_area           250 non-null    bool
#  8   floor                 250 non-null    bool
#  9   is_apartment          250 non-null    bool
#  10  studio                250 non-null    bool
#  11  open_plan             250 non-null    bool
#  12  kitchen_area          250 non-null    bool
#  13  balcony               250 non-null    bool
#  14  locality_name         250 non-null    object
#  15  airports_nearest      250 non-null    bool
#  16  cityCenters_nearest   250 non-null    bool
#  17  parks_around3000      250 non-null    bool
#  18  parks_nearest         250 non-null    bool
#  19  ponds_around3000      250 non-null    bool
#  20  ponds_nearest         250 non-null    bool
#  21  days_exposition       250 non-null    bool
# dtypes: bool(20), object(2)
# memory usage: 10.7+ KB
# 0.0%

# %%
df = df.where(df['is_apartment'].isna(), False)
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 42            False       False       False                False  False
# 50            False       False       False                False  False
# 56            False       False       False                False  False
# 77            False       False       False                False  False
# 95            False       False       False                False  False
# ...             ...         ...         ...                  ...    ...
# 23378         False       False       False                False  False
# 23404         False       False       False                False  False
# 23416         False       False       False                False  False
# 23563         False       False       False                False  False
# 23671         False       False       False                False  False
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 42              False         False        False  False         False  ...
# 50              False         False        False  False         False  ...
# 56              False         False        False  False         False  ...
# 77              False         False        False  False         False  ...
# 95              False         False        False  False         False  ...
# ...               ...           ...          ...    ...           ...  ...
# 23378           False         False        False  False         False  ...
# 23404           False         False        False  False         False  ...
# 23416           False         False        False  False         False  ...
# 23563           False         False        False  False         False  ...
# 23671           False         False        False  False         False  ...
#
#        kitchen_area  balcony  locality_name  airports_nearest  \
# 42            False    False          False             False
# 50            False    False          False             False
# 56            False    False          False             False
# 77            False    False          False             False
# 95            False    False          False             False
# ...             ...      ...            ...               ...
# 23378         False    False          False             False
# 23404         False    False          False             False
# 23416         False    False          False             False
# 23563         False    False          False             False
# 23671         False    False          False             False
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 42                  False             False          False             False
# 50                  False             False          False             False
# 56                  False             False          False             False
# 77                  False             False          False             False
# 95                  False             False          False             False
# ...                   ...               ...            ...               ...
# 23378               False             False          False             False
# 23404               False             False          False             False
# 23416               False             False          False             False
# 23563               False             False          False             False
# 23671               False             False          False             False
#
#        ponds_nearest  days_exposition
# 42             False            False
# 50             False            False
# 56             False            False
# 77             False            False
# 95             False            False
# ...              ...              ...
# 23378          False            False
# 23404          False            False
# 23416          False            False
# 23563          False            False
# 23671          False            False
#
# [250 rows x 22 columns]

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
df.dropna(inplace=True)
df=df.dropna()

# %%
_df=np.where(df['is_apartment'].isna(),True,False)

# %%
_df.sum()
# Out:
# 0

# %%
df=df.where(df['is_apartment'].isna(),False)
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 42            False       False       False                False  False
# 50            False       False       False                False  False
# 56            False       False       False                False  False
# 77            False       False       False                False  False
# 95            False       False       False                False  False
# ...             ...         ...         ...                  ...    ...
# 23378         False       False       False                False  False
# 23404         False       False       False                False  False
# 23416         False       False       False                False  False
# 23563         False       False       False                False  False
# 23671         False       False       False                False  False
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 42              False         False        False  False         False  ...
# 50              False         False        False  False         False  ...
# 56              False         False        False  False         False  ...
# 77              False         False        False  False         False  ...
# 95              False         False        False  False         False  ...
# ...               ...           ...          ...    ...           ...  ...
# 23378           False         False        False  False         False  ...
# 23404           False         False        False  False         False  ...
# 23416           False         False        False  False         False  ...
# 23563           False         False        False  False         False  ...
# 23671           False         False        False  False         False  ...
#
#        kitchen_area  balcony  locality_name  airports_nearest  \
# 42            False    False          False             False
# 50            False    False          False             False
# 56            False    False          False             False
# 77            False    False          False             False
# 95            False    False          False             False
# ...             ...      ...            ...               ...
# 23378         False    False          False             False
# 23404         False    False          False             False
# 23416         False    False          False             False
# 23563         False    False          False             False
# 23671         False    False          False             False
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 42                  False             False          False             False
# 50                  False             False          False             False
# 56                  False             False          False             False
# 77                  False             False          False             False
# 95                  False             False          False             False
# ...                   ...               ...            ...               ...
# 23378               False             False          False             False
# 23404               False             False          False             False
# 23416               False             False          False             False
# 23563               False             False          False             False
# 23671               False             False          False             False
#
#        ponds_nearest  days_exposition
# 42             False            False
# 50             False            False
# 56             False            False
# 77             False            False
# 95             False            False
# ...              ...              ...
# 23378          False            False
# 23404          False            False
# 23416          False            False
# 23563          False            False
# 23671          False            False
#
# [250 rows x 22 columns]

# %%
df=df.where(df['is_apartment'].isna(),False)
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 42            False       False       False                False  False
# 50            False       False       False                False  False
# 56            False       False       False                False  False
# 77            False       False       False                False  False
# 95            False       False       False                False  False
# ...             ...         ...         ...                  ...    ...
# 23378         False       False       False                False  False
# 23404         False       False       False                False  False
# 23416         False       False       False                False  False
# 23563         False       False       False                False  False
# 23671         False       False       False                False  False
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 42              False         False        False  False         False  ...
# 50              False         False        False  False         False  ...
# 56              False         False        False  False         False  ...
# 77              False         False        False  False         False  ...
# 95              False         False        False  False         False  ...
# ...               ...           ...          ...    ...           ...  ...
# 23378           False         False        False  False         False  ...
# 23404           False         False        False  False         False  ...
# 23416           False         False        False  False         False  ...
# 23563           False         False        False  False         False  ...
# 23671           False         False        False  False         False  ...
#
#        kitchen_area  balcony  locality_name  airports_nearest  \
# 42            False    False          False             False
# 50            False    False          False             False
# 56            False    False          False             False
# 77            False    False          False             False
# 95            False    False          False             False
# ...             ...      ...            ...               ...
# 23378         False    False          False             False
# 23404         False    False          False             False
# 23416         False    False          False             False
# 23563         False    False          False             False
# 23671         False    False          False             False
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 42                  False             False          False             False
# 50                  False             False          False             False
# 56                  False             False          False             False
# 77                  False             False          False             False
# 95                  False             False          False             False
# ...                   ...               ...            ...               ...
# 23378               False             False          False             False
# 23404               False             False          False             False
# 23416               False             False          False             False
# 23563               False             False          False             False
# 23671               False             False          False             False
#
#        ponds_nearest  days_exposition
# 42             False            False
# 50             False            False
# 56             False            False
# 77             False            False
# 95             False            False
# ...              ...              ...
# 23378          False            False
# 23404          False            False
# 23416          False            False
# 23563          False            False
# 23671          False            False
#
# [250 rows x 22 columns]

# %%
df['is_apartment']=df['is_apartment'].fillna(False)
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 42            False       False       False                False  False
# 50            False       False       False                False  False
# 56            False       False       False                False  False
# 77            False       False       False                False  False
# 95            False       False       False                False  False
# ...             ...         ...         ...                  ...    ...
# 23378         False       False       False                False  False
# 23404         False       False       False                False  False
# 23416         False       False       False                False  False
# 23563         False       False       False                False  False
# 23671         False       False       False                False  False
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 42              False         False        False  False         False  ...
# 50              False         False        False  False         False  ...
# 56              False         False        False  False         False  ...
# 77              False         False        False  False         False  ...
# 95              False         False        False  False         False  ...
# ...               ...           ...          ...    ...           ...  ...
# 23378           False         False        False  False         False  ...
# 23404           False         False        False  False         False  ...
# 23416           False         False        False  False         False  ...
# 23563           False         False        False  False         False  ...
# 23671           False         False        False  False         False  ...
#
#        kitchen_area  balcony  locality_name  airports_nearest  \
# 42            False    False          False             False
# 50            False    False          False             False
# 56            False    False          False             False
# 77            False    False          False             False
# 95            False    False          False             False
# ...             ...      ...            ...               ...
# 23378         False    False          False             False
# 23404         False    False          False             False
# 23416         False    False          False             False
# 23563         False    False          False             False
# 23671         False    False          False             False
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 42                  False             False          False             False
# 50                  False             False          False             False
# 56                  False             False          False             False
# 77                  False             False          False             False
# 95                  False             False          False             False
# ...                   ...               ...            ...               ...
# 23378               False             False          False             False
# 23404               False             False          False             False
# 23416               False             False          False             False
# 23563               False             False          False             False
# 23671               False             False          False             False
#
#        ponds_nearest  days_exposition
# 42             False            False
# 50             False            False
# 56             False            False
# 77             False            False
# 95             False            False
# ...              ...              ...
# 23378          False            False
# 23404          False            False
# 23416          False            False
# 23563          False            False
# 23671          False            False
#
# [250 rows x 22 columns]

# %%
df.isna().sum()
# Out:
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# cityCenters_nearest     0
# parks_around3000        0
# parks_nearest           0
# ponds_around3000        0
# ponds_nearest           0
# days_exposition         0
# dtype: int64
