# %%
class Matrix:
    matrix1:list=([
    [1,2,3],
    [5,9,15],
    [45,67,32],
    ])
    matrix2:list=([
    [53,7,11],
    [39,32,35],
    [62,40,86],
    ])
    # def __init__(
    # self,
    # matrix1:list=([
    # [1,2,3],
    # [5,9,15],
    # [45,67,32],
    # ]),
    # matrix2:list=([
    # [53,7,11],
    # [39,32,35],
    # [62,40,86],
    # ])
    # ):
        # self.matrix1=matrix1
        # self.matrix2=matrix2
        # def __add__(self,other):
        #     plus_matrix=Matrix(self.matrix1+other.matrix2)
        #     return plus_matrix
        # def __sub__(self,other):
        #     minus_matrix=Matrix(self.matrix1-other.matrix2)
        #     return minus_matrix
        # def __mul__(self,other):
        #     ymnoshenie_matrix=Matrix(self.matrix1*other.matrix2)
        #     return ymnoshenie_matrix
    for i in range(len(matrix1)):
        for j in range(len(matrix2)):
            matrix3:list=([matrix1[0][0]+matrix2[0][0],matrix1[0][1]+matrix2[0][1],matrix1[0][2]+matrix2[0][2],
                           matrix1[1][0]+matrix2[1][0],matrix1[1][1]+matrix2[1][1],matrix1[1][2]+matrix2[1][2],
                           matrix1[2][0]+matrix2[2][0],matrix1[2][1]+matrix2[2][1],matrix1[2][2]+matrix2[2][2]])
            print(matrix3)
            matrix4: list=([matrix1[0][0]-matrix2[0][0],matrix1[0][1]-matrix2[0][1],matrix1[0][2]-matrix2[0][2],
                            matrix1[1][0]-matrix2[1][0],matrix1[1][1]-matrix2[1][1],matrix1[1][2]-matrix2[1][2],
                            matrix1[2][0]-matrix2[2][0],matrix1[2][1]-matrix2[2][1],matrix1[2][2]-matrix2[2][2]])
            print(matrix4)
            matrix5: list=([matrix1[0][0]*matrix2[0][0],matrix1[0][1]*matrix2[1][0],matrix1[0][2]*matrix2[2][0],
                            matrix1[1][0]*matrix2[0][1],matrix1[1][1]*matrix2[1][1],matrix1[1][2]*matrix2[1][2],
                            matrix1[2][0]*matrix2[0][2],matrix1[2][1]*matrix2[1][2],matrix1[2][2]*matrix2[2][2]])
            print(matrix5)
            matrix6: list=([matrix1[0][0]/matrix2[0][0],matrix1[0][1]/matrix2[1][0],matrix1[0][2]/matrix2[2][0],
                            matrix1[1][0]/matrix2[0][1],matrix1[1][1]/matrix2[1][1],matrix1[1][2]/matrix2[1][2],
                            matrix1[2][0]/matrix2[0][2],matrix1[2][1]/matrix2[1][2],matrix1[2][2]/matrix2[2][2]])
            print(matrix6)
# Out:
# [54, 9, 14, 44, 41, 50, 107, 107, 118]
# [-52, -5, -8, -34, -23, -20, -17, 27, -54]
# [53, 78, 186, 35, 288, 525, 495, 2345, 2752]
# [0.018867924528301886, 0.05128205128205128, 0.04838709677419355, 0.7142857142857143, 0.28125, 0.42857142857142855, 4.090909090909091, 1.9142857142857144, 0.37209302325581395]
# [54, 9, 14, 44, 41, 50, 107, 107, 118]
# [-52, -5, -8, -34, -23, -20, -17, 27, -54]
# [53, 78, 186, 35, 288, 525, 495, 2345, 2752]
# [0.018867924528301886, 0.05128205128205128, 0.04838709677419355, 0.7142857142857143, 0.28125, 0.42857142857142855, 4.090909090909091, 1.9142857142857144, 0.37209302325581395]
# [54, 9, 14, 44, 41, 50, 107, 107, 118]
# [-52, -5, -8, -34, -23, -20, -17, 27, -54]
# [53, 78, 186, 35, 288, 525, 495, 2345, 2752]
# [0.018867924528301886, 0.05128205128205128, 0.04838709677419355, 0.7142857142857143, 0.28125, 0.42857142857142855, 4.090909090909091, 1.9142857142857144, 0.37209302325581395]
# [54, 9, 14, 44, 41, 50, 107, 107, 118]
# ...
